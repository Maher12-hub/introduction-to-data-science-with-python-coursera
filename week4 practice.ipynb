# %%
import pandas as pd
import numpy as np

# %%
np.random.binomial(1,0.5)
# Out:
# 0

# %%
np.random.binomial(1000,0.5)
# Out:
# 516

# %%
np.random.binomial(10,0.4)
# Out:
# 5

# %%
np.random.binomial(10,0.5,10)==5
# Out:
# array([False, False, False,  True, False, False, False, False, False,
#         True])

# %%
sum(np.random.binomial(5,0.5,5))
# Out:
# 14

# %%
sum(np.random.binomial(20,0.5,1000000)==20)/1000000
# Out:
# 3e-06

# %%
sum(np.random.binomial(20,0.5,10000)>=15)/10000
# Out:
# 0.0205

# %%
chance_of_tornado=0.01/100
np.random.binomial(10000,chance_of_tornado)
# Out:
# 1

# %%
chance_of_tornado=0.01
two_days_in_a_row=0
tornado_events=np.random.binomial(1,chance_of_tornado,1000000)
for j in range(1,len(tornado_events)-1):
    if tornado_events[j]==1 and tornado_events[j-1]==1:
        two_days_in_a_row+=1
print('{} tornadoes back to back in {} years'.format(two_days_in_a_row,1000000/365))
# Out:
# 93 tornadoes back to back in 2739.72602739726 years

# %%
np.random.normal(0.75,size=100)
# Out:
# array([ 1.3098954 ,  0.55211641,  0.3468324 ,  0.83350199,  0.31443186,
#         1.30225552,  1.30054449,  1.8646745 ,  0.36303479,  1.01154345,
#         1.55903575, -1.21658053,  1.71301571,  0.35804117,  1.19682395,
#         0.12375504, -1.01918738, -0.49429893,  1.90524046,  2.19320595,
#         0.98494511,  0.6421536 ,  0.54592134, -0.03185349, -0.84811274,
#         0.89081367,  1.63354531,  1.38465844,  0.34821281, -0.82609702,
#         1.05413602,  0.71551624,  0.50973278, -0.8556655 ,  1.50123171,
#         0.1874507 ,  1.31886609, -0.16602585,  2.22420494,  1.73009727,
#         0.09083635, -0.28044088,  0.04308284,  0.17259098,  0.96894572,
#         0.50743902, -0.34524091,  1.25364634,  1.87266046,  0.22781025,
#         1.35287849,  1.20933014,  0.96651531,  0.30324046,  2.31163065,
#         1.03728376,  2.0077112 ,  0.63444906,  0.57437082,  0.10952809,
#         1.81208655,  1.45755695, -0.3447451 , -0.31538462,  1.49609997,
# ...

# %%
distribution=np.random.normal(0.75,size=1000)
np.sqrt(np.sum((np.mean(distribution))-distribution)**2/len(distribution))
# Out:
# 5.617333549722722e-16

# %%
np.std(distribution)
# Out:
# 0.9848707805052569

# %%
import scipy.stats as stats

# %%
stats.kurtosis(distribution)
# Out:
# -0.15799160154399639

# %%
stats.skew(distribution)
# Out:
# 0.17215496133700448

# %%
chi_square_df2=np.random.chisquare(2,1000)
stats.skew(chi_square_df2)
# Out:
# 1.4705372661279354

# %%
chi_square_df5=np.random.chisquare(5,1000)
stats.skew(chi_square_df5)
# Out:
# 1.1922847527218325

# %%
chi_square_df2
# Out:
# array([1.44408606e+00, 1.86328871e+00, 1.50460300e+00, 3.60061341e+00,
#        1.20230121e-01, 2.88464149e-01, 7.33016882e-01, 1.93683996e+00,
#        5.93594969e-01, 1.72116316e+00, 2.46851532e+00, 1.74436064e+00,
#        7.38184728e-02, 2.11036275e+00, 2.24009544e-01, 4.13975079e-02,
#        1.86910153e+00, 1.09396130e+01, 1.10548607e+00, 2.91343920e+00,
#        3.85097099e+00, 2.03224988e+00, 1.75555497e-01, 2.44583865e-01,
#        1.14010223e+00, 6.50585241e-01, 9.60281006e-01, 1.31536846e+00,
#        4.85756994e+00, 1.91648196e+00, 3.27522060e+00, 4.12566745e+00,
#        3.69342805e-01, 1.22133542e+00, 8.58462710e-01, 6.10483820e-01,
#        2.05764719e+00, 3.41450670e+00, 2.24988690e+00, 3.29661263e-01,
#        1.28637703e+00, 2.77737320e+00, 6.33523524e+00, 5.37999079e-01,
#        4.01700210e+00, 1.37955271e+00, 7.03890261e-01, 3.46063021e+00,
#        1.66767832e+00, 5.91887721e+00, 9.21693541e-02, 3.18036464e-01,
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
plt.hist([chi_square_df2,chi_square_df5],bins=50,histtype='step',
        label=['2 degrees of freedom','5 degrees of freedom'])
plt.legend(loc='upper right')

# %%
np.random.normal(0.75)
# Out:
# 0.6436679264988702

# %%
distribution=np.random.normal(0.75,size=1000)

# %%
#np.sqrt(np.sum((np.mean(distribution))-distribution)**2/len(distribution))
#np.sqrt(np.sum((np.mean(distribution)-distribution)**2)/len(distribution))

# %%
np.std(distribution)
# Out:
# 0.9994105320010072

# %%
np.sqrt(np.sum((np.mean(distribution)-distribution)**2)/len(distribution))
# Out:
# 0.9994105320010072

# %%
import scipy.stats as stats

# %%
stats.kurtosis(distribution)
# Out:
# 0.01910122508128964

# %%
stats.skew(distribution)
# Out:
# 0.015190565999653986

# %%
plt.hist(distribution)
# Out:
# (array([  5.,  25.,  74., 173., 266., 240., 135.,  66.,  12.,   4.]),
#  array([-2.53543666, -1.86670369, -1.19797072, -0.52923774,  0.13949523,
#          0.8082282 ,  1.47696118,  2.14569415,  2.81442712,  3.4831601 ,
#          4.15189307]),
#  <a list of 10 Patch objects>)

# %%
chi_square_df2=np.random.chisquare(2,1000)
stats.skew(chi_square_df2)
# Out:
# 2.105588537270677

# %%
chi_square_df5=np.random.chisquare(5,1000)
stats.skew(chi_square_df5)
# Out:
# 1.5148129655972145

# %%
chi_square_df7=np.random.chisquare(7,1000)
stats.skew(chi_square_df7)
# Out:
# 0.9852994195578149

# %%
plt.hist([chi_square_df2,chi_square_df5,chi_square_df7],histtype='step',
        label=['2 degrees of freedom','5 degrees of freedom','7 degrees of freedom'])
# Out:
# ([array([751., 182.,  47.,  15.,   2.,   3.,   0.,   0.,   0.,   0.]),
#   array([221., 381., 223., 101.,  46.,  16.,   6.,   4.,   1.,   1.]),
#   array([ 81., 267., 286., 190., 102.,  47.,  17.,   5.,   3.,   2.])],
#  array([7.65938937e-04, 2.58745745e+00, 5.17414896e+00, 7.76084047e+00,
#         1.03475320e+01, 1.29342235e+01, 1.55209150e+01, 1.81076065e+01,
#         2.06942980e+01, 2.32809895e+01, 2.58676811e+01]),
#  <a list of 3 Lists of Patches objects>)

# %%
df=pd.read_csv('grades.csv')
df.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
df[df['assignment1_submission']<'2015-12-31'].mean()
# Out:
# assignment1_grade    74.972741
# assignment2_grade    67.252190
# assignment3_grade    61.129050
# assignment4_grade    54.157620
# assignment5_grade    48.634643
# assignment6_grade    43.838980
# dtype: float64

# %%
early=df[df['assignment1_submission']<'2015-12-31']
late=df[df['assignment1_submission']>'2015-12-31']

# %% [raw]
# early.mean(

# %%
early.mean()
# Out:
# assignment1_grade    74.972741
# assignment2_grade    67.252190
# assignment3_grade    61.129050
# assignment4_grade    54.157620
# assignment5_grade    48.634643
# assignment6_grade    43.838980
# dtype: float64

# %%
late.mean()
# Out:
# assignment1_grade    74.017429
# assignment2_grade    66.370822
# assignment3_grade    60.023244
# assignment4_grade    54.058138
# assignment5_grade    48.599402
# assignment6_grade    43.844384
# dtype: float64

# %%
import scipy.stats as stats

# %%
stats.ttest_ind(early['assignment1_grade'],late['assignment1_grade'])
# Out:
# Ttest_indResult(statistic=1.400549944897566, pvalue=0.16148283016060577)

# %%
early=df[df['assignment2_submission']<'2016-01-01']

# %%
late=df[df['assignment2_submission']>'2016-01-01']

# %%
stats.ttest_ind(early['assignment2_grade'],late['assignment2_grade'])
# Out:
# Ttest_indResult(statistic=1.362005108556627, pvalue=0.17332889938698917)

# %%
np.random.binomial(10,0.5,10)
# Out:
# array([4, 2, 6, 4, 3, 6, 7, 3, 7, 4])

# %%
sum(np.random.binomial(20,0.5,1000000)==20)
# Out:
# 2

# %%
sum(np.random.binomial(20,0.5,1000000)==20)/1000000
# Out:
# 0.0

# %%
sum(np.random.binomial(20,0.5,10000)>=15)/10000
# Out:
# 0.0212

# %%
np.random.binomial(1000000,0.01)
# Out:
# 9880

# %%
chance_of_tornado=0.01

tornado_events=np.random.binomial(1,0.01,1000000)
two_days_in_a_row=0
for j in range(1,len(tornado_events)-1):
    if tornado_events[j]==1 and tornado_events[j-1]==1:
        two_days_in_a_row+=1
        
print('{} tornados happen back to back in {} years'.format(two_days_in_a_row,1000000/365))
# Out:
# 110 tornados happen back to back in 2739.72602739726 years

# %%
win_chance=0.5
match_event=np.random.binomial(1,win_chance,1095)
two_wins_back_to_back=0
for j in range(1,len(match_event)-1):
    if match_event[j]==1 and match_event[j-1]==1:
        two_wins_back_to_back+=1
print('Bangladesh wins {} match back to back in two days with in {} years'.format(two_wins_back_to_back,1095/365))
# Out:
# Bangladesh wins 296 match back to back in two days with in 3.0 years

# %%
distribution=np.random.normal(0.75,size=1000)
distribution
# Out:
# array([-6.54550597e-01, -5.22403300e-02,  1.54579692e+00,  1.09767114e+00,
#         5.67667533e-01,  1.65895715e+00,  1.13140668e-01,  2.06980486e+00,
#        -9.33818926e-01, -5.88401349e-01,  8.87727098e-01, -4.19145378e-01,
#         8.28307777e-01,  7.05145041e-01,  6.55410399e-01,  1.61612351e+00,
#         1.16711627e+00, -2.12353067e-01,  9.88720806e-01,  1.12178906e+00,
#         1.00450736e+00,  5.34048943e-01,  1.57192409e-01,  1.23910314e+00,
#         2.23504133e+00, -2.70802920e-01, -1.27203036e+00,  1.06745040e+00,
#        -2.94294858e-01, -4.23561409e-02, -8.78901634e-01,  3.41371477e-01,
#        -1.99836011e-01, -9.18644147e-01,  1.59570919e+00,  1.00215583e+00,
#        -1.64195077e+00,  1.23242614e+00, -2.38640578e-01,  2.10353774e+00,
#         4.80534875e-01,  5.87439489e-01,  1.14869443e+00, -2.64946636e-01,
#        -1.19484209e+00,  1.24408989e+00,  4.66451456e-01,  3.74529503e-01,
# ...

# %%
#np.sqrt(np.sum(((np.mean(distribution))-distribution)**2)/len(distribution))
# Out:
# 1.0028404903026686

# %%
np.sqrt(np.sum((np.mean(distribution)-distribution)**2)/len(distribution))
# Out:
# 1.0028404903026686

# %%
np.std(distribution)
# Out:
# 1.0028404903026686

# %%
stats.skew(distribution)
# Out:
# -0.07750254427315115

# %%
stats.kurtosis(distribution)
# Out:
# -0.19831286781147472

# %%
chi_square_df2=np.random.chisquare(2,size=1000)

# %%
chi_square_df5=np.random.chisquare(5,size=1000)

# %%
plt.hist([chi_square_df2,chi_square_df5],histtype='step')
# Out:
# ([array([570., 250., 108.,  45.,  21.,   4.,   2.,   0.,   0.,   0.]),
#   array([131., 252., 230., 164., 109.,  51.,  35.,  13.,   5.,  10.])],
#  array([3.07696601e-03, 1.75384358e+00, 3.50461020e+00, 5.25537682e+00,
#         7.00614344e+00, 8.75691006e+00, 1.05076767e+01, 1.22584433e+01,
#         1.40092099e+01, 1.57599765e+01, 1.75107432e+01]),
#  <a list of 2 Lists of Patches objects>)

# %%
df=pd.read_csv('grades.csv')

# %%
early=df[df['assignment3_submission']<'2016-01-01']

# %%
late=df[df['assignment3_submission']>'2016-01-01']

# %%
import scipy.stats as stats

# %%
stats.ttest_ind(early['assignment3_grade'],late['assignment3_grade'])
# Out:
# Ttest_indResult(statistic=1.2287086561461127, pvalue=0.2193060556647722)

# %%
# Out:
# True

# %%
df=pd.read_csv('City_Zhvi_AllHomes.csv')

# %%
df.head()
# Out:
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07  ...  2015-11  2015-12  \
# 0         1       NaN       NaN       NaN       NaN  ...   573600   576200
# 1         2  155000.0  154600.0  154400.0  154200.0  ...   558200   560800
# 2         3  109700.0  109400.0  109300.0  109300.0  ...   207800   206900
# 3         4   50000.0   49900.0   49600.0   49400.0  ...   122300   121600
# 4         5   87200.0   87700.0   88200.0   88400.0  ...   183800   185300
#
# ...

# %%
GDP=pd.read_excel('gdplev.xls')

# %%
GDP
# Out:
#     Current-Dollar and "Real" Gross Domestic Product  \
# 0                                                NaN
# 1                                             Annual
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 280                                              NaN
# 281                                              NaN
# 282                                              NaN
# 283                                              NaN
# 284                                              NaN
#
#                              Unnamed: 1  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4    GDP in billions of current dollars
# ..                                  ...
# ...

# %%
states = {'OH': 'Ohio', 'KY': 'Kentucky', 'AS': 'American Samoa', 'NV': 'Nevada', 'WY': 'Wyoming', 'NA': 'National', 'AL': 'Alabama', 'MD': 'Maryland', 'AK': 'Alaska', 'UT': 'Utah', 'OR': 'Oregon', 'MT': 'Montana', 'IL': 'Illinois', 'TN': 'Tennessee', 'DC': 'District of Columbia', 'VT': 'Vermont', 'ID': 'Idaho', 'AR': 'Arkansas', 'ME': 'Maine', 'WA': 'Washington', 'HI': 'Hawaii', 'WI': 'Wisconsin', 'MI': 'Michigan', 'IN': 'Indiana', 'NJ': 'New Jersey', 'AZ': 'Arizona', 'GU': 'Guam', 'MS': 'Mississippi', 'PR': 'Puerto Rico', 'NC': 'North Carolina', 'TX': 'Texas', 'SD': 'South Dakota', 'MP': 'Northern Mariana Islands', 'IA': 'Iowa', 'MO': 'Missouri', 'CT': 'Connecticut', 'WV': 'West Virginia', 'SC': 'South Carolina', 'LA': 'Louisiana', 'KS': 'Kansas', 'NY': 'New York', 'NE': 'Nebraska', 'OK': 'Oklahoma', 'FL': 'Florida', 'CA': 'California', 'CO': 'Colorado', 'PA': 'Pennsylvania', 'DE': 'Delaware', 'NM': 'New Mexico', 'RI': 'Rhode Island', 'MN': 'Minnesota', 'VI': 'Virgin Islands', 'NH': 'New Hampshire', 'MA': 'Massachusetts', 'GA': 'Georgia', 'ND': 'North Dakota', 'VA': 'Virginia'}
df['State']=df['State'].map(states)

# %%
df.head()
# Out:
#    RegionID    RegionName         State                           Metro  \
# 0      6181      New York      New York                        New York
# 1     12447   Los Angeles    California  Los Angeles-Long Beach-Anaheim
# 2     17426       Chicago      Illinois                         Chicago
# 3     13271  Philadelphia  Pennsylvania                    Philadelphia
# 4     40326       Phoenix       Arizona                         Phoenix
#
#      CountyName  SizeRank   1996-04   1996-05   1996-06   1996-07  ...  \
# 0        Queens         1       NaN       NaN       NaN       NaN  ...
# 1   Los Angeles         2  155000.0  154600.0  154400.0  154200.0  ...
# 2          Cook         3  109700.0  109400.0  109300.0  109300.0  ...
# 3  Philadelphia         4   50000.0   49900.0   49600.0   49400.0  ...
# 4      Maricopa         5   87200.0   87700.0   88200.0   88400.0  ...
#
#    2015-11  2015-12  2016-01  2016-02  2016-03  2016-04  2016-05  2016-06  \
# ...

# %%
fo=open('university_towns.txt','r')
lines=fo.readlines()
fo.close()
lines
# Out:
# ['Alabama[edit]\n',
#  'Auburn (Auburn University)[1]\n',
#  'Florence (University of North Alabama)\n',
#  'Jacksonville (Jacksonville State University)[2]\n',
#  'Livingston (University of West Alabama)[2]\n',
#  'Montevallo (University of Montevallo)[2]\n',
#  'Troy (Troy University)[2]\n',
#  'Tuscaloosa (University of Alabama, Stillman College, Shelton State)[3][4]\n',
#  'Tuskegee (Tuskegee University)[5]\n',
#  'Alaska[edit]\n',
#  'Fairbanks (University of Alaska Fairbanks)[2]\n',
#  'Arizona[edit]\n',
#  'Flagstaff (Northern Arizona University)[6]\n',
#  'Tempe (Arizona State University)\n',
#  'Tucson (University of Arizona)\n',
#  'Arkansas[edit]\n',
#  'Arkadelphia (Henderson State University, Ouachita Baptist University)[2]\n',
#  'Conway (Central Baptist College, Hendrix College, University of Central Arkansas)[2]\n',
#  'Fayetteville (University of Arkansas)[7]\n',
#  'Jonesboro (Arkansas State University)[8]\n',
#  'Magnolia (Southern Arkansas University)[2]\n',
# ...

# %%
import re
new_lines = []
for line in lines:
    if not re.match(r'^\s*$', line):
        new_lines.append(line)
lines=new_lines.copy()
lines
# Out:
# ['Alabama[edit]\n',
#  'Auburn (Auburn University)[1]\n',
#  'Florence (University of North Alabama)\n',
#  'Jacksonville (Jacksonville State University)[2]\n',
#  'Livingston (University of West Alabama)[2]\n',
#  'Montevallo (University of Montevallo)[2]\n',
#  'Troy (Troy University)[2]\n',
#  'Tuscaloosa (University of Alabama, Stillman College, Shelton State)[3][4]\n',
#  'Tuskegee (Tuskegee University)[5]\n',
#  'Alaska[edit]\n',
#  'Fairbanks (University of Alaska Fairbanks)[2]\n',
#  'Arizona[edit]\n',
#  'Flagstaff (Northern Arizona University)[6]\n',
#  'Tempe (Arizona State University)\n',
#  'Tucson (University of Arizona)\n',
#  'Arkansas[edit]\n',
#  'Arkadelphia (Henderson State University, Ouachita Baptist University)[2]\n',
#  'Conway (Central Baptist College, Hendrix College, University of Central Arkansas)[2]\n',
#  'Fayetteville (University of Arkansas)[7]\n',
#  'Jonesboro (Arkansas State University)[8]\n',
#  'Magnolia (Southern Arkansas University)[2]\n',
# ...

# %%
new_lines
# Out:
# ['Alabama[edit]\n',
#  'Auburn (Auburn University)[1]\n',
#  'Florence (University of North Alabama)\n',
#  'Jacksonville (Jacksonville State University)[2]\n',
#  'Livingston (University of West Alabama)[2]\n',
#  'Montevallo (University of Montevallo)[2]\n',
#  'Troy (Troy University)[2]\n',
#  'Tuscaloosa (University of Alabama, Stillman College, Shelton State)[3][4]\n',
#  'Tuskegee (Tuskegee University)[5]\n',
#  'Alaska[edit]\n',
#  'Fairbanks (University of Alaska Fairbanks)[2]\n',
#  'Arizona[edit]\n',
#  'Flagstaff (Northern Arizona University)[6]\n',
#  'Tempe (Arizona State University)\n',
#  'Tucson (University of Arizona)\n',
#  'Arkansas[edit]\n',
#  'Arkadelphia (Henderson State University, Ouachita Baptist University)[2]\n',
#  'Conway (Central Baptist College, Hendrix College, University of Central Arkansas)[2]\n',
#  'Fayetteville (University of Arkansas)[7]\n',
#  'Jonesboro (Arkansas State University)[8]\n',
#  'Magnolia (Southern Arkansas University)[2]\n',
# ...

# %%
df=pd.DataFrame(columns=('state','region'))

# %%
df
# Out:
# Empty DataFrame
# Columns: [state, region]
# Index: []

# %%
s1='22/07/2017,20/01/2017,01/01/2018'
=re.sb(r'(\d{2})/(\d{2})/(/d{4})',r'\3-\2-\1',s1)
# Out:
# '22/07/2017,20/01/2017,01/01/2018'

# %%
import re
s1='22/07/2017,20/01/2017,01/01/2018'
result=re.sub(r'(\d{2})/(\d{2})/(\d{4})',r'\3-\2-\1',s1)

# %%
result
# Out:
# '2017-07-22,2017-01-20,2018-01-01'

# %%
import pandas as pd
df=pd.DataFrame(columns=('state','region'))
df.loc[0]=['maher','rehman']

# %%
df
# Out:
#    state  region
# 0  maher  rehman

# %%
import pandas as pd
import re

# %%
fo=open('university_towns.txt','r')
lines=fo.readlines()
fo.close()

# %%
new_lines=[]
for line in lines:
    if not re.match(r'^\s*$',line):
        new_lines.append(line)
lines=new_lines.copy()

# %%
for index,line in enumerate(lines):
    lines[index]=line.strip()
lines
# Out:
# ['Alabama[edit]',
#  'Auburn (Auburn University)[1]',
#  'Florence (University of North Alabama)',
#  'Jacksonville (Jacksonville State University)[2]',
#  'Livingston (University of West Alabama)[2]',
#  'Montevallo (University of Montevallo)[2]',
#  'Troy (Troy University)[2]',
#  'Tuscaloosa (University of Alabama, Stillman College, Shelton State)[3][4]',
#  'Tuskegee (Tuskegee University)[5]',
#  'Alaska[edit]',
#  'Fairbanks (University of Alaska Fairbanks)[2]',
#  'Arizona[edit]',
#  'Flagstaff (Northern Arizona University)[6]',
#  'Tempe (Arizona State University)',
#  'Tucson (University of Arizona)',
#  'Arkansas[edit]',
#  'Arkadelphia (Henderson State University, Ouachita Baptist University)[2]',
#  'Conway (Central Baptist College, Hendrix College, University of Central Arkansas)[2]',
#  'Fayetteville (University of Arkansas)[7]',
#  'Jonesboro (Arkansas State University)[8]',
#  'Magnolia (Southern Arkansas University)[2]',
# ...

# %%
df_result=pd.DataFrame(columns=('State','RegionName'))
i=0
state_string=''
region_string=''
for line in lines:
    if '[edit]' in line:
        state_string=line.replace('[edit]','')
    else:
        region_string=re.sub(r'\(.*','',line)
        df_result.loc[i]=[state_string,region_string]
        i+=1

# %%
df_result
# Out:
#          State      RegionName
# 0      Alabama         Auburn
# 1      Alabama       Florence
# 2      Alabama   Jacksonville
# 3      Alabama     Livingston
# 4      Alabama     Montevallo
# ..         ...             ...
# 512  Wisconsin    River Falls
# 513  Wisconsin  Stevens Point
# 514  Wisconsin       Waukesha
# 515  Wisconsin     Whitewater
# 516    Wyoming        Laramie
#
# [517 rows x 2 columns]

# %%
fo=open('university_towns.txt','r')
lines=fo.readlines()
fo.close()
New_lines=[]
for line in lines:
    if not re.match(r'^\s*$',line):
        New_lines.append(line)
lines=New_lines.copy()
for index,line in enumerate(lines):
    lines[index]=line.strip()
df_result=pd.DataFrame(columns=('State','RegionName'))
i=0
state_string=''
region_string=''
for line in lines:
    if '[edit]' in line:
        state_string=line.replace('[edit]','')
    else:
        region_string=re.sub(r'\(.*','',line)
        df_result.loc[i]=[state_string,region_string]
        i+=1
df_result
# Out:
#          State      RegionName
# 0      Alabama         Auburn
# 1      Alabama       Florence
# 2      Alabama   Jacksonville
# 3      Alabama     Livingston
# 4      Alabama     Montevallo
# ..         ...             ...
# 512  Wisconsin    River Falls
# 513  Wisconsin  Stevens Point
# 514  Wisconsin       Waukesha
# 515  Wisconsin     Whitewater
# 516    Wyoming        Laramie
#
# [517 rows x 2 columns]

# %%
df=pd.read_excel('gdplev.xls',skiprows=220,header=None)

# %%
df_gdp=pd.read_excel('gdplev.xls',skiprows=219)

# %%
df_gdp=df_gdp[['1999q4',9926.1]]

# %%
df_gdp.columns= ['quarter', 'GDP']

# %%
df_gdp[df_gdp['quarter']>='2007q1']
# Out:
#    quarter      GDP
# 28  2007q1  14233.2
# 29  2007q2  14422.3
# 30  2007q3  14569.7
# 31  2007q4  14685.3
# 32  2008q1  14668.4
# 33  2008q2  14813.0
# 34  2008q3  14843.0
# 35  2008q4  14549.9
# 36  2009q1  14383.9
# 37  2009q2  14340.4
# 38  2009q3  14384.1
# 39  2009q4  14566.5
# 40  2010q1  14681.1
# 41  2010q2  14888.6
# 42  2010q3  15057.7
# 43  2010q4  15230.2
# 44  2011q1  15238.4
# 45  2011q2  15460.9
# 46  2011q3  15587.1
# 47  2011q4  15785.3
# 48  2012q1  15973.9
# 49  2012q2  16121.9
# 50  2012q3  16227.9
# 51  2012q4  16297.3
# 52  2013q1  16475.4
# 53  2013q2  16541.4
# 54  2013q3  16749.3
# 55  2013q4  16999.9
# 56  2014q1  17025.2
# 57  2014q2  17285.6
# 58  2014q3  17569.4
# 59  2014q4  17692.2
# 60  2015q1  17783.6
# 61  2015q2  17998.3
# 62  2015q3  18141.9
# 63  2015q4  18222.8
# 64  2016q1  18281.6
# 65  2016q2  18450.1

# %%
for i in range(4, len(df_gdp)):
        if (df_gdp.loc[i-4, 'GDP'] > df_gdp.loc[i-3, 'GDP']) \
                and (df_gdp.loc[i-3, 'GDP'] > df_gdp.loc[i-2, 'GDP']) \
                and (df_gdp.loc[i-2, 'GDP'] < df_gdp.loc[i-1, 'GDP']) \
                and (df_gdp.loc[i-1, 'GDP'] < df_gdp.loc[i, 'GDP']):
            recession_base_idx = i-4

# %%
recession_base_idx
# Out:
# 35

# %%
df_gdp
# Out:
#    quarter      GDP
# 0   2000q1  10031.0
# 1   2000q2  10278.3
# 2   2000q3  10357.4
# 3   2000q4  10472.3
# 4   2001q1  10508.1
# ..     ...      ...
# 61  2015q2  17998.3
# 62  2015q3  18141.9
# 63  2015q4  18222.8
# 64  2016q1  18281.6
# 65  2016q2  18450.1
#
# [66 rows x 2 columns]

# %%
df_gdp=pd.read_excel('gdplev.xls',skiprows=219)

# %%
df_gdp=df_gdp[['1999q4',9926.1]]

# %%
df_gdp.columns=['quarter', 'GDP']

# %%
for i in range(4,len(df_gdp)):
    if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
    and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
    and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
    and(df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
         recession_base_idx=i-4
result=df_gdp.loc[recession_base_idx,'quarter']
j=recession_base_idx
while True:
    if (df_gdp.loc[j-1,'GDP']>df_gdp.loc[j,'GDP']):
        j-=1
    else:
        result=df_gdp.loc[j,'quarter']
        break
result
# Out:
# '2008q4'

# %%
df_gdp.iloc[2]
# Out:
# quarter     2000q3
# GDP        10357.4
# Name: 2, dtype: object

# %%
def get_recession_start():
    '''Returns the year and quarter of the recession start time as a 
    string value in a format such as 2005q3'''
    import pandas as pd
    df_gdp=pd.read_excel('gdplev.xls',skiprows=219)
    df_gdp=df_gdp[['1999q4',9926.1]]
    df_gdp.columns=['quarter', 'GDP']
    for i in range(4,len(df_gdp)):
        if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
        and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
        and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
        and(df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
             recession_base_idx=i-4
    result=df_gdp.loc[recession_base_idx,'quarter']
    j=recession_base_idx
    while True:
        if (df_gdp.loc[j-1,'GDP']>df_gdp.loc[j,'GDP']):
            j-=1
        else:
            result=df_gdp.loc[j,'quarter']
            break
    
    
    return result
get_recession_start()
# Out:
# '2008q3'

# %%
for i in range(2,len(df_gdp)):
    if (df_gdp.loc[i-2,'GDP'] > df_gdp.loc[i-1,'GDP'])\
    and (df_gdp.loc[i-1,'GDP']>df_gdp.loc[i,'GDP']):
         result1=df_gdp.loc[i-2,'quarter']
result1
# Out:
# '2008q4'

# %%
def get_recession_start():
    '''Returns the year and quarter of the recession start time as a 
    string value in a format such as 2005q3'''
    gdplev = pd.ExcelFile('gdplev.xls')
    gdplev = gdplev.parse("Sheet1", skiprows=219)
    gdplev = gdplev[['1999q4', 9926.1]]
    gdplev.columns = ['Quarter','GDP']
    for i in range(2, len(gdplev)):
        if (gdplev.iloc[i-2][1] > gdplev.iloc[i-1][1]) and (gdplev.iloc[i-1][1] > gdplev.iloc[i][1]):
            return gdplev.iloc[i-2][0]
get_recession_start()
# Out:
# '2008q3'

# %%
df_gdp=pd.read_excel('gdplev.xls',skiprows=219)

# %%
df_gdp=df_gdp[['1999q4',9926.1]]

# %%
df_gdp.columns=['quarter','GDP']

# %%
import pandas as pd
df_gdp=pd.read_excel('gdplev.xls',skiprows=219)
df_gdp=df_gdp[['1999q4',9926.1]]
df_gdp.columns=['quarter','GDP']
for i in range(4,len(df_gdp)):
    if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
    and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
    and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
    and (df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
        result=df_gdp.loc[i,'quarter']

# %%
result
# Out:
# '2009q4'

# %%
def get_recession_end():
    '''Returns the year and quarter of the recession end time as a 
    string value in a format such as 2005q3'''
    import pandas as pd
    df_gdp=pd.read_excel('gdplev.xls',skiprows=219)
    df_gdp=df_gdp[['1999q4',9926.1]]
    df_gdp.columns=['quarter','GDP']
    for i in range(4,len(df_gdp)):
        if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
        and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
        and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
        and (df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
            result=df_gdp.loc[i,'quarter']
        
       
    return result
get_recession_end()
# Out:
# '2009q4'

# %%
df_gdp[df_gdp['quarter']>='2008q1']
# Out:
#    quarter      GDP
# 32  2008q1  14668.4
# 33  2008q2  14813.0
# 34  2008q3  14843.0
# 35  2008q4  14549.9
# 36  2009q1  14383.9
# 37  2009q2  14340.4
# 38  2009q3  14384.1
# 39  2009q4  14566.5
# 40  2010q1  14681.1
# 41  2010q2  14888.6
# 42  2010q3  15057.7
# 43  2010q4  15230.2
# 44  2011q1  15238.4
# 45  2011q2  15460.9
# 46  2011q3  15587.1
# 47  2011q4  15785.3
# 48  2012q1  15973.9
# 49  2012q2  16121.9
# 50  2012q3  16227.9
# 51  2012q4  16297.3
# 52  2013q1  16475.4
# 53  2013q2  16541.4
# 54  2013q3  16749.3
# 55  2013q4  16999.9
# 56  2014q1  17025.2
# 57  2014q2  17285.6
# 58  2014q3  17569.4
# 59  2014q4  17692.2
# 60  2015q1  17783.6
# 61  2015q2  17998.3
# 62  2015q3  18141.9
# 63  2015q4  18222.8
# 64  2016q1  18281.6
# 65  2016q2  18450.1

# %%
import pandas as pd
df_gdp=pd.read_excel('gdplev.xls',skiprows=219)
df_gdp=df_gdp[['1999q4',9926.1]]
df_gdp.columns=['quarter','GDP']
for i in range(4,len(df_gdp)):
    if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
    and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
    and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
    and (df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
                    result=df_gdp.loc[i-2,'quarter']
result
# Out:
# '2009q2'

# %%
    data = []
    state = None
    state_towns = []
    with open('university_towns.txt') as file:
        for line in file:
            thisLine = line[:-1]
            if thisLine[-6:] == '[edit]':
                state = thisLine[:-6]
                continue
            if '(' in line:
                town = thisLine[:thisLine.index('(')-1]
                state_towns.append([state,town])
            else:
                town = thisLine
                state_towns.append([state,town])
            data.append(thisLine)
        df = pd.DataFrame(state_towns,columns = ['State','RegionName'])
df
# Out:
#          State     RegionName
# 0      Alabama         Auburn
# 1      Alabama       Florence
# 2      Alabama   Jacksonville
# 3      Alabama     Livingston
# 4      Alabama     Montevallo
# ..         ...            ...
# 512  Wisconsin    River Falls
# 513  Wisconsin  Stevens Point
# 514  Wisconsin       Waukesha
# 515  Wisconsin     Whitewater
# 516    Wyoming        Laramie
#
# [517 rows x 2 columns]

# %%
with open('university_towns.txt') as file:
     for line in file:
            thisline=line[:-1]
            print(thisline)
# Out:
# Alabama[edit]
# Auburn (Auburn University)[1]
# Florence (University of North Alabama)
# Jacksonville (Jacksonville State University)[2]
# Livingston (University of West Alabama)[2]
# Montevallo (University of Montevallo)[2]
# Troy (Troy University)[2]
# Tuscaloosa (University of Alabama, Stillman College, Shelton State)[3][4]
# Tuskegee (Tuskegee University)[5]
# Alaska[edit]
# Fairbanks (University of Alaska Fairbanks)[2]
# Arizona[edit]
# Flagstaff (Northern Arizona University)[6]
# Tempe (Arizona State University)
# Tucson (University of Arizona)
# Arkansas[edit]
# Arkadelphia (Henderson State University, Ouachita Baptist University)[2]
# Conway (Central Baptist College, Hendrix College, University of Central Arkansas)[2]
# Fayetteville (University of Arkansas)[7]
# Jonesboro (Arkansas State University)[8]
# Magnolia (Southern Arkansas University)[2]
# Monticello (University of Arkansas at Monticello)[2]
# Russellville (Arkansas Tech University)[2]
# ...

# %%
li=[]
li.append(['maher','rahman'])

# %%
pd.DataFrame(li,columns=['name1','name2'])
# Out:
#    name1   name2
# 0  maher  rahman

# %%
data=[]
state=None
state_towns=[]
with open('university_towns.txt') as file:
    for line in file:
        thisline=line[:-1]
        if thisline[-6:]=='[edit]':
            state=thisline[:-6]
            continue
        if '(' in thisline:
            town=thisline[:thisline.index('(')-1]
            state_towns.append([state,town])
        else:
            town=thisline
            state_towns.append([state,town])
        data.append(thisline)
        
df=pd.DataFrame(state_towns,columns=['State','RegionName'])

# %%
df
# Out:
#          State     RegionName
# 0      Alabama         Auburn
# 1      Alabama       Florence
# 2      Alabama   Jacksonville
# 3      Alabama     Livingston
# 4      Alabama     Montevallo
# ..         ...            ...
# 512  Wisconsin    River Falls
# 513  Wisconsin  Stevens Point
# 514  Wisconsin       Waukesha
# 515  Wisconsin     Whitewater
# 516    Wyoming        Laramie
#
# [517 rows x 2 columns]

# %%
df=pd.read_csv('City_Zhvi_AllHomes.csv',header=0)

# %%
df.head()
# Out:
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York        Queens
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07  ...  2015-11  2015-12  \
# 0         1       NaN       NaN       NaN       NaN  ...   573600   576200
# 1         2  155000.0  154600.0  154400.0  154200.0  ...   558200   560800
# 2         3  109700.0  109400.0  109300.0  109300.0  ...   207800   206900
# 3         4   50000.0   49900.0   49600.0   49400.0  ...   122300   121600
# 4         5   87200.0   87700.0   88200.0   88400.0  ...   183800   185300
#
# ...

# %%
df.columns
# Out:
# Index(['RegionID', 'RegionName', 'State', 'Metro', 'CountyName', 'SizeRank',
#        '1996-04', '1996-05', '1996-06', '1996-07',
#        ...
#        '2015-11', '2015-12', '2016-01', '2016-02', '2016-03', '2016-04',
#        '2016-05', '2016-06', '2016-07', '2016-08'],
#       dtype='object', length=251)

# %%
hdata=pd.read_csv('City_Zhvi_AllHomes.csv')

# %%
hdata=hdata.drop(hdata.columns[[0]+list(range(3,51))],axis=1)

# %%
hdata2=pd.DataFrame(hdata[['State','RegionName']])

# %%
hdata2
# Out:
#       State           RegionName
# 0        NY             New York
# 1        CA          Los Angeles
# 2        IL              Chicago
# 3        PA         Philadelphia
# 4        AZ              Phoenix
# ...     ...                  ...
# 10725    WI  Town of Wrightstown
# 10726    NY               Urbana
# 10727    WI          New Denmark
# 10728    CA               Angels
# 10729    WI              Holland
#
# [10730 rows x 2 columns]

# %%
hdata
# Out:
#                 RegionName State   2000-01   2000-02   2000-03   2000-04  \
# 0                 New York    NY       NaN       NaN       NaN       NaN
# 1              Los Angeles    CA  204400.0  207000.0  209800.0  212300.0
# 2                  Chicago    IL  136800.0  138300.0  140100.0  141900.0
# 3             Philadelphia    PA   52700.0   53100.0   53200.0   53400.0
# 4                  Phoenix    AZ  111000.0  111700.0  112800.0  113700.0
# ...                    ...   ...       ...       ...       ...       ...
# 10725  Town of Wrightstown    WI  101100.0  101500.0  102700.0  103700.0
# 10726               Urbana    NY   77600.0   79400.0   80600.0   80200.0
# 10727          New Denmark    WI  113900.0  114000.0  115800.0  117600.0
# 10728               Angels    CA  148000.0  151200.0  153800.0  155600.0
# 10729              Holland    WI  150800.0  151000.0  151300.0  151000.0
#
#         2000-05   2000-06   2000-07   2000-08  ...  2015-11  2015-12  2016-01  \
# ...

# %%
hdata=pd.read_csv('City_Zhvi_AllHomes.csv',header=0)

# %%
hdata=hdata.drop(hdata.columns[[0]+list(range(3,51))],axis=1)
hdata2=hdata[['RegionName','State']]
hdata2
# Out:
#                 RegionName State
# 0                 New York    NY
# 1              Los Angeles    CA
# 2                  Chicago    IL
# 3             Philadelphia    PA
# 4                  Phoenix    AZ
# ...                    ...   ...
# 10725  Town of Wrightstown    WI
# 10726               Urbana    NY
# 10727          New Denmark    WI
# 10728               Angels    CA
# 10729              Holland    WI
#
# [10730 rows x 2 columns]

# %%
states = {'OH': 'Ohio', 'KY': 'Kentucky', 'AS': 'American Samoa', 'NV': 'Nevada', 'WY': 'Wyoming', 'NA': 'National', 'AL': 'Alabama', 'MD': 'Maryland', 'AK': 'Alaska', 'UT': 'Utah', 'OR': 'Oregon', 'MT': 'Montana', 'IL': 'Illinois', 'TN': 'Tennessee', 'DC': 'District of Columbia', 'VT': 'Vermont', 'ID': 'Idaho', 'AR': 'Arkansas', 'ME': 'Maine', 'WA': 'Washington', 'HI': 'Hawaii', 'WI': 'Wisconsin', 'MI': 'Michigan', 'IN': 'Indiana', 'NJ': 'New Jersey', 'AZ': 'Arizona', 'GU': 'Guam', 'MS': 'Mississippi', 'PR': 'Puerto Rico', 'NC': 'North Carolina', 'TX': 'Texas', 'SD': 'South Dakota', 'MP': 'Northern Mariana Islands', 'IA': 'Iowa', 'MO': 'Missouri', 'CT': 'Connecticut', 'WV': 'West Virginia', 'SC': 'South Carolina', 'LA': 'Louisiana', 'KS': 'Kansas', 'NY': 'New York', 'NE': 'Nebraska', 'OK': 'Oklahoma', 'FL': 'Florida', 'CA': 'California', 'CO': 'Colorado', 'PA': 'Pennsylvania', 'DE': 'Delaware', 'NM': 'New Mexico', 'RI': 'Rhode Island', 'MN': 'Minnesota', 'VI': 'Virgin Islands', 'NH': 'New Hampshire', 'MA': 'Massachusetts', 'GA': 'Georgia', 'ND': 'North Dakota', 'VA': 'Virginia'}
for year in range(2000,2016):
    hdata2[str(year)+'q1']=hdata[[str(year)+'-01',str(year)+'-02',str(year)+'-03']].mean(axis=1)
    hdata2[str(year)+'q2']=hdata[[str(year)+'-04',str(year)+'-05',str(year)+'-06']].mean(axis=1)
    hdata2[str(year)+'q3']=hdata[[str(year)+'-07',str(year)+'-08',str(year)+'-09']].mean(axis=1)
    hdata2[str(year)+'q4']=hdata[[str(year)+'-10',str(year)+'-11',str(year)+'-12']].mean(axis=1)
hdata2['State']=hdata2['State'].map(states)
hdata2=hdata2.set_index(['State','RegionName'])
hdata2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
import pandas as pd
import numpy as np
hdata=pd.read_csv('City_Zhvi_AllHomes.csv',header=0)
hdata=hdata.drop(hdata.columns[[0]+list(range(3,51))],axis=1)
hdata2=hdata[['RegionName','State']]
states = {'OH': 'Ohio', 'KY': 'Kentucky', 'AS': 'American Samoa', 'NV': 'Nevada', 'WY': 'Wyoming', 'NA': 'National', 'AL': 'Alabama', 'MD': 'Maryland', 'AK': 'Alaska', 'UT': 'Utah', 'OR': 'Oregon', 'MT': 'Montana', 'IL': 'Illinois', 'TN': 'Tennessee', 'DC': 'District of Columbia', 'VT': 'Vermont', 'ID': 'Idaho', 'AR': 'Arkansas', 'ME': 'Maine', 'WA': 'Washington', 'HI': 'Hawaii', 'WI': 'Wisconsin', 'MI': 'Michigan', 'IN': 'Indiana', 'NJ': 'New Jersey', 'AZ': 'Arizona', 'GU': 'Guam', 'MS': 'Mississippi', 'PR': 'Puerto Rico', 'NC': 'North Carolina', 'TX': 'Texas', 'SD': 'South Dakota', 'MP': 'Northern Mariana Islands', 'IA': 'Iowa', 'MO': 'Missouri', 'CT': 'Connecticut', 'WV': 'West Virginia', 'SC': 'South Carolina', 'LA': 'Louisiana', 'KS': 'Kansas', 'NY': 'New York', 'NE': 'Nebraska', 'OK': 'Oklahoma', 'FL': 'Florida', 'CA': 'California', 'CO': 'Colorado', 'PA': 'Pennsylvania', 'DE': 'Delaware', 'NM': 'New Mexico', 'RI': 'Rhode Island', 'MN': 'Minnesota', 'VI': 'Virgin Islands', 'NH': 'New Hampshire', 'MA': 'Massachusetts', 'GA': 'Georgia', 'ND': 'North Dakota', 'VA': 'Virginia'}
for year in range(2000,2016):
    hdata2[str(year)+'q1']=hdata[[str(year)+'-01',str(year)+'-02',str(year)+'-03']].mean(axis=1)
    hdata2[str(year)+'q2']=hdata[[str(year)+'-04',str(year)+'-05',str(year)+'-06']].mean(axis=1)
    hdata2[str(year)+'q3']=hdata[[str(year)+'-07',str(year)+'-08',str(year)+'-09']].mean(axis=1)
    hdata2[str(year)+'q4']=hdata[[str(year)+'-10',str(year)+'-11',str(year)+'-12']].mean(axis=1)

year=2016
hdata2[str(year)+'q1']=hdata[[str(year)+'-01',str(year)+'-02',str(year)+'-03']].mean(axis=1)
hdata2[str(year)+'q2']=hdata[[str(year)+'-04',str(year)+'-05',str(year)+'-06']].mean(axis=1)
hdata2[str(year)+'q3']=hdata[[str(year)+'-07',str(year)+'-08']].mean(axis=1)
hdata2['State']=hdata2['State'].map(states)
hdata2=hdata2.set_index(['State','RegionName'])
hdata2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
hdata2
# Out:
#                                          2000q1         2000q2         2000q3  \
# State        RegionName
# New York     New York                       NaN            NaN            NaN
# California   Los Angeles          207066.666667  214466.666667  220966.666667
# Illinois     Chicago              138400.000000  143633.333333  147866.666667
# Pennsylvania Philadelphia          53000.000000   53633.333333   54133.333333
# Arizona      Phoenix              111833.333333  114366.666667  116000.000000
# ...                                         ...            ...            ...
# Wisconsin    Town of Wrightstown  101766.666667  105400.000000  111366.666667
# New York     Urbana                79200.000000   81666.666667   91700.000000
# Wisconsin    New Denmark          114566.666667  119266.666667  126066.666667
# California   Angels               151000.000000  155900.000000  158100.000000
# Wisconsin    Holland              151033.333333  150500.000000  153233.333333
#
# ...

# %%
df_result
# Out:
#          State      RegionName
# 0      Alabama         Auburn
# 1      Alabama       Florence
# 2      Alabama   Jacksonville
# 3      Alabama     Livingston
# 4      Alabama     Montevallo
# ..         ...             ...
# 512  Wisconsin    River Falls
# 513  Wisconsin  Stevens Point
# 514  Wisconsin       Waukesha
# 515  Wisconsin     Whitewater
# 516    Wyoming        Laramie
#
# [517 rows x 2 columns]

# %%
def get_list_of_university_towns():
    '''Returns a DataFrame of towns and the states they are in from the 
    university_towns.txt list. The format of the DataFrame should be:
    DataFrame( [ ["Michigan", "Ann Arbor"], ["Michigan", "Yipsilanti"] ], 
    columns=["State", "RegionName"]  )
    
    The following cleaning needs to be done:

    1. For "State", removing characters from "[" to the end.
    2. For "RegionName", when applicable, removing every character from " (" to the end.
    3. Depending on how you read the data, you may need to remove newline character '\n'. '''
    import pandas as pd
    data=[]
    state=None
    state_towns=[]
    with open('university_towns.txt') as file:
        for line in file:
            thisline=line[:-1]
            if thisline[-6:]=='[edit]':
                state=thisline[:-6]
                continue
            if '(' in thisline:
                town=thisline[:thisline.index('(')-1]
                state_towns.append([state,town])
            else:
                town=thisline
                state_towns.append([state,town])
            data.append(thisline)
        
    df=pd.DataFrame(state_towns,columns=['State','RegionName'])
    return df
get_list_of_university_towns()
# Out:
#          State     RegionName
# 0      Alabama         Auburn
# 1      Alabama       Florence
# 2      Alabama   Jacksonville
# 3      Alabama     Livingston
# 4      Alabama     Montevallo
# ..         ...            ...
# 512  Wisconsin    River Falls
# 513  Wisconsin  Stevens Point
# 514  Wisconsin       Waukesha
# 515  Wisconsin     Whitewater
# 516    Wyoming        Laramie
#
# [517 rows x 2 columns]

# %%
def get_recession_start():
    '''Returns the year and quarter of the recession start time as a 
    string value in a format such as 2005q3'''
    import pandas as pd
    df_gdp=pd.read_excel('gdplev.xls',skiprows=219)
    df_gdp=df_gdp[['1999q4',9926.1]]
    df_gdp.columns=['quarter', 'GDP']
    for i in range(4,len(df_gdp)):
        if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
        and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
        and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
        and(df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
             recession_base_idx=i-4
    result=df_gdp.loc[recession_base_idx,'quarter']
    j=recession_base_idx
    while True:
        if (df_gdp.loc[j-1,'GDP']>df_gdp.loc[j,'GDP']):
            j-=1
        else:
            result=df_gdp.loc[j,'quarter']
            break
    
    
    return result
get_recession_start()
# Out:
# '2008q3'

# %%
def get_recession_end():
    '''Returns the year and quarter of the recession end time as a 
    string value in a format such as 2005q3'''
    import pandas as pd
    df_gdp=pd.read_excel('gdplev.xls',skiprows=219)
    df_gdp=df_gdp[['1999q4',9926.1]]
    df_gdp.columns=['quarter','GDP']
    for i in range(4,len(df_gdp)):
        if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
        and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
        and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
        and (df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
            result=df_gdp.loc[i,'quarter']
        
       
    return result
get_recession_end()
# Out:
# '2009q4'

# %%
def get_recession_bottom():
    '''Returns the year and quarter of the recession bottom time as a 
    string value in a format such as 2005q3'''
    import pandas as pd
    df_gdp=pd.read_excel('gdplev.xls',skiprows=219)
    df_gdp=df_gdp[['1999q4',9926.1]]
    df_gdp.columns=['quarter','GDP']
    for i in range(4,len(df_gdp)):
        if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
        and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
        and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
        and (df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
                    result=df_gdp.loc[i-2,'quarter']
    
    return result
get_recession_bottom()
# Out:
# '2009q2'

# %%
def convert_housing_data_to_quarters():
    '''Converts the housing data to quarters and returns it as mean 
    values in a dataframe. This dataframe should be a dataframe with
    columns for 2000q1 through 2016q3, and should have a multi-index
    in the shape of ["State","RegionName"].
    
    Note: Quarters are defined in the assignment description, they are
    not arbitrary three month periods.
    
    The resulting dataframe should have 67 columns, and 10,730 rows.
    '''
    import pandas as pd
    import numpy as np
    hdata=pd.read_csv('City_Zhvi_AllHomes.csv',header=0)
    hdata=hdata.drop(hdata.columns[[0]+list(range(3,51))],axis=1)
    hdata2=hdata[['RegionName','State']]
    states = {'OH': 'Ohio', 'KY': 'Kentucky', 'AS': 'American Samoa', 'NV': 'Nevada', 'WY': 'Wyoming', 'NA': 'National', 'AL': 'Alabama', 'MD': 'Maryland', 'AK': 'Alaska', 'UT': 'Utah', 'OR': 'Oregon', 'MT': 'Montana', 'IL': 'Illinois', 'TN': 'Tennessee', 'DC': 'District of Columbia', 'VT': 'Vermont', 'ID': 'Idaho', 'AR': 'Arkansas', 'ME': 'Maine', 'WA': 'Washington', 'HI': 'Hawaii', 'WI': 'Wisconsin', 'MI': 'Michigan', 'IN': 'Indiana', 'NJ': 'New Jersey', 'AZ': 'Arizona', 'GU': 'Guam', 'MS': 'Mississippi', 'PR': 'Puerto Rico', 'NC': 'North Carolina', 'TX': 'Texas', 'SD': 'South Dakota', 'MP': 'Northern Mariana Islands', 'IA': 'Iowa', 'MO': 'Missouri', 'CT': 'Connecticut', 'WV': 'West Virginia', 'SC': 'South Carolina', 'LA': 'Louisiana', 'KS': 'Kansas', 'NY': 'New York', 'NE': 'Nebraska', 'OK': 'Oklahoma', 'FL': 'Florida', 'CA': 'California', 'CO': 'Colorado', 'PA': 'Pennsylvania', 'DE': 'Delaware', 'NM': 'New Mexico', 'RI': 'Rhode Island', 'MN': 'Minnesota', 'VI': 'Virgin Islands', 'NH': 'New Hampshire', 'MA': 'Massachusetts', 'GA': 'Georgia', 'ND': 'North Dakota', 'VA': 'Virginia'}
    for year in range(2000,2016):
        hdata2[str(year)+'q1']=hdata[[str(year)+'-01',str(year)+'-02',str(year)+'-03']].mean(axis=1)
        hdata2[str(year)+'q2']=hdata[[str(year)+'-04',str(year)+'-05',str(year)+'-06']].mean(axis=1)
        hdata2[str(year)+'q3']=hdata[[str(year)+'-07',str(year)+'-08',str(year)+'-09']].mean(axis=1)
        hdata2[str(year)+'q4']=hdata[[str(year)+'-10',str(year)+'-11',str(year)+'-12']].mean(axis=1)

    year=2016
    hdata2[str(year)+'q1']=hdata[[str(year)+'-01',str(year)+'-02',str(year)+'-03']].mean(axis=1)
    hdata2[str(year)+'q2']=hdata[[str(year)+'-04',str(year)+'-05',str(year)+'-06']].mean(axis=1)
    hdata2[str(year)+'q3']=hdata[[str(year)+'-07',str(year)+'-08']].mean(axis=1)
    hdata2['State']=hdata2['State'].map(states)
    hdata2=hdata2.set_index(['State','RegionName'])
    
    return hdata2
convert_housing_data_to_quarters()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
unitowns=get_list_of_university_towns()
bottom=get_recession_bottom()
start=get_recession_start()
hdata=convert_housing_data_to_quarters()
bstart=hdata.columns[hdata.columns.get_loc(start)-1]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
hdata['ratio']=hdata[bottom]-hdata[bstart]
hdata=hdata[[bottom,bstart,'ratio']]
hdata=hdata.reset_index()
unitowns_hdata=pd.merge(hdata,unitowns,how='inner',on=['State','RegionName'])
unitowns_hdata['uni']=True
hdata2=pd.merge(hdata,unitowns_hdata,how='outer',on=['State','RegionName',bottom,bstart,'ratio'])
hdata2['uni']=hdata2['uni'].fillna(False)

# %%
ut=hdata2[hdata2['uni']==True]
nut=hdata2[hdata2['uni']==False]

# %%
nut
# Out:
#               State           RegionName         2009q2         2008q2  \
# 0          New York             New York  465833.333333  503933.333333
# 1        California          Los Angeles  413900.000000  502266.666667
# 2          Illinois              Chicago  219700.000000  237900.000000
# 3      Pennsylvania         Philadelphia  116166.666667  118133.333333
# 4           Arizona              Phoenix  168233.333333  205266.666667
# ...             ...                  ...            ...            ...
# 10725     Wisconsin  Town of Wrightstown  144833.333333  149966.666667
# 10726      New York               Urbana  123433.333333  115900.000000
# 10727     Wisconsin          New Denmark  178833.333333  173466.666667
# 10728    California               Angels  282866.666667  328033.333333
# 10729     Wisconsin              Holland  198200.000000  225100.000000
#
#               ratio    uni
# 0     -38100.000000  False
# 1     -88366.666667  False
# 2     -18200.000000  False
# ...

# %%
p=0.04
difference=True if p<0.05 else False

# %%
difference
# Out:
# True

# %%
ut
# Out:
#             State       RegionName         2009q2         2008q2  \
# 5          Nevada        Las Vegas  164333.333333  232300.000000
# 6      California        San Diego  389500.000000  441400.000000
# 7           Texas           Dallas  105100.000000  115366.666667
# 11          Texas           Austin  204000.000000  213733.333333
# 13           Ohio         Columbus  109766.666667  113500.000000
# ...           ...              ...            ...            ...
# 9655     Michigan  Berrien Springs  105733.333333  114833.333333
# 9851      Indiana     Oakland City   50866.666667   61666.666667
# 9898         Ohio          Oberlin  125100.000000  131133.333333
# 10207       Texas            Keene   95900.000000   97600.000000
# 10256    New York          Clinton  163566.666667  168333.333333
#
#               ratio   uni
# 5     -67966.666667  True
# 6     -51900.000000  True
# 7     -10266.666667  True
# 11     -9733.333333  True
# 13     -3733.333333  True
# ...

# %%
nut
# Out:
#               State           RegionName         2009q2         2008q2  \
# 0          New York             New York  465833.333333  503933.333333
# 1        California          Los Angeles  413900.000000  502266.666667
# 2          Illinois              Chicago  219700.000000  237900.000000
# 3      Pennsylvania         Philadelphia  116166.666667  118133.333333
# 4           Arizona              Phoenix  168233.333333  205266.666667
# ...             ...                  ...            ...            ...
# 10725     Wisconsin  Town of Wrightstown  144833.333333  149966.666667
# 10726      New York               Urbana  123433.333333  115900.000000
# 10727     Wisconsin          New Denmark  178833.333333  173466.666667
# 10728    California               Angels  282866.666667  328033.333333
# 10729     Wisconsin              Holland  198200.000000  225100.000000
#
#               ratio    uni
# 0     -38100.000000  False
# 1     -88366.666667  False
# 2     -18200.000000  False
# ...

# %%
from scipy.stats import ttest_ind
unitowns=get_list_of_university_towns()
start=get_recession_start()
bottom=get_recession_bottom()
hdata=convert_housing_data_to_quarters()
bstart=hdata.columns[hdata.columns.get_loc(start)-1]
hdata['ratio']=hdata[bottom]-hdata[bstart]
hdata=hdata[[bottom,bstart,'ratio']]
hdata=hdata.reset_index()
unitowns_hdata=pd.merge(hdata,unitowns,how='inner',on=['State','RegionName'])
unitowns_hdata['uni']=True
hdata2=pd.merge(hdata,unitowns_hdata,how='outer',on=['State','RegionName',bottom,bstart,'ratio'])
hdata2['uni']=hdata2['uni'].fillna(False)
ut=hdata2[hdata2['uni']==True]
nut=hdata2[hdata2['uni']==False]
t,p=ttest_ind(ut['ratio'].dropna(),nut['ratio'].dropna())
difference=True if p<0.01 else False
better='non_university_towns' if ut['ratio'].mean()<nut['ratio'].mean() else 'university_towns'
difference
better
p
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
state=None
state_towns=[]
with open('university_towns.txt') as fp:
    for line in fp:
        thisline=line[:-1]
        if thisline[-6:]=='[edit]':
            state=thisline[:-6]
            continue
        if '(' in thisline:
            town=thisline[:thisline.index('(')-1]
            state_towns.append([state,town])
        else:
            town=thisline
            state_towns.append([state,town])
df=pd.DataFrame(state_towns,columns=['State','RegionName'])

# %%
df
# Out:
#          State     RegionName
# 0      Alabama         Auburn
# 1      Alabama       Florence
# 2      Alabama   Jacksonville
# 3      Alabama     Livingston
# 4      Alabama     Montevallo
# ..         ...            ...
# 512  Wisconsin    River Falls
# 513  Wisconsin  Stevens Point
# 514  Wisconsin       Waukesha
# 515  Wisconsin     Whitewater
# 516    Wyoming        Laramie
#
# [517 rows x 2 columns]

# %%
df_gdp=pd.read_excel('gdplev.xls',skiprows=219)
df_gdp=df_gdp[['1999q4',9926.1]]
df_gdp.columns=['quarter','GDP']
for i in range(4,len(df_gdp)):
     if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
     and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
     and (df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
     and(df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
                        recession_idx=i-4
j=recession_idx
while True:
    if df_gdp.loc[j-1,'GDP']>df_gdp.loc[j,'GDP']:
        j-=1
    else:
        result=df_gdp.loc[j,'quarter']
        break
result
# Out:
# '2008q3'

# %%
df_gdp[df_gdp['quarter']>='2007q4']
# Out:
#    quarter      GDP
# 31  2007q4  14685.3
# 32  2008q1  14668.4
# 33  2008q2  14813.0
# 34  2008q3  14843.0
# 35  2008q4  14549.9
# 36  2009q1  14383.9
# 37  2009q2  14340.4
# 38  2009q3  14384.1
# 39  2009q4  14566.5
# 40  2010q1  14681.1
# 41  2010q2  14888.6
# 42  2010q3  15057.7
# 43  2010q4  15230.2
# 44  2011q1  15238.4
# 45  2011q2  15460.9
# 46  2011q3  15587.1
# 47  2011q4  15785.3
# 48  2012q1  15973.9
# 49  2012q2  16121.9
# 50  2012q3  16227.9
# 51  2012q4  16297.3
# 52  2013q1  16475.4
# 53  2013q2  16541.4
# 54  2013q3  16749.3
# 55  2013q4  16999.9
# 56  2014q1  17025.2
# 57  2014q2  17285.6
# 58  2014q3  17569.4
# 59  2014q4  17692.2
# 60  2015q1  17783.6
# 61  2015q2  17998.3
# 62  2015q3  18141.9
# 63  2015q4  18222.8
# 64  2016q1  18281.6
# 65  2016q2  18450.1

# %%
for i in range(4,len(df_gdp)):
    if (df_gdp.loc[i-4,'GDP']>df_gdp.loc[i-3,'GDP'])\
    and (df_gdp.loc[i-3,'GDP']>df_gdp.loc[i-2,'GDP'])\
    and(df_gdp.loc[i-2,'GDP']<df_gdp.loc[i-1,'GDP'])\
    and (df_gdp.loc[i-1,'GDP']<df_gdp.loc[i,'GDP']):
        recession_end=df_gdp.loc[i,'quarter']
        recession_bottom=df_gdp.loc[i-2,'quarter']
recession_end
recession_bottom
# Out:
# '2009q2'

# %%
hdata=pd.read_csv('City_Zhvi_AllHomes.csv',header=0)

# %%
hdata=hdata.drop(hdata.columns[[0]+list(range(3,51))],axis=1)
hdata2=pd.DataFrame(hdata[['State','RegionName']])
hdata2['State']=hdata2['State'].map(states)
for year in range(2000,2016):
    hdata2[str(year)+'q1']=hdata[[str(year)+'-01',str(year)+'-02',str(year)+'-03']].mean(axis=1)
    hdata2[str(year)+'q2']=hdata[[str(year)+'-04',str(year)+'-05',str(year)+'-06']].mean(axis=1)
    hdata2[str(year)+'q3']=hdata[[str(year)+'-07',str(year)+'-08',str(year)+'-09']].mean(axis=1)
    hdata2[str(year)+'q4']=hdata[[str(year)+'-10',str(year)+'-11',str(year)+'-12']].mean(axis=1)
year=2016
hdata2[str(year)+'q1']=hdata[[str(year)+'-01',str(year)+'-02',str(year)+'-03']].mean(axis=1)
hdata2[str(year)+'q2']=hdata[[str(year)+'-04',str(year)+'-05',str(year)+'-06']].mean(axis=1)
hdata2[str(year)+'q3']=hdata[[str(year)+'-07',str(year)+'-08']].mean(axis=1)

hdata2
# Out:
#               State           RegionName         2000q1         2000q2  \
# 0          New York             New York            NaN            NaN
# 1        California          Los Angeles  207066.666667  214466.666667
# 2          Illinois              Chicago  138400.000000  143633.333333
# 3      Pennsylvania         Philadelphia   53000.000000   53633.333333
# 4           Arizona              Phoenix  111833.333333  114366.666667
# ...             ...                  ...            ...            ...
# 10725     Wisconsin  Town of Wrightstown  101766.666667  105400.000000
# 10726      New York               Urbana   79200.000000   81666.666667
# 10727     Wisconsin          New Denmark  114566.666667  119266.666667
# 10728    California               Angels  151000.000000  155900.000000
# 10729     Wisconsin              Holland  151033.333333  150500.000000
#
#               2000q3         2000q4         2001q1         2001q2  \
# ...

# %%
unitowns=get_list_of_university_towns()
bottom=get_recession_bottom()
start=get_recession_start()
hdata=convert_housing_data_to_quarters()
bstart=hdata.columns[hdata.columns.get_loc(start)-1]
hdata['ratio']=hdata[bottom]-hdata[bstart]
hdata=hdata[[bottom,bstart,'ratio']]
hdata=hdata.reset_index()
unitowns_hdata=pd.merge(hdata,unitowns,how='inner',on=['State','RegionName'])
unitowns_hdata['uni']=True
hdata2=pd.merge(hdata,unitowns_hdata,how='outer',on=['State','RegionName',bottom,bstart,'ratio'])
hdata2['uni']=hdata2['uni'].fillna(False)
ut=hdata2[hdata2['uni']==True]
nut=hdata2[hdata2['uni']==False]
t,p=ttest_ind(ut['ratio'].dropna(),nut['ratio'].dropna())
difference=True if p<0.01 else False
better='uni_towns' if ut['ratio'].mean()>nut['ratio'].mean() else 'non_uni_towns'
p
difference
better
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
