# %%
import pandas as pd

# %%
df=pd.DataFrame([{'Name':'Chris','Item Purchased':'Sponge','Cost':22.50},
                 {'Name':'Maher','Item Purchased':'Bread','Cost':30},
                 {'Name':'Sunny','Item Purchased':'Cheese','Cost':20}],
               index=['Store1','Store1','Store2'])
df
# Out:
#          Name Item Purchased  Cost
# Store1  Chris         Sponge  22.5
# Store1  Maher          Bread  30.0
# Store2  Sunny         Cheese  20.0

# %%
df['Date']=['January 15','February 15','March 30']

# %%
df
# Out:
#          Name Item Purchased  Cost         Date
# Store1  Chris         Sponge  22.5   January 15
# Store1  Maher          Bread  30.0  February 15
# Store2  Sunny         Cheese  20.0     March 30

# %%
df['Delivered']=True

# %%
df
# Out:
#          Name Item Purchased  Cost         Date  Delivered
# Store1  Chris         Sponge  22.5   January 15       True
# Store1  Maher          Bread  30.0  February 15       True
# Store2  Sunny         Cheese  20.0     March 30       True

# %%
df['Feedback']=['Positive',None,'Negative']

# %%
df
# Out:
#          Name Item Purchased  Cost         Date  Delivered  Feedback
# Store1  Chris         Sponge  22.5   January 15       True  Positive
# Store1  Maher          Bread  30.0  February 15       True      None
# Store2  Sunny         Cheese  20.0     March 30       True  Negative

# %%
df.index
# Out:
# Index(['Store1', 'Store1', 'Store2'], dtype='object')

# %%
pd.Series({'Name':'Maher','Location':'Chittagong'})
# Out:
# Name             Maher
# Location    Chittagong
# dtype: object

# %%
df
# Out:
#          Name Item Purchased  Cost         Date  Delivered  Feedback
# Store1  Chris         Sponge  22.5   January 15       True  Positive
# Store1  Maher          Bread  30.0  February 15       True      None
# Store2  Sunny         Cheese  20.0     March 30       True  Negative

# %%
adf=df.reset_index()

# %%
adf
# Out:
#     index   Name Item Purchased  Cost         Date  Delivered  Feedback
# 0  Store1  Chris         Sponge  22.5   January 15       True  Positive
# 1  Store1  Maher          Bread  30.0  February 15       True      None
# 2  Store2  Sunny         Cheese  20.0     March 30       True  Negative

# %%
adf['Date']=pd.Series({0:'December 1',1:'February 20'})

# %%
adf
# Out:
#     index   Name Item Purchased  Cost         Date  Delivered  Feedback
# 0  Store1  Chris         Sponge  22.5   December 1       True  Positive
# 1  Store1  Maher          Bread  30.0  February 20       True      None
# 2  Store2  Sunny         Cheese  20.0          NaN       True  Negative

# %%
staff_df=pd.DataFrame([{'Name':'Kelly','Role':'Director of HR'},
                       {'Name':'Sally','Role':'Course liason' },
                       {'Name':'James','Role':'Garder'}])
staff_df
# Out:
#     Name            Role
# 0  Kelly  Director of HR
# 1  Sally   Course liason
# 2  James          Garder

# %%
staff_df=staff_df.set_index('Name')

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally   Course liason
# James          Garder

# %%
student_df=pd.DataFrame([{'Name':'James','School':'Business'},
                         {'Name':'Mike','School':'Law'},
                         {'Name':'Sally','School':'Engineering'}])
student_df
# Out:
#     Name       School
# 0  James     Business
# 1   Mike          Law
# 2  Sally  Engineering

# %%
student_df=student_df.set_index('Name')

# %%
student_df
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df,student_df,how='outer',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# James          Garder     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally   Course liason  Engineering

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally   Course liason
# James          Garder

# %%
student_df
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df,student_df,how='inner',left_index=True,right_index=True)
# Out:
#                 Role       School
# Name
# Sally  Course liason  Engineering
# James         Garder     Business

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally   Course liason
# James          Garder

# %%
student_df
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df,student_df,how='left',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally   Course liason  Engineering
# James          Garder     Business

# %%
pd.merge(staff_df,student_df,how='right',left_index=True,right_index=True)
# Out:
#                 Role       School
# Name
# James         Garder     Business
# Mike             NaN          Law
# Sally  Course liason  Engineering

# %%
staff_df=staff_df.reset_index()

# %%
student_df=student_df.reset_index()

# %%
staff_df
# Out:
#     Name            Role
# 0  Kelly  Director of HR
# 1  Sally   Course liason
# 2  James          Garder

# %%
student_df
# Out:
#     Name       School
# 0  James     Business
# 1   Mike          Law
# 2  Sally  Engineering

# %%
pd.merge(staff_df,student_df,how='left',left_on='Name',right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          NaN
# 1  Sally   Course liason  Engineering
# 2  James          Garder     Business

# %%
staff_df=pd.DataFrame([{'Name':'Kelly','Role':'Director of HR','Location':'State Street'},
                       {'Name':'Sally','Role':'Course Liasion','Location':'Washington Avenue'},
                       {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])

# %%
staff_df
# Out:
#     Name            Role           Location
# 0  Kelly  Director of HR       State Street
# 1  Sally  Course Liasion  Washington Avenue
# 2  James          Grader  Washington Avenue

# %%
student_df=pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])

# %%
student_df
# Out:
#     Name       School              Location
# 0  James     Business  1024 Billiard Avenue
# 1   Mike          Law  Fraternity House #22
# 2  Sally  Engineering   512 Wilson Crescent

# %%
pd.merge(staff_df,student_df,how='left',left_on='Name',right_on='Name')
# Out:
#     Name            Role         Location_x       School            Location_y
# 0  Kelly  Director of HR       State Street          NaN                   NaN
# 1  Sally  Course Liasion  Washington Avenue  Engineering   512 Wilson Crescent
# 2  James          Grader  Washington Avenue     Business  1024 Billiard Avenue

# %%
product_df=pd.DataFrame([{'Product Id':4109,'Price':5.0,'Product':'Sushi Roll'},
                         {'Product Id':1412,'Price':0.5,'Product':'Egg'},
                         {'Product Id':8931,'Price':1.5,'Product':'Bagei'}])

# %%
product_df=product_df.set_index('Product Id')

# %%
invoices_df=pd.DataFrame([{'Customer':'Ali','Product Id':4109,'Quantity':1},
                          {'Customer':'Eric','Product Id':1412,'Quantity':12},
                          {'Customer':'Ande','Product Id':8931,'Quantity':6},
                          {'Customer':'Sam','Product Id':4109,'Quantity':2}])

# %%
invoices_df=invoices_df.set_index('Product Id')

# %%
product_df
# Out:
#             Price     Product
# Product Id
# 4109          5.0  Sushi Roll
# 1412          0.5         Egg
# 8931          1.5       Bagei

# %%
invoices_df
# Out:
#            Customer  Quantity
# Product Id
# 4109            Ali         1
# 1412           Eric        12
# 8931           Ande         6
# 4109            Sam         2

# %%
df=pd.merge(product_df,invoices_df,how='inner',left_index=True,right_index=True)

# %%
df.loc[1412]['Price']*df.loc[1412]['Quantity']
# Out:
# 6.0

# %%
df
# Out:
#             Price     Product Customer  Quantity
# Product Id
# 1412          0.5         Egg     Eric        12
# 4109          5.0  Sushi Roll      Ali         1
# 4109          5.0  Sushi Roll      Sam         2
# 8931          1.5       Bagei     Ande         6

# %%
product_df1=pd.DataFrame([{'Product Id':4109,'Price':5.0,'Product':'Sushi Roll'},
                         {'Product Id':1412,'Price':0.5,'Product':'Egg'},
                         {'Product Id':8931,'Price':1.5,'Product':'Bagei'}])

# %%
invoices_df1=pd.DataFrame([{'Customer':'Ali','Product Id':4109,'Quantity':1},
                          {'Customer':'Eric','Product Id':1412,'Quantity':12},
                          {'Customer':'Ande','Product Id':8931,'Quantity':6},
                          {'Customer':'Sam','Product Id':4109,'Quantity':2}])

# %%
product_df1.set_index('Product Id')
# Out:
#             Price     Product
# Product Id
# 4109          5.0  Sushi Roll
# 1412          0.5         Egg
# 8931          1.5       Bagei

# %%
invoices_df1
# Out:
#   Customer  Product Id  Quantity
# 0      Ali        4109         1
# 1     Eric        1412        12
# 2     Ande        8931         6
# 3      Sam        4109         2

# %%
pd.merge(product_df1,invoices_df1,left_index=True,right_on='Product Id')
# Out:
# Empty DataFrame
# Columns: [Product Id, Product Id_x, Price, Product, Customer, Product Id_y, Quantity]
# Index: []

# %%
product_df1=product_df1.set_index('Product Id')

# %%
product_df1
# Out:
#             Price     Product
# Product Id
# 4109          5.0  Sushi Roll
# 1412          0.5         Egg
# 8931          1.5       Bagei

# %%
pd.merge(product_df1,invoices_df1,left_index=True,right_on='Product Id')
# Out:
#    Price     Product Customer  Product Id  Quantity
# 0    5.0  Sushi Roll      Ali        4109         1
# 3    5.0  Sushi Roll      Sam        4109         2
# 1    0.5         Egg     Eric        1412        12
# 2    1.5       Bagei     Ande        8931         6

# %%
pd.merge(product_df,invoices_df,how='inner',left_index=True,right_index=True)
# Out:
#             Price     Product Customer  Quantity
# Product Id
# 1412          0.5         Egg     Eric        12
# 4109          5.0  Sushi Roll      Ali         1
# 4109          5.0  Sushi Roll      Sam         2
# 8931          1.5       Bagei     Ande         6

# %%
product_df.reset_index()
# Out:
#    Product Id  Price     Product
# 0        4109    5.0  Sushi Roll
# 1        1412    0.5         Egg
# 2        8931    1.5       Bagei

# %%
pd.merge(product_df,invoices_df,how='right',left_on='Product Id',right_on='Product Id')
# Out:
#             Price     Product Customer  Quantity
# Product Id
# 4109          5.0  Sushi Roll      Ali         1
# 4109          5.0  Sushi Roll      Sam         2
# 1412          0.5         Egg     Eric        12
# 8931          1.5       Bagei     Ande         6

# %%
product_df=product_df.reset_index()

# %%
product_df
# Out:
#    Product Id  Price     Product
# 0        4109    5.0  Sushi Roll
# 1        1412    0.5         Egg
# 2        8931    1.5       Bagei

# %%
invoices_df=invoices_df.reset_index()

# %%
invoices_df
# Out:
#    Product Id Customer  Quantity
# 0        4109      Ali         1
# 1        1412     Eric        12
# 2        8931     Ande         6
# 3        4109      Sam         2

# %%
pd.merge(product_df,invoices_df,how='right',left_on='Product Id',right_on='Product Id')
# Out:
#    Product Id  Price     Product Customer  Quantity
# 0        4109    5.0  Sushi Roll      Ali         1
# 1        4109    5.0  Sushi Roll      Sam         2
# 2        1412    0.5         Egg     Eric        12
# 3        8931    1.5       Bagei     Ande         6

# %%
pd.merge(product_df1,invoices_df1,left_index=True,right_on='Product Id')
# Out:
#    Price     Product Customer  Product Id  Quantity
# 0    5.0  Sushi Roll      Ali        4109         1
# 3    5.0  Sushi Roll      Sam        4109         2
# 1    0.5         Egg     Eric        1412        12
# 2    1.5       Bagei     Ande        8931         6

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])

# %%
staff_df
# Out:
#   First Name   Last Name            Role
# 0      Kelly  Desjardins  Director of HR
# 1      Sally      Brooks  Course liasion
# 2      James       Wilde          Grader

# %%
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])

# %%
student_df
# Out:
#   First Name Last Name       School
# 0      James   Hammond     Business
# 1       Mike     Smith          Law
# 2      Sally    Brooks  Engineering

# %%
pd.merge(staff_df,student_df,how='outer',left_on=['First Name','Last Name'],right_on=['First Name','Last Name'])
# Out:
#   First Name   Last Name            Role       School
# 0      Kelly  Desjardins  Director of HR          NaN
# 1      Sally      Brooks  Course liasion  Engineering
# 2      James       Wilde          Grader          NaN
# 3      James     Hammond             NaN     Business
# 4       Mike       Smith             NaN          Law

# %%
staff_df
# Out:
#   First Name   Last Name            Role
# 0      Kelly  Desjardins  Director of HR
# 1      Sally      Brooks  Course liasion
# 2      James       Wilde          Grader

# %%
pd.merge(staff_df,student_df,how='left',left_on=['First Name','Last Name'],right_on=['First Name','Last Name'])
# Out:
#   First Name   Last Name            Role       School
# 0      Kelly  Desjardins  Director of HR          NaN
# 1      Sally      Brooks  Course liasion  Engineering
# 2      James       Wilde          Grader          NaN

# %%
df=pd.DataFrame([{'Name':'Maher','Item Purchased':'Fish','Cost':200},
                 {'Name':'Sunny','Item Purchased':'Pizza','Cost':150},
                 {'Name':'Nasima','Item Purchased':'Chicken','Cost':250}],
               index=['store1','store1','store2'])
df
# Out:
#           Name Item Purchased  Cost
# store1   Maher           Fish   200
# store1   Sunny          Pizza   150
# store2  Nasima        Chicken   250

# %%
df['Date']=['February 15','Dcember 1','January 24']

# %%
df
# Out:
#           Name Item Purchased  Cost         Date
# store1   Maher           Fish   200  February 15
# store1   Sunny          Pizza   150    Dcember 1
# store2  Nasima        Chicken   250   January 24

# %%
df['Delivered']=True

# %%
df
# Out:
#           Name Item Purchased  Cost         Date  Delivered
# store1   Maher           Fish   200  February 15       True
# store1   Sunny          Pizza   150    Dcember 1       True
# store2  Nasima        Chicken   250   January 24       True

# %%
df['Feedback']=['Positive',None,'Negative']

# %%
df
# Out:
#           Name Item Purchased  Cost         Date  Delivered  Feedback
# store1   Maher           Fish   200  February 15       True  Positive
# store1   Sunny          Pizza   150    Dcember 1       True      None
# store2  Nasima        Chicken   250   January 24       True  Negative

# %%
adf=df.reset_index()

# %%
adf['Delivered']=pd.Series({0:True,2:False})

# %%
adf
# Out:
#     index    Name Item Purchased  Cost         Date Delivered  Feedback
# 0  store1   Maher           Fish   200  February 15      True  Positive
# 1  store1   Sunny          Pizza   150    Dcember 1       NaN      None
# 2  store2  Nasima        Chicken   250   January 24     False  Negative

# %%
adf['Quantity']=pd.Series({0:'1kg',1:'1piece',2:'3kg'})

# %%
adf
# Out:
#     index    Name Item Purchased  Cost         Date Delivered  Feedback  \
# 0  store1   Maher           Fish   200  February 15      True  Positive
# 1  store1   Sunny          Pizza   150    Dcember 1       NaN      None
# 2  store2  Nasima        Chicken   250   January 24     False  Negative
#
#   Quantity
# 0      1kg
# 1   1piece
# 2      3kg

# %%
adf=adf.set_index('index')

# %%
adf
# Out:
#           Name Item Purchased  Cost         Date Delivered  Feedback Quantity
# index
# store1   Maher           Fish   200  February 15      True  Positive      1kg
# store1   Sunny          Pizza   150    Dcember 1       NaN      None   1piece
# store2  Nasima        Chicken   250   January 24     False  Negative      3kg

# %%
staff_df=pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}])

# %%
staff_df=staff_df.set_index('Name')

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
student_df=pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])

# %%
student_df
# Out:
#     Name       School
# 0  James     Business
# 1   Mike          Law
# 2  Sally  Engineering

# %%
student_df=student_df.set_index('Name')

# %%
student_df
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
pd.merge(staff_df,student_df,how='outer',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
pd.merge(staff_df,student_df,how='inner',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df,student_df,how='left',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df,student_df,how='right',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df=staff_df.reset_index()

# %%
student_df=student_df.reset_index()

# %%
pd.merge(staff_df,student_df,how='left',left_on='Name',right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          NaN
# 1  Sally  Course liasion  Engineering
# 2  James          Grader     Business

# %%
staff_df=pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])

# %%
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': 'Washington Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])

# %%
pd.merge(staff_df,student_df,how='left',left_on='Name',right_on='Name')
# Out:
#     Name            Role         Location_x       School           Location_y
# 0  Kelly  Director of HR       State Street          NaN                  NaN
# 1  Sally  Course liasion  Washington Avenue  Engineering  512 Wilson Crescent
# 2  James          Grader  Washington Avenue     Business    Washington Avenue

# %%
df=pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
(df.where(df['SUMLEV']==50).dropna().set_index(['STNAME','CTYNAME'])
.rename(columns={'ESTIMATESBASE2010':'Estimates Base 2010'}))
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County       50.0     3.0       6.0    1.0     1.0
#         Baldwin County       50.0     3.0       6.0    1.0     3.0
#         Barbour County       50.0     3.0       6.0    1.0     5.0
#         Bibb County          50.0     3.0       6.0    1.0     7.0
#         Blount County        50.0     3.0       6.0    1.0     9.0
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County    50.0     4.0       8.0   56.0    37.0
#         Teton County         50.0     4.0       8.0   56.0    39.0
#         Uinta County         50.0     4.0       8.0   56.0    41.0
#         Washakie County      50.0     4.0       8.0   56.0    43.0
#         Weston County        50.0     4.0       8.0   56.0    45.0
#
#                            CENSUS2010POP  Estimates Base 2010  \
# STNAME  CTYNAME
# Alabama Autauga County           54571.0              54571.0
# ...

# %%
(df.where(df['SUMLEV']==50).dropna().set_index(['STNAME','CTYNAME'])
.rename(columns={'CENSUS2010POP':'CENSUS 2010 POP'})).head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County    50.0     3.0       6.0    1.0     1.0
#         Baldwin County    50.0     3.0       6.0    1.0     3.0
#         Barbour County    50.0     3.0       6.0    1.0     5.0
#         Bibb County       50.0     3.0       6.0    1.0     7.0
#         Blount County     50.0     3.0       6.0    1.0     9.0
#
#                         CENSUS 2010 POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571.0            54571.0          54660.0
#         Baldwin County         182265.0           182265.0         183193.0
#         Barbour County          27457.0            27457.0          27341.0
#         Bibb County             22915.0            22919.0          22861.0
#         Blount County           57322.0            57322.0          57373.0
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df=pd.read_csv('census.csv')

# %%
df.where(df['SUMLEV']==50)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0        NaN     NaN       NaN    NaN     NaN      NaN                NaN
# 1       50.0     3.0       6.0    1.0     1.0  Alabama     Autauga County
# 2       50.0     3.0       6.0    1.0     3.0  Alabama     Baldwin County
# 3       50.0     3.0       6.0    1.0     5.0  Alabama     Barbour County
# 4       50.0     3.0       6.0    1.0     7.0  Alabama        Bibb County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188    50.0     4.0       8.0   56.0    37.0  Wyoming  Sweetwater County
# 3189    50.0     4.0       8.0   56.0    39.0  Wyoming       Teton County
# 3190    50.0     4.0       8.0   56.0    41.0  Wyoming       Uinta County
# 3191    50.0     4.0       8.0   56.0    43.0  Wyoming    Washakie County
# 3192    50.0     4.0       8.0   56.0    45.0  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
df=df[df['SUMLEV']==50]

# %%
df.set_index(['STNAME','CTYNAME'],inplace=True)

# %%
df.rename(columns={'CENSUS2010POP':'census 2010 pop'})
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            census 2010 pop  ESTIMATESBASE2010  \
# STNAME  CTYNAME
# Alabama Autauga County               54571              54571
# ...

# %%
df.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#         Blount County       50       3         6      1       9
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#         Blount County           57322              57322            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
data=row[[
    'POPESTIMATE2010',
    'POPESTIMATE2011',
    'POPESTIMATE2012',
    'POPESTIMATE2013',
    'POPESTIMATE2014'
    'POPESTIMATE2015'
]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-171-d36efbdcf18a> in <module>
# ----> 1 data=row[[
#       2     'POPESTIMATE2010',
#       3     'POPESTIMATE2011',
#       4     'POPESTIMATE2012',
#       5     'POPESTIMATE2013',
#
# NameError: name 'row' is not defined

# %%
import numpy as np

# %%
np.max(df[['POPESTIMATE2010','POPESTIMATE2011']])
# Out:
# POPESTIMATE2010    9826009
# POPESTIMATE2011    9896602
# dtype: int64

# %%
def min_max(row):
    data=row[['POPESTIMATE2010',
              'POPESTIMATE2011',
              'POPESTIMATE2012',
              'POPESTIMATE2013',
              'POPESTIMATE2014',
              'POPESTIMATE2015']]
    return pd.Series({'min':np.min(data),'max':np.max(data)})
    
df.apply(min_max,axis=1)
# Out:
#                                 min       max
# STNAME  CTYNAME
# Alabama Autauga County      54660.0   55347.0
#         Baldwin County     183193.0  203709.0
#         Barbour County      26489.0   27341.0
#         Bibb County         22512.0   22861.0
#         Blount County       57373.0   57776.0
# ...                             ...       ...
# Wyoming Sweetwater County   43593.0   45162.0
#         Teton County        21297.0   23125.0
#         Uinta County        20822.0   21102.0
#         Washakie County      8316.0    8545.0
#         Weston County        7065.0    7234.0
#
# [3142 rows x 2 columns]

# %%
pd.Series({'min':20,'max':30}).index
# Out:
# Index(['min', 'max'], dtype='object')

# %%
np.max(df[['POPESTIMATE2010','POPESTIMATE2011']])
# Out:
# POPESTIMATE2010    9826009
# POPESTIMATE2011    9896602
# dtype: int64

# %%
df.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#         Blount County       50       3         6      1       9
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#         Blount County           57322              57322            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
rows=df[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013']]

# %% [raw]
# rows

# %%
np.max(rows,axis=1)
# Out:
# STNAME   CTYNAME
# Alabama  Autauga County        55253
#          Baldwin County       195126
#          Barbour County        27341
#          Bibb County           22861
#          Blount County         57776
#                                ...
# Wyoming  Sweetwater County     45162
#          Teton County          22347
#          Uinta County          21102
#          Washakie County        8545
#          Weston County          7181
# Length: 3142, dtype: int64

# %%
df.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#         Blount County       50       3         6      1       9
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#         Blount County           57322              57322            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
def min_max(row):
    data=row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['min']=np.min(data)
    row['max']=np.max(data)
    return row[['min','max']]
df.apply(min_max,axis=1)
# Out:
#                                 min       max
# STNAME  CTYNAME
# Alabama Autauga County      54660.0   55347.0
#         Baldwin County     183193.0  203709.0
#         Barbour County      26489.0   27341.0
#         Bibb County         22512.0   22861.0
#         Blount County       57373.0   57776.0
# ...                             ...       ...
# Wyoming Sweetwater County   43593.0   45162.0
#         Teton County        21297.0   23125.0
#         Uinta County        20822.0   21102.0
#         Washakie County      8316.0    8545.0
#         Weston County        7065.0    7234.0
#
# [3142 rows x 2 columns]

# %%
df.head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County      50       3         6      1       1
#         Baldwin County      50       3         6      1       3
#         Barbour County      50       3         6      1       5
#         Bibb County         50       3         6      1       7
#         Blount County       50       3         6      1       9
#
#                         CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County          54571              54571            54660
#         Baldwin County         182265             182265           183193
#         Barbour County          27457              27457            27341
#         Bibb County             22915              22919            22861
#         Blount County           57322              57322            57373
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
rows=['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']

# %%
df.apply(lambda x:np.min(x[rows]),axis=1)
# Out:
# STNAME   CTYNAME
# Alabama  Autauga County        54660.0
#          Baldwin County       183193.0
#          Barbour County        26489.0
#          Bibb County           22512.0
#          Blount County         57373.0
#                                 ...
# Wyoming  Sweetwater County     43593.0
#          Teton County          21297.0
#          Uinta County          20822.0
#          Washakie County        8316.0
#          Weston County          7065.0
# Length: 3142, dtype: float64

# %%
df.apply(lambda x:np.max(x[['POPESTIMATE2010','POPESTIMATE2011']]),axis=1)
# Out:
# STNAME   CTYNAME
# Alabama  Autauga County        55253.0
#          Baldwin County       186659.0
#          Barbour County        27341.0
#          Bibb County           22861.0
#          Blount County         57711.0
#                                 ...
# Wyoming  Sweetwater County     44041.0
#          Teton County          21482.0
#          Uinta County          21102.0
#          Washakie County        8545.0
#          Weston County          7181.0
# Length: 3142, dtype: float64

# %%
df=pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df['STNAME'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df=df[df['SUMLEV']==50]
for state in df['STNAME'].unique():
    avg=np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('counties in state ' + state + ' have an average population of '+str(avg))
# Out:
# counties in state Alabama have an average population of 71339.34328358209
# counties in state Alaska have an average population of 24490.724137931036
# counties in state Arizona have an average population of 426134.4666666667
# counties in state Arkansas have an average population of 38878.90666666667
# counties in state California have an average population of 642309.5862068966
# counties in state Colorado have an average population of 78581.1875
# counties in state Connecticut have an average population of 446762.125
# counties in state Delaware have an average population of 299311.3333333333
# counties in state District of Columbia have an average population of 601723.0
# counties in state Florida have an average population of 280616.5671641791
# counties in state Georgia have an average population of 60928.63522012578
# counties in state Hawaii have an average population of 272060.2
# counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
df.where(df['SUMLEV']==50)
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
for state in df['STNAME'].unique():
    avg=np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print(avg)
# Out:
# 71339.34328358209
# 24490.724137931036
# 426134.4666666667
# 38878.90666666667
# 642309.5862068966
# 78581.1875
# 446762.125
# 299311.3333333333
# 601723.0
# 280616.5671641791
# 60928.63522012578
# 272060.2
# 35626.86363636364
# 125790.50980392157
# 70476.10869565218
# 30771.262626262625
# 27172.55238095238
# 36161.39166666667
# 70833.9375
# 83022.5625
# 240564.66666666666
# 467687.78571428574
# 119080.0
# 60964.65517241379
# 36186.54878048781
# 52077.62608695652
# 17668.125
# 19638.075268817203
# 158855.9411764706
# 131647.0
# 418661.61904761905
# 62399.36363636364
# 312550.03225806454
# 95354.83
# 12690.396226415094
# 131096.63636363635
# 48718.844155844155
# 106418.72222222222
# 189587.74626865672
# 210513.4
# 100551.39130434782
# 12336.060606060606
# 66801.1052631579
# 98998.27165354331
# 95306.37931034483
# 44695.78571428572
# 60111.29323308271
# 172424.10256410256
# 33690.8
# 78985.91666666667
# 24505.478260869564

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
list(df.groupby('STNAME'))
# Out:
# [('Alabama',
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
#   1       50       3         6      1       1  Alabama     Autauga County
#   2       50       3         6      1       3  Alabama     Baldwin County
#   3       50       3         6      1       5  Alabama     Barbour County
#   4       50       3         6      1       7  Alabama        Bibb County
#   5       50       3         6      1       9  Alabama      Blount County
#   ..     ...     ...       ...    ...     ...      ...                ...
#   63      50       3         6      1     125  Alabama  Tuscaloosa County
#   64      50       3         6      1     127  Alabama      Walker County
#   65      50       3         6      1     129  Alabama  Washington County
#   66      50       3         6      1     131  Alabama      Wilcox County
#   67      50       3         6      1     133  Alabama     Winston County
#
# ...

# %%
df
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 1         50       3         6      1       1  Alabama     Autauga County
# 2         50       3         6      1       3  Alabama     Baldwin County
# 3         50       3         6      1       5  Alabama     Barbour County
# 4         50       3         6      1       7  Alabama        Bibb County
# 5         50       3         6      1       9  Alabama      Blount County
# ...      ...     ...       ...    ...     ...      ...                ...
# 3188      50       4         8     56      37  Wyoming  Sweetwater County
# 3189      50       4         8     56      39  Wyoming       Teton County
# 3190      50       4         8     56      41  Wyoming       Uinta County
# 3191      50       4         8     56      43  Wyoming    Washakie County
# 3192      50       4         8     56      45  Wyoming      Weston County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  \
# ...

# %%
for group,frame in df.groupby('STNAME'):
    avg=np.average(frame['CENSUS2010POP'])
    print('counties in state '+group+' has an average population of '+str(avg))
# Out:
# counties in state Alabama has an average population of 71339.34328358209
# counties in state Alaska has an average population of 24490.724137931036
# counties in state Arizona has an average population of 426134.4666666667
# counties in state Arkansas has an average population of 38878.90666666667
# counties in state California has an average population of 642309.5862068966
# counties in state Colorado has an average population of 78581.1875
# counties in state Connecticut has an average population of 446762.125
# counties in state Delaware has an average population of 299311.3333333333
# counties in state District of Columbia has an average population of 601723.0
# counties in state Florida has an average population of 280616.5671641791
# counties in state Georgia has an average population of 60928.63522012578
# counties in state Hawaii has an average population of 272060.2
# counties in state Idaho has an average population of 35626.86363636364
# ...

# %%
df=df.set_index('STNAME')
df.head()
# Out:
#          SUMLEV  REGION  DIVISION  STATE  COUNTY         CTYNAME  \
# STNAME
# Alabama      50       3         6      1       1  Autauga County
# Alabama      50       3         6      1       3  Baldwin County
# Alabama      50       3         6      1       5  Barbour County
# Alabama      50       3         6      1       7     Bibb County
# Alabama      50       3         6      1       9   Blount County
#
#          CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# Alabama          54571              54571            54660            55253
# Alabama         182265             182265           183193           186659
# Alabama          27457              27457            27341            27226
# Alabama          22915              22919            22861            22733
# Alabama          57322              57322            57373            57711
#
#          ...  RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# STNAME   ...
# ...

# %%
def fun(item):
    if item[0]<'M':
        return 0
    if item[0]<'Q':
        return 1
    return 2
for group,frame in df.groupby(fun):
    print('there are '+str(len(frame))+' record in group '+str(group)+' for processing.')
# Out:
# there are 1177 record in group 0 for processing.
# there are 1134 record in group 1 for processing.
# there are 831 record in group 2 for processing.

# %%
df=df.reset_index()

# %%
df.groupby('STNAME')['CENSUS2010POP'].agg(['sum','mean','max','min'])
# Out:
#                            sum           mean      max     min
# STNAME
# Alabama                4779736   71339.343284   658466    9045
# Alaska                  710231   24490.724138   291826     662
# Arizona                6392017  426134.466667  3817117    8437
# Arkansas               2915918   38878.906667   382748    5368
# California            37253956  642309.586207  9818605    1175
# Colorado               5029196   78581.187500   622263     699
# Connecticut            3574097  446762.125000   916829  118428
# Delaware                897934  299311.333333   538479  162310
# District of Columbia    601723  601723.000000   601723  601723
# Florida               18801310  280616.567164  2496435    8365
# Georgia                9687653   60928.635220   920581    1717
# Hawaii                 1360301  272060.200000   953207      90
# Idaho                  1567582   35626.863636   392365     982
# Illinois              12830632  125790.509804  5194675    4320
# ...

# %%
df.groupby('STNAME')['CENSUS2010POP'].mean()
# Out:
# STNAME
# Alabama                  71339.343284
# Alaska                   24490.724138
# Arizona                 426134.466667
# Arkansas                 38878.906667
# California              642309.586207
# Colorado                 78581.187500
# Connecticut             446762.125000
# Delaware                299311.333333
# District of Columbia    601723.000000
# Florida                 280616.567164
# Georgia                  60928.635220
# Hawaii                  272060.200000
# Idaho                    35626.863636
# Illinois                125790.509804
# Indiana                  70476.108696
# Iowa                     30771.262626
# Kansas                   27172.552381
# Kentucky                 36161.391667
# Louisiana                70833.937500
# Maine                    83022.562500
# Maryland                240564.666667
# Massachusetts           467687.785714
# Michigan                119080.000000
# Minnesota                60964.655172
# ...

# %%
df.groupby('STNAME').agg({'CENSUS2010POP':np.average})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                       CENSUS2010POP
# STNAME
# Alabama                71339.343284
# Alaska                 24490.724138
# Arizona               426134.466667
# Arkansas               38878.906667
# California            642309.586207
# Colorado               78581.187500
# Connecticut           446762.125000
# Delaware              299311.333333
# District of Columbia  601723.000000
# Florida               280616.567164
# Georgia                60928.635220
# Hawaii                272060.200000
# Idaho                  35626.863636
# Illinois              125790.509804
# Indiana                70476.108696
# Iowa                   30771.262626
# ...

# %%
df.head()
# Out:
#     STNAME  SUMLEV  REGION  DIVISION  STATE  COUNTY         CTYNAME  \
# 0  Alabama      50       3         6      1       1  Autauga County
# 1  Alabama      50       3         6      1       3  Baldwin County
# 2  Alabama      50       3         6      1       5  Barbour County
# 3  Alabama      50       3         6      1       7     Bibb County
# 4  Alabama      50       3         6      1       9   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0          54571              54571            54660  ...          7.242091
# 1         182265             182265           183193  ...         14.832960
# 2          27457              27457            27341  ...         -4.728132
# 3          22915              22919            22861  ...         -5.527043
# 4          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.groupby('STNAME').agg({'POPESTIMATE2010':[np.sum,np.max,np.min,np.average]})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                      POPESTIMATE2010
#                                  sum     amax    amin        average
# STNAME
# Alabama                      4785161   658116    9001   71420.313433
# Alaska                        714021   293405     662   24621.413793
# Arizona                      6408208  3825597    8339  427213.866667
# Arkansas                     2922394   383628    5338   38965.253333
# California                  37334079  9826009    1159  643691.017241
# Colorado                     5048254   626916     704   78878.968750
# Connecticut                  3579717   919744  118593  447464.625000
# Delaware                      899791   538911  162990  299930.333333
# ...

# %%
df.head()
# Out:
#     STNAME  SUMLEV  REGION  DIVISION  STATE  COUNTY         CTYNAME  \
# 0  Alabama      50       3         6      1       1  Autauga County
# 1  Alabama      50       3         6      1       3  Baldwin County
# 2  Alabama      50       3         6      1       5  Barbour County
# 3  Alabama      50       3         6      1       7     Bibb County
# 4  Alabama      50       3         6      1       9   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0          54571              54571            54660  ...          7.242091
# 1         182265             182265           183193  ...         14.832960
# 2          27457              27457            27341  ...         -4.728132
# 3          22915              22919            22861  ...         -5.527043
# 4          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.

# %%
print(type(df.groupby(level=0)['POPESTIMATE2010']))
# Out:
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>

# %%
df.head()
# Out:
#     STNAME  SUMLEV  REGION  DIVISION  STATE  COUNTY         CTYNAME  \
# 0  Alabama      50       3         6      1       1  Autauga County
# 1  Alabama      50       3         6      1       3  Baldwin County
# 2  Alabama      50       3         6      1       5  Barbour County
# 3  Alabama      50       3         6      1       7     Bibb County
# 4  Alabama      50       3         6      1       9   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0          54571              54571            54660  ...          7.242091
# 1         182265             182265           183193  ...         14.832960
# 2          27457              27457            27341  ...         -4.728132
# 3          22915              22919            22861  ...         -5.527043
# 4          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010'].agg({'avg':np.average,'sum':np.sum}))
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-268-eba58f00d288> in <module>
# ----> 1 (df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010'].agg({'avg':np.average,'sum':np.sum}))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     251             # but not the class list / tuple itself.
#     252             func = _maybe_mangle_lambdas(func)
# --> 253             ret = self._aggregate_multiple_funcs(func)
#     254             if relabeling:
#     255                 ret.columns = columns
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg)
#     292             # GH 15931
#     293             if isinstance(self._selected_obj, Series):
# ...

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg({'avg': np.average, 'sum': np.sum}))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-269-554977a3acb1> in <module>
#       1 (df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
# ----> 2     .agg({'avg': np.average, 'sum': np.sum}))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     938         func = _maybe_mangle_lambdas(func)
#     939
# --> 940         result, how = self._aggregate(func, *args, **kwargs)
#     941         if how is None:
#     942             return result
#
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2010'].agg({'avg':np.average,'sum':np.sum})
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-270-0eddc31af68a> in <module>
# ----> 1 df.groupby('STNAME')['POPESTIMATE2010'].agg({'avg':np.average,'sum':np.sum})
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     251             # but not the class list / tuple itself.
#     252             func = _maybe_mangle_lambdas(func)
# --> 253             ret = self._aggregate_multiple_funcs(func)
#     254             if relabeling:
#     255                 ret.columns = columns
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg)
#     292             # GH 15931
#     293             if isinstance(self._selected_obj, Series):
# --> 294                 raise SpecificationError("nested renamer is not supported")
#     295
# ...

# %%
(df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011']
    .agg([np.average,np.sum]))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                      POPESTIMATE2010           POPESTIMATE2011
#                              average       sum         average       sum
# STNAME
# Alabama                 71420.313433   4785161    71658.328358   4801108
# Alaska                  24621.413793    714021    24921.379310    722720
# Arizona                427213.866667   6408208   431248.800000   6468732
# ...

# %%
df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010'].agg([np.average,np.sum])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                             average       sum
# STNAME
# Alabama                71420.313433   4785161
# Alaska                 24621.413793    714021
# Arizona               427213.866667   6408208
# Arkansas               38965.253333   2922394
# California            643691.017241  37334079
# Colorado               78878.968750   5048254
# Connecticut           447464.625000   3579717
# Delaware              299930.333333    899791
# District of Columbia  605126.000000    605126
# Florida               281341.641791  18849890
# Georgia                61090.905660   9713454
# Hawaii                272796.000000   1363980
# Idaho                  35704.227273   1570986
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2010','POPESTIMATE2011'].agg({'POPESTIMATE2010':np.average,'POPESTIMATE2011':np.sum})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  71420.313433          4801108
# Alaska                   24621.413793           722720
# Arizona                 427213.866667          6468732
# Arkansas                 38965.253333          2938538
# California              643691.017241         37700034
# Colorado                 78878.968750          5119480
# ...

# %%
df.groupby('STNAME').agg({'POPESTIMATE2010':np.average,'POPESTIMATE2011':np.sum})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  71420.313433          4801108
# Alaska                   24621.413793           722720
# Arizona                 427213.866667          6468732
# Arkansas                 38965.253333          2938538
# California              643691.017241         37700034
# Colorado                 78878.968750          5119480
# Connecticut             447464.625000          3589759
# Delaware                299930.333333           907916
# District of Columbia    605126.000000           620472
# Florida                 281341.641791         19105533
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2010','POPESTIMATE2011'].agg([np.average,np.sum,np.max,np.min])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                      POPESTIMATE2010                             \
#                              average       sum     amax    amin
# STNAME
# Alabama                 71420.313433   4785161   658116    9001
# Alaska                  24621.413793    714021   293405     662
# Arizona                427213.866667   6408208  3825597    8339
# Arkansas                38965.253333   2922394   383628    5338
# ...

# %%
df=pd.read_csv('census.csv')
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.where(df['SUMLEV']==50).dropna().set_index(['STNAME','CTYNAME']).rename(columns={'ESTIMATESBASE2010':'ESTIMATE BASE 2010'})
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County       50.0     3.0       6.0    1.0     1.0
#         Baldwin County       50.0     3.0       6.0    1.0     3.0
#         Barbour County       50.0     3.0       6.0    1.0     5.0
#         Bibb County          50.0     3.0       6.0    1.0     7.0
#         Blount County        50.0     3.0       6.0    1.0     9.0
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County    50.0     4.0       8.0   56.0    37.0
#         Teton County         50.0     4.0       8.0   56.0    39.0
#         Uinta County         50.0     4.0       8.0   56.0    41.0
#         Washakie County      50.0     4.0       8.0   56.0    43.0
#         Weston County        50.0     4.0       8.0   56.0    45.0
#
#                            CENSUS2010POP  ESTIMATE BASE 2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# ...

# %%
df=df[df['SUMLEV']==50]

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
#df.set_index(['STNAME','CTYNAME'],inplace=True)
df=df.rename(columns={'ESTIMATESBASE2010':'ESTIMATE BASE 2010'})
df
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            CENSUS2010POP  ESTIMATE BASE 2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# ...

# %%
df
# Out:
#                            SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County         50       3         6      1       1
#         Baldwin County         50       3         6      1       3
#         Barbour County         50       3         6      1       5
#         Bibb County            50       3         6      1       7
#         Blount County          50       3         6      1       9
# ...                           ...     ...       ...    ...     ...
# Wyoming Sweetwater County      50       4         8     56      37
#         Teton County           50       4         8     56      39
#         Uinta County           50       4         8     56      41
#         Washakie County        50       4         8     56      43
#         Weston County          50       4         8     56      45
#
#                            CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# ...

# %%
df=df.reset_index()

# %%
df.head()
# Out:
#     STNAME         CTYNAME  SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# 0  Alabama  Autauga County      50       3         6      1       1
# 1  Alabama  Baldwin County      50       3         6      1       3
# 2  Alabama  Barbour County      50       3         6      1       5
# 3  Alabama     Bibb County      50       3         6      1       7
# 4  Alabama   Blount County      50       3         6      1       9
#
#    CENSUS2010POP  ESTIMATE BASE 2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0          54571               54571            54660  ...          7.242091
# 1         182265              182265           183193  ...         14.832960
# 2          27457               27457            27341  ...         -4.728132
# 3          22915               22919            22861  ...         -5.527043
# 4          57322               57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011'].agg([np.max,np.min])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      POPESTIMATE2010         POPESTIMATE2011
#                                 amax    amin            amax    amin
# STNAME
# Alabama                       658116    9001          657779    8910
# Alaska                        293405     662          296333     651
# Arizona                      3825597    8339         3871957    8589
# Arkansas                      383628    5338          386827    5286
# California                   9826009    1159         9896602    1111
# Colorado                      626916     704          636946     697
# Connecticut                   919744  118593          929013  118418
# Delaware                      538911  162990          542349  165242
# ...

# %%
df[df['STNAME']=='Alabama'][['CTYNAME','POPESTIMATE2010']].max()
# Out:
# CTYNAME            Winston County
# POPESTIMATE2010            658116
# dtype: object

# %%
def min_max(row):
    data=row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    row['min']=np.min(data)
    row['max']=np.max(data)
    return row[['min','max']]

# %%
df.apply(min_max,axis=1)
# Out:
#          min     max
# 0      54660   55347
# 1     183193  203709
# 2      26489   27341
# 3      22512   22861
# 4      57373   57776
# ...      ...     ...
# 3137   43593   45162
# 3138   21297   23125
# 3139   20822   21102
# 3140    8316    8545
# 3141    7065    7234
#
# [3142 rows x 2 columns]

# %%
data=df[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
np.min(data,axis=1)
# Out:
# 0        54660
# 1       183193
# 2        26489
# 3        22512
# 4        57373
#          ...
# 3137     43593
# 3138     21297
# 3139     20822
# 3140      8316
# 3141      7065
# Length: 3142, dtype: int64

# %%
def min_max(row):
    data=row[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
    return pd.Series({'min':np.min(data),'max':np.max(data)})

# %%
df.apply(min_max,axis=1)
# Out:
#          min     max
# 0      54660   55347
# 1     183193  203709
# 2      26489   27341
# 3      22512   22861
# 4      57373   57776
# ...      ...     ...
# 3137   43593   45162
# 3138   21297   23125
# 3139   20822   21102
# 3140    8316    8545
# 3141    7065    7234
#
# [3142 rows x 2 columns]

# %%
rows=[['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']]
# Out:
#   File "<ipython-input-324-ee50d05f6c4a>", line 7
#     df.apply(lambda x:(x[rows].min(),axis=1))
#                                          ^
# SyntaxError: invalid syntax

# %%
rows=['POPESTIMATE2010',
                'POPESTIMATE2011',
                'POPESTIMATE2012',
                'POPESTIMATE2013',
                'POPESTIMATE2014',
                'POPESTIMATE2015']
df.apply(lambda x:np.max(x[rows]),axis=1)
# Out:
# 0        55347
# 1       203709
# 2        27341
# 3        22861
# 4        57776
#          ...
# 3137     45162
# 3138     23125
# 3139     21102
# 3140      8545
# 3141      7234
# Length: 3142, dtype: int64

# %%
df
# Out:
#        STNAME            CTYNAME  SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# 0     Alabama     Autauga County      50       3         6      1       1
# 1     Alabama     Baldwin County      50       3         6      1       3
# 2     Alabama     Barbour County      50       3         6      1       5
# 3     Alabama        Bibb County      50       3         6      1       7
# 4     Alabama      Blount County      50       3         6      1       9
# ...       ...                ...     ...     ...       ...    ...     ...
# 3137  Wyoming  Sweetwater County      50       4         8     56      37
# 3138  Wyoming       Teton County      50       4         8     56      39
# 3139  Wyoming       Uinta County      50       4         8     56      41
# 3140  Wyoming    Washakie County      50       4         8     56      43
# 3141  Wyoming      Weston County      50       4         8     56      45
#
#       CENSUS2010POP  ESTIMATE BASE 2010  POPESTIMATE2010  ...  \
# ...

# %%
df=pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df=df[df['SUMLEV']==50]

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
for state in df['STNAME'].unique():
    avg=np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('counties in state '+state+' have an average population of '+str(avg))
# Out:
# counties in state Alabama have an average population of 71339.34328358209
# counties in state Alaska have an average population of 24490.724137931036
# counties in state Arizona have an average population of 426134.4666666667
# counties in state Arkansas have an average population of 38878.90666666667
# counties in state California have an average population of 642309.5862068966
# counties in state Colorado have an average population of 78581.1875
# counties in state Connecticut have an average population of 446762.125
# counties in state Delaware have an average population of 299311.3333333333
# counties in state District of Columbia have an average population of 601723.0
# counties in state Florida have an average population of 280616.5671641791
# counties in state Georgia have an average population of 60928.63522012578
# counties in state Hawaii have an average population of 272060.2
# counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
for group,frame in df.groupby('STNAME'):
    avg=np.average(frame['CENSUS2010POP'])
    print('counties in state '+group+' have an average population of '+str(avg))
# Out:
# counties in state Alabama have an average population of 71339.34328358209
# counties in state Alaska have an average population of 24490.724137931036
# counties in state Arizona have an average population of 426134.4666666667
# counties in state Arkansas have an average population of 38878.90666666667
# counties in state California have an average population of 642309.5862068966
# counties in state Colorado have an average population of 78581.1875
# counties in state Connecticut have an average population of 446762.125
# counties in state Delaware have an average population of 299311.3333333333
# counties in state District of Columbia have an average population of 601723.0
# counties in state Florida have an average population of 280616.5671641791
# counties in state Georgia have an average population of 60928.63522012578
# counties in state Hawaii have an average population of 272060.2
# counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df['SUMLEV'].unique()
# Out:
# array([50], dtype=int64)

# %%
df.groupby('STNAME')['POPESTIMATE2010','POPESTIMATE2011'].sum()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                       4785161          4801108
# Alaska                         714021           722720
# Arizona                       6408208          6468732
# Arkansas                      2922394          2938538
# California                   37334079         37700034
# Colorado                      5048254          5119480
# Connecticut                   3579717          3589759
# Delaware                       899791           907916
# District of Columbia           605126           620472
# Florida                      18849890         19105533
# Georgia                       9713454          9812280
# Hawaii                        1363980          1378227
# ...

# %%
df.columns
# Out:
# Index(['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME',
#        'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010',
#        'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013',
#        'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011',
#        'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015',
#        'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014',
#        'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013',
#        'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011',
#        'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015',
#        'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012',
#        'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015',
#        'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012',
#        'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010',
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2014'].agg(np.sum)
# Out:
# STNAME
# Alabama                  4846411
# Alaska                    737046
# Arizona                  6728783
# Arkansas                 2966835
# California              38792291
# Colorado                 5355588
# Connecticut              3594762
# Delaware                  935968
# District of Columbia      659836
# Florida                 19905569
# Georgia                 10097132
# Hawaii                   1420257
# Idaho                    1634806
# Illinois                12882189
# Indiana                  6597880
# Iowa                     3109481
# Kansas                   2902507
# Kentucky                 4412617
# Louisiana                4648990
# Maine                    1330256
# Maryland                 5975346
# Massachusetts            6755124
# Michigan                 9916306
# Minnesota                5457125
# Mississippi              2993443
# Missouri                 6063827
# Montana                  1023252
# Nebraska                 1882980
# ...

# %%
df['STNAME'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df[df['STNAME']=='Alabama'][['CTYNAME','CENSUS2010POP']].max()
# Out:
# CTYNAME          Winston County
# CENSUS2010POP            658466
# dtype: object

# %%
df.groupby('STNAME').agg({'POPESTIMATE2014':np.sum})
# Out:
#                       POPESTIMATE2014
# STNAME
# Alabama                       4846411
# Alaska                         737046
# Arizona                       6728783
# Arkansas                      2966835
# California                   38792291
# Colorado                      5355588
# Connecticut                   3594762
# Delaware                       935968
# District of Columbia           659836
# Florida                      19905569
# Georgia                      10097132
# Hawaii                        1420257
# Idaho                         1634806
# Illinois                     12882189
# Indiana                       6597880
# Iowa                          3109481
# Kansas                        2902507
# Kentucky                      4412617
# Louisiana                     4648990
# Maine                         1330256
# Maryland                      5975346
# Massachusetts                 6755124
# Michigan                      9916306
# ...

# %%
df.set_index('STNAME').groupby(level=0)['POPESTIMATE2010','POPESTIMATE2011',
'POPESTIMATE2012'].agg([np.sum,np.max,np.min])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                      POPESTIMATE2010                  POPESTIMATE2011  \
#                                  sum     amax    amin             sum
# STNAME
# Alabama                      4785161   658116    9001         4801108
# Alaska                        714021   293405     662          722720
# Arizona                      6408208  3825597    8339         6468732
# Arkansas                     2922394   383628    5338         2938538
# California                  37334079  9826009    1159        37700034
# Colorado                     5048254   626916     704         5119480
# Connecticut                  3579717   919744  118593         3589759
# Delaware                      899791   538911  162990          907916
# ...

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
               index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])

df.rename(columns={0:'Grade'},inplace=True)

# %%
df
# Out:
#           Grade
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D

# %%
type(df['Grade'])
# Out:
# pandas.core.series.Series

# %%
df['Grade'].astype('category')
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grade, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
               index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])

# %%
df.rename(columns={0:'Grades'},inplace=True)

# %%
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
type(df['Grades'])
# Out:
# pandas.core.series.Series

# %%
df['Grades'].astype('category')
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
type(df['Grades'])
# Out:
# pandas.core.series.Series

# %%
Grades=df['Grades'].astype('category',
                          categories=['D','D+','C-','C','C+','B-','B','B+','A-','A','A+'],
                          ordered=True)
# Out:
#   File "<ipython-input-17-3d6a34da39d9>", line 2
#     'categories'=['D','D+','C-','C','C+','B-','B','B+','A-','A','A+'],
#     ^
# SyntaxError: keyword can't be an expression

# %%
grades = df['Grades'].astype('category',
                             categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                             ordered=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-2429e1039aac> in <module>
#       1 grades = df['Grades'].astype('category',
#       2                              categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
# ----> 3                              ordered=True)
#
# TypeError: astype() got an unexpected keyword argument 'categories'

# %%
df['Grades']=df['Grades'].astype('category')

# %%
type(df['Grades'])
# Out:
# pandas.core.series.Series

# %%
Grades=df['Grades'].astype('category')

# %%
df['Grades']
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
Grades.head()
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
df['Grades']=df['Grades'].astype('categories'=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'])
# Out:
#   File "<ipython-input-28-addff5e1d630>", line 1
#     df['Grades']=df['Grades'].astype('categories'=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'])
#                                     ^
# SyntaxError: keyword can't be an expression

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
               index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])

# %%
df.head()
# Out:
#             0
# excellent  A+
# excellent   A
# excellent  A-
# good       B+
# good        B

# %%
df.rename(columns={0:'Grades'},inplace=True)

# %%
df['Grades']
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: object

# %%
Grades=df['Grades'].astype('category',
                          categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                          ordered=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-e80a0c62c9a7> in <module>
#       1 Grades=df['Grades'].astype('category',
#       2                           categories=['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
# ----> 3                           ordered=True)
#
# TypeError: astype() got an unexpected keyword argument 'categories'

# %%
df['Grades']=df['Grades'].astype('category')

# %%
df['Grades']=='C'
# Out:
# excellent    False
# excellent    False
# excellent    False
# good         False
# good         False
# good         False
# ok           False
# ok            True
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
df['Grades']=pd.Categorical(df['Grades'],['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                           ordered=True)

# %%
df['Grades']>'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
df['Grades']
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
df['Grades']>'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
df=pd.read_csv('census.csv')
df=df[df['SUMLEV']==50]

# %%
df=df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg([np.average])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df['average']
# Out:
# STNAME
# Alabama                  71339.343284
# Alaska                   24490.724138
# Arizona                 426134.466667
# Arkansas                 38878.906667
# California              642309.586207
# Colorado                 78581.187500
# Connecticut             446762.125000
# Delaware                299311.333333
# District of Columbia    601723.000000
# Florida                 280616.567164
# Georgia                  60928.635220
# Hawaii                  272060.200000
# Idaho                    35626.863636
# Illinois                125790.509804
# Indiana                  70476.108696
# Iowa                     30771.262626
# Kansas                   27172.552381
# Kentucky                 36161.391667
# Louisiana                70833.937500
# Maine                    83022.562500
# Maryland                240564.666667
# Massachusetts           467687.785714
# Michigan                119080.000000
# Minnesota                60964.655172
# ...

# %%
pd.cut(df['average'],10)
# Out:
# STNAME
# Alabama                   (11706.087, 75333.413]
# Alaska                    (11706.087, 75333.413]
# Arizona                 (390320.176, 453317.529]
# Arkansas                  (11706.087, 75333.413]
# California              (579312.234, 642309.586]
# Colorado                 (75333.413, 138330.766]
# Connecticut             (390320.176, 453317.529]
# Delaware                (264325.471, 327322.823]
# District of Columbia    (579312.234, 642309.586]
# Florida                 (264325.471, 327322.823]
# Georgia                   (11706.087, 75333.413]
# Hawaii                  (264325.471, 327322.823]
# Idaho                     (11706.087, 75333.413]
# Illinois                 (75333.413, 138330.766]
# Indiana                   (11706.087, 75333.413]
# Iowa                      (11706.087, 75333.413]
# Kansas                    (11706.087, 75333.413]
# Kentucky                  (11706.087, 75333.413]
# Louisiana                 (11706.087, 75333.413]
# ...

# %%
df1=pd.DataFrame([{'Name':'Maher','age':24},
                  {'Name':'Sunny','age':50},
                  {'Name':'Nasima','age':42},
                  {'Name':'ALIUR','age':54}])

# %%
df1
# Out:
#      Name  age
# 0   Maher   24
# 1   Sunny   50
# 2  Nasima   42
# 3   ALIUR   54

# %%
df1['age_group']=pd.cut(df1['age'],bins=[20,30,40,50,60],
                       labels=['20-30','30-40','40-50','50-60'])

# %%
df1
# Out:
#      Name  age age_group
# 0   Maher   24     20-30
# 1   Sunny   50     40-50
# 2  Nasima   42     40-50
# 3   ALIUR   54     50-60

# %%
df1.loc[1]['age']=50
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df1['age']
# Out:
# 0    24
# 1    50
# 2    42
# 3    54
# Name: age, dtype: int64

# %%
pd.cut(df1['age'],bins=10)
# Out:
# 0    (23.97, 27.0]
# 1     (48.0, 51.0]
# 2     (39.0, 42.0]
# 3     (51.0, 54.0]
# Name: age, dtype: category
# Categories (10, interval[float64]): [(23.97, 27.0] < (27.0, 30.0] < (30.0, 33.0] < (33.0, 36.0] ... (42.0, 45.0] < (45.0, 48.0] < (48.0, 51.0] < (51.0, 54.0]]

# %%
pd.cut(df['average'],bins=3,labels=['small','medium','large'])
# Out:
# STNAME
# Alabama                  small
# Alaska                   small
# Arizona                 medium
# Arkansas                 small
# California               large
# Colorado                 small
# Connecticut              large
# Delaware                medium
# District of Columbia     large
# Florida                 medium
# Georgia                  small
# Hawaii                  medium
# Idaho                    small
# Illinois                 small
# Indiana                  small
# Iowa                     small
# Kansas                   small
# Kentucky                 small
# Louisiana                small
# Maine                    small
# Maryland                medium
# Massachusetts            large
# Michigan                 small
# Minnesota                small
# Mississippi              small
# Missouri                 small
# Montana                  small
# Nebraska                 small
# Nevada                   small
# New Hampshire            small
# ...

# %%
df1
# Out:
#      Name  age age_group
# 0   Maher   24     20-30
# 1   Sunny   50     40-50
# 2  Nasima   42     40-50
# 3   ALIUR   54     50-60

# %%
del[df1['age_group']]

# %%
df1
# Out:
#      Name  age
# 0   Maher   24
# 1   Sunny   50
# 2  Nasima   42
# 3   ALIUR   54

# %%
df1['age_group']=pd.cut(df1['age'],bins=4,labels=['20-30','30-40','40-50','50-60'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-48f62dab3e18> in <module>
# ----> 1 df1['age_group']=pd.cut(df1['age'],bins=4,labels=['20-30','30-40','40-50','50-60'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates)
#     221
#     222         rng = (nanops.nanmin(x), nanops.nanmax(x))
# --> 223         mn, mx = [mi + 0.0 for mi in rng]
#     224
#     225         if np.isinf(mn) or np.isinf(mx):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\tile.py in <listcomp>(.0)
#     221
#     222         rng = (nanops.nanmin(x), nanops.nanmax(x))
# --> 223         mn, mx = [mi + 0.0 for mi in rng]
#     224
#     225         if np.isinf(mn) or np.isinf(mx):
#
# TypeError: can only concatenate str (not "float") to str

# %%
df1
# Out:
#      Name    age
# 0   Maher  20-30
# 1   Sunny  50-60
# 2  Nasima  40-50
# 3   ALIUR  50-60

# %%
df1=pd.DataFrame([{'Name':'Maher','age':24},
                  {'Name':'Sunny','age':50},
                  {'Name':'Nasima','age':42},
                  {'Name':'ALIUR','age':54}])

# %%
df1
# Out:
#      Name  age
# 0   Maher   24
# 1   Sunny   50
# 2  Nasima   42
# 3   ALIUR   54

# %%
df1['age_group']=pd.cut(df1['age'],bins=3,
                       labels=['20-30','40-50','50-60'])

# %%
df1
# Out:
#      Name  age age_group
# 0   Maher   24     20-30
# 1   Sunny   50     50-60
# 2  Nasima   42     40-50
# 3   ALIUR   54     50-60

# %%
df=pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
df.pivot_table(values='(kW)',index='YEAR',columns='Make',aggfunc=np.mean)
# Out:
# Make    BMW  CHEVROLET   FORD   KIA  MITSUBISHI  NISSAN  SMART       TESLA
# YEAR
# 2012    NaN        NaN    NaN   NaN        49.0    80.0    NaN         NaN
# 2013    NaN        NaN  107.0   NaN        49.0    80.0   35.0  280.000000
# 2014    NaN      104.0  107.0   NaN        49.0    80.0   35.0  268.333333
# 2015  125.0      104.0  107.0  81.0        49.0    80.0   35.0  320.666667
# 2016  125.0      104.0  107.0  81.0        49.0    80.0   35.0  409.700000

# %%
df['YEAR'].unique()
# Out:
# array([2012, 2013, 2014, 2015, 2016], dtype=int64)

# %%
df['Make'].unique()
# Out:
# array(['MITSUBISHI', 'NISSAN', 'FORD', 'SMART', 'TESLA', 'CHEVROLET',
#        'BMW', 'KIA'], dtype=object)

# %%
df[df['Make']=='BMW']
# Out:
#     YEAR Make Model        Size  (kW) Unnamed: 5 TYPE  CITY (kWh/100 km)  \
# 20  2015  BMW    i3  SUBCOMPACT   125         A1    B               15.2
# 34  2016  BMW    i3  SUBCOMPACT   125         A1    B               15.2
#
#     HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  HWY (Le/100 km)  \
# 20              18.8               16.8               1.7              2.1
# 34              18.8               16.8               1.7              2.1
#
#     COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# 20               1.9       0     NaN   130         4
# 34               1.9       0    10.0   130         4

# %%
df[df['Make']=='MITSUBISHI']
# Out:
#     YEAR        Make   Model        Size  (kW) Unnamed: 5 TYPE  \
# 0   2012  MITSUBISHI  i-MiEV  SUBCOMPACT    49         A1    B
# 3   2013  MITSUBISHI  i-MiEV  SUBCOMPACT    49         A1    B
# 13  2014  MITSUBISHI  i-MiEV  SUBCOMPACT    49         A1    B
# 24  2015  MITSUBISHI  i-MiEV  SUBCOMPACT    49         A1    B
# 38  2016  MITSUBISHI  i-MiEV  SUBCOMPACT    49         A1    B
#
#     CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0                16.9              21.4               18.7               1.9
# 3                16.9              21.4               18.7               1.9
# 13               16.9              21.4               18.7               1.9
# 24               16.9              21.4               18.7               1.9
# 38               16.9              21.4               18.7               1.9
#
#     HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
df.pivot_table(values='CITY (kWh/100 km)',index='Make',columns='YEAR',aggfunc=np.mean)
# Out:
# YEAR        2012    2013  2014       2015   2016
# Make
# BMW          NaN     NaN   NaN  15.200000  15.20
# CHEVROLET    NaN     NaN  16.0  16.000000  16.00
# FORD         NaN  19.000  19.0  19.000000  19.00
# KIA          NaN     NaN   NaN  17.500000  17.50
# MITSUBISHI  16.9  16.900  16.9  16.900000  16.90
# NISSAN      19.3  19.300  16.5  16.500000  16.75
# SMART        NaN  17.200  17.2  17.200000  17.20
# TESLA        NaN  23.075  23.3  22.666667  22.65

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
df.pivot_table(values='(kW)',index='YEAR',columns='Make',aggfunc=[np.mean,np.sum,np.max,np.min])
# Out:
#        mean                                                               sum  \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA    BMW
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN    NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000    NaN
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333    NaN
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667  125.0
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000  125.0
#
#                 ...  amax          amin                                    \
# Make CHEVROLET  ... SMART  TESLA    BMW CHEVROLET   FORD   KIA MITSUBISHI
# YEAR            ...
# 2012       NaN  ...   NaN    NaN    NaN       NaN    NaN   NaN       49.0
# 2013       NaN  ...  35.0  310.0    NaN       NaN  107.0   NaN       49.0
# 2014     104.0  ...  35.0  310.0    NaN     104.0  107.0   NaN       49.0
# ...

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
df[df['Make']=='NISSAN']
# Out:
#     YEAR    Make                  Model      Size  (kW) Unnamed: 5 TYPE  \
# 1   2012  NISSAN                   LEAF  MID-SIZE    80         A1    B
# 4   2013  NISSAN                   LEAF  MID-SIZE    80         A1    B
# 14  2014  NISSAN                   LEAF  MID-SIZE    80         A1    B
# 25  2015  NISSAN                   LEAF  MID-SIZE    80         A1    B
# 39  2016  NISSAN  LEAF (24 kWh battery)  MID-SIZE    80         A1    B
# 40  2016  NISSAN  LEAF (30 kWh battery)  MID-SIZE    80         A1    B
#
#     CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 1                19.3              23.0               21.1               2.2
# 4                19.3              23.0               21.1               2.2
# 14               16.5              20.8               18.4               1.9
# 25               16.5              20.8               18.4               1.9
# 39               16.5              20.8               18.4               1.9
# ...

# %%
df=df.pivot_table(values='(kW)',index='YEAR',columns='Make',aggfunc=np.mean)

# %%
df.loc[2016]
# Out:
# Make
# BMW           125.0
# CHEVROLET     104.0
# FORD          107.0
# KIA            81.0
# MITSUBISHI     49.0
# NISSAN         80.0
# SMART          35.0
# TESLA         409.7
# Name: 2016, dtype: float64

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
               index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])
df
# Out:
#             0
# excellent  A+
# excellent   A
# excellent  A-
# good       B+
# good        B
# good       B-
# ok         C+
# ok          C
# ok         C-
# poor       D+
# poor        D

# %%
df.rename(columns={0:'Grades'},inplace=True)

# %%
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades'].astype('category')
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
df['Grades']=pd.Categorical(df['Grades'],['D', 'D+', 'C-', 'C', 'C+', 'B-', 'B', 'B+', 'A-', 'A', 'A+'],
                           ordered=True)

# %%
df['Grades']
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [D < D+ < C- < C ... B+ < A- < A < A+]

# %%
df['Grades']>'B-'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good         False
# ok           False
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
df1=pd.DataFrame([{'Name':'Maher','age':24},
                  {'Name':'Sunny','age':34},
                  {'Name':'Nasima','age':42},
                  {'Name':'ALIUR','age':54}])

# %%
df1
# Out:
#      Name  age
# 0   Maher   24
# 1   Sunny   34
# 2  Nasima   42
# 3   ALIUR   54

# %%
df1['age_group']=pd.cut(df1['age'],bins=4,labels=['20-30','30-40','40-50','50-60'])

# %%
df1
# Out:
#      Name  age age_group
# 0   Maher   24     20-30
# 1   Sunny   34     30-40
# 2  Nasima   42     40-50
# 3   ALIUR   54     50-60

# %%
df=pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
df.pivot_table(values='(kW)',index='YEAR',columns='Make',aggfunc=[np.mean,np.max,np.min],margins=True)
# Out:
#        mean                                                             \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000
# All   125.0     104.0  107.0  81.0       49.0   80.0  35.0  345.478261
#
#                    amax  ...        amin                                    \
# Make         All    BMW  ...  All    BMW CHEVROLET   FORD   KIA MITSUBISHI
# YEAR                     ...
# 2012   64.500000    NaN  ...   80    NaN       NaN    NaN   NaN       49.0
# 2013  158.444444    NaN  ...  310    NaN       NaN  107.0   NaN       49.0
# ...

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.pivot_table(values='Fare',index='PassengerId',columns='Name',aggfunc=np.max)
# Out:
# Name         Abbing, Mr. Anthony  Abbott, Mr. Rossmore Edward  \
# PassengerId
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                            NaN                          NaN
# 5                            NaN                          NaN
# ...                          ...                          ...
# 887                          NaN                          NaN
# 888                          NaN                          NaN
# 889                          NaN                          NaN
# 890                          NaN                          NaN
# 891                          NaN                          NaN
#
# Name         Abbott, Mrs. Stanton (Rosa Hunt)  Abelson, Mr. Samuel  \
# PassengerId
# 1                                         NaN                  NaN
# ...

# %%
pd.Timestamp('9/1/2016 10:05AM')
# Out:
# Timestamp('2016-09-01 10:05:00')

# %%
pd.Timestamp('6/7/2020 12:21PM')
# Out:
# Timestamp('2020-06-07 12:21:00')

# %%
pd.Period('1/2016')
# Out:
# Period('2016-01', 'M')

# %%
pd.Period('6/7/2020')
# Out:
# Period('2020-06-07', 'D')

# %%
t1=pd.Series(list('abc'),[pd.Timestamp('4/7/2020'),pd.Timestamp('5/7/2020'),
                         pd.Timestamp('6/7/2020')])

# %%
t1
# Out:
# 2020-04-07    a
# 2020-05-07    b
# 2020-06-07    c
# dtype: object

# %%
type(t1.index)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
t2=pd.Series(list('def'),[pd.Period('2016-09'),pd.Period('2016-10'),pd.Period('2016-11')])

# %%
t2
# Out:
# 2016-09    d
# 2016-10    e
# 2016-11    f
# Freq: M, dtype: object

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']

# %%
ts3=pd.DataFrame(np.random.randint(10,100,(4,2)),index=d1,columns=list('ab'))

# %%
ts3
# Out:
#                a   b
# 2 June 2013   74  25
# Aug 29, 2014  24  53
# 2015-06-26    31  50
# 7/12/16       89  14

# %%
ts3.index=pd.to_datetime(ts3.index)

# %%
ts3
# Out:
#              a   b
# 2013-06-02  74  25
# 2014-08-29  24  53
# 2015-06-26  31  50
# 2016-07-12  89  14

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16','june 6,2020','july 7,2020']

# %%
ts3=pd.DataFrame(np.random.randint(10,100,(6,3)),index=d1,columns=list('abc'))

# %%
ts3
# Out:
#                a   b   c
# 2 June 2013   54  17  76
# Aug 29, 2014  91  52  87
# 2015-06-26    13  59  42
# 7/12/16       41  60  54
# june 6,2020   71  45  60
# july 7,2020   91  61  71

# %%
ts3.index=pd.to_datetime(ts3.index)

# %%
ts3
# Out:
#              a   b   c
# 2013-06-02  54  17  76
# 2014-08-29  91  52  87
# 2015-06-26  13  59  42
# 2016-07-12  41  60  54
# 2020-06-06  71  45  60
# 2020-07-07  91  61  71

# %%
pd.Timestamp(7/6/2020)-pd.Timestamp(3/6/2020)
# Out:
# Timedelta('0 days 00:00:00')

# %%
pd.Timestamp(9/3/2016)-pd.Timestamp(9/1/2016)
# Out:
# Timedelta('0 days 00:00:00')

# %%
pd.Timestamp('9/3/2016')-pd.Timestamp('9/1/2016')
# Out:
# Timedelta('2 days 00:00:00')

# %%
pd.Timestamp('6/7/2020')-pd.Timestamp('6/3/2020')
# Out:
# Timedelta('4 days 00:00:00')

# %%
pd.Timestamp('6/7/2020 6:16AM')+pd.Timedelta('3d 3H')
# Out:
# Timestamp('2020-06-10 09:16:00')

# %%
pd.Timestamp('6/7/2020 8:10AM')-pd.Timestamp('6/1/2020 6:00PM')
# Out:
# Timedelta('5 days 14:10:00')

# %%
pd.Timestamp('1/10/2016')-pd.Timestamp('1/10/2015')
# Out:
# Timedelta('365 days 00:00:00')

# %%
pd.Timestamp('6/7/2020 8:20AM')+pd.Timedelta('3d 3H')
# Out:
# Timestamp('2020-06-10 11:20:00')

# %%
dates=pd.date_range('1/1/2016',periods=9,freq='2w-SUN')

# %%
dates
# Out:
# DatetimeIndex(['2016-01-03', '2016-01-17', '2016-01-31', '2016-02-14',
#                '2016-02-28', '2016-03-13', '2016-03-27', '2016-04-10',
#                '2016-04-24'],
#               dtype='datetime64[ns]', freq='2W-SUN')

# %%
df=pd.DataFrame({'count1':100+np.random.randint(-3,10,9).cumsum(),
                 'count2':120+np.random.randint(-3,10,9)},index=dates)

# %%
df
# Out:
#             count1  count2
# 2016-01-03     100     118
# 2016-01-17     106     119
# 2016-01-31     109     119
# 2016-02-14     114     119
# 2016-02-28     111     122
# 2016-03-13     120     127
# 2016-03-27     121     121
# 2016-04-10     121     122
# 2016-04-24     119     120

# %%
df.index.Weekday_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-178-8330fd4d739c> in <module>
# ----> 1 df.index.Weekday_name
#
# AttributeError: 'DatetimeIndex' object has no attribute 'Weekday_name'

# %%
df.index.weekday_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-179-89e418acb61d> in <module>
# ----> 1 df.index.weekday_name
#
# AttributeError: 'DatetimeIndex' object has no attribute 'weekday_name'

# %%
df.diff()
# Out:
#             count1  count2
# 2016-01-03     NaN     NaN
# 2016-01-17     6.0     1.0
# 2016-01-31     3.0     0.0
# 2016-02-14     5.0     0.0
# 2016-02-28    -3.0     3.0
# 2016-03-13     9.0     5.0
# 2016-03-27     1.0    -6.0
# 2016-04-10     0.0     1.0
# 2016-04-24    -2.0    -2.0

# %%
df
# Out:
#             count1  count2
# 2016-01-03     100     118
# 2016-01-17     106     119
# 2016-01-31     109     119
# 2016-02-14     114     119
# 2016-02-28     111     122
# 2016-03-13     120     127
# 2016-03-27     121     121
# 2016-04-10     121     122
# 2016-04-24     119     120

# %%
df.resample('M').mean()
# Out:
#             count1      count2
# 2016-01-31   105.0  118.666667
# 2016-02-29   112.5  120.500000
# 2016-03-31   120.5  124.000000
# 2016-04-30   120.0  121.000000

# %%
df['2016-01']
# Out:
#             count1  count2
# 2016-01-03     100     118
# 2016-01-17     106     119
# 2016-01-31     109     119

# %%
df
# Out:
#             count1  count2
# 2016-01-03     100     118
# 2016-01-17     106     119
# 2016-01-31     109     119
# 2016-02-14     114     119
# 2016-02-28     111     122
# 2016-03-13     120     127
# 2016-03-27     121     121
# 2016-04-10     121     122
# 2016-04-24     119     120

# %%
df['2016-03']
# Out:
#             count1  count2
# 2016-03-13     120     127
# 2016-03-27     121     121

# %%
df['2016-03-27':]
# Out:
#             count1  count2
# 2016-03-27     121     121
# 2016-04-10     121     122
# 2016-04-24     119     120

# %%
df.asfreq('W',method='ffill')
# Out:
#             count1  count2
# 2016-01-03     100     118
# 2016-01-10     100     118
# 2016-01-17     106     119
# 2016-01-24     106     119
# 2016-01-31     109     119
# 2016-02-07     109     119
# 2016-02-14     114     119
# 2016-02-21     114     119
# 2016-02-28     111     122
# 2016-03-06     111     122
# 2016-03-13     120     127
# 2016-03-20     120     127
# 2016-03-27     121     121
# 2016-04-03     121     121
# 2016-04-10     121     122
# 2016-04-17     121     122
# 2016-04-24     119     120

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.plot()

# %%
df
# Out:
#             count1  count2
# 2016-01-03     100     118
# 2016-01-17     106     119
# 2016-01-31     109     119
# 2016-02-14     114     119
# 2016-02-28     111     122
# 2016-03-13     120     127
# 2016-03-27     121     121
# 2016-04-10     121     122
# 2016-04-24     119     120

# %%
df.asfreq('W',method='ffill')
# Out:
#             count1  count2
# 2016-01-03     100     118
# 2016-01-10     100     118
# 2016-01-17     106     119
# 2016-01-24     106     119
# 2016-01-31     109     119
# 2016-02-07     109     119
# 2016-02-14     114     119
# 2016-02-21     114     119
# 2016-02-28     111     122
# 2016-03-06     111     122
# 2016-03-13     120     127
# 2016-03-20     120     127
# 2016-03-27     121     121
# 2016-04-03     121     121
# 2016-04-10     121     122
# 2016-04-17     121     122
# 2016-04-24     119     120

# %%
pd.Timestamp('1/6/2020 10:08 AM')
# Out:
# Timestamp('2020-01-06 10:08:00')

# %%
pd.Period('2016-01-11')
# Out:
# Period('2016-01-11', 'D')

# %%
t1=pd.Series(list('abc'),[pd.Timestamp('1/6/2020'),pd.Timestamp('2/6/2020'),pd.Timestamp('3/6/2020')])

# %%
t1
# Out:
# 2020-01-06    a
# 2020-02-06    b
# 2020-03-06    c
# dtype: object

# %% [markdown]
# t1.index

# %%
t1.index
# Out:
# DatetimeIndex(['2020-01-06', '2020-02-06', '2020-03-06'], dtype='datetime64[ns]', freq=None)

# %%
t2=pd.Series(list('def'),[pd.Period('2020-01-01'),pd.Period('2020-01-02'),pd.Period('2020-01-03')])

# %%
t2
# Out:
# 2020-01-01    d
# 2020-01-02    e
# 2020-01-03    f
# Freq: D, dtype: object

# %%
d1=['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
ts1=pd.DataFrame(np.random.randint(1,100,(4,2)),columns=list('ab'),index=d1)

# %%
ts1.index=pd.to_datetime(ts1.index)

# %%
ts1
# Out:
#              a   b
# 2013-06-02  66  83
# 2014-08-29  72  39
# 2015-06-26  65  28
# 2016-07-12  61  43

# %%
pd.to_datetime('6.7.2020',dayfirst=True)
# Out:
# Timestamp('2020-07-06 00:00:00')

# %%
pd.Timestamp('6/7/2020')-pd.Timestamp('6/2/2020')
# Out:
# Timedelta('5 days 00:00:00')

# %%
pd.Timestamp('6/7/2020')+pd.Timedelta('3d')
# Out:
# Timestamp('2020-06-10 00:00:00')

# %%
dates=pd.date_range('01/10/2016',periods=8,freq='1W-SAT')

# %%
dates
# Out:
# DatetimeIndex(['2016-01-16', '2016-01-23', '2016-01-30', '2016-02-06',
#                '2016-02-13', '2016-02-20', '2016-02-27', '2016-03-05'],
#               dtype='datetime64[ns]', freq='W-SAT')

# %%
df=pd.DataFrame({'col1':100+np.random.randint(-5,10,8).cumsum(),
                 'col2':200+np.random.randint(-5,10,8)},index=dates)

# %%
df
# Out:
#             col1  col2
# 2016-01-16   108   199
# 2016-01-23   111   196
# 2016-01-30   108   200
# 2016-02-06   112   208
# 2016-02-13   117   198
# 2016-02-20   117   201
# 2016-02-27   112   198
# 2016-03-05   109   195

# %%
df.diff()
# Out:
#             col1  col2
# 2016-01-16   NaN   NaN
# 2016-01-23   3.0  -3.0
# 2016-01-30  -3.0   4.0
# 2016-02-06   4.0   8.0
# 2016-02-13   5.0 -10.0
# 2016-02-20   0.0   3.0
# 2016-02-27  -5.0  -3.0
# 2016-03-05  -3.0  -3.0

# %%
df.diff()
# Out:
#             col1  col2
# 2016-01-16   NaN   NaN
# 2016-01-23   3.0  -3.0
# 2016-01-30  -3.0   4.0
# 2016-02-06   4.0   8.0
# 2016-02-13   5.0 -10.0
# 2016-02-20   0.0   3.0
# 2016-02-27  -5.0  -3.0
# 2016-03-05  -3.0  -3.0

# %%
df.resample('M').mean()
# Out:
#              col1        col2
# 2016-01-31  109.0  198.333333
# 2016-02-29  114.5  201.250000
# 2016-03-31  109.0  195.000000

# %%
df['2016-01']
# Out:
#             col1  col2
# 2016-01-16   108   199
# 2016-01-23   111   196
# 2016-01-30   108   200

# %%
df['2016-01-30':]
# Out:
#             col1  col2
# 2016-01-30   108   200
# 2016-02-06   112   208
# 2016-02-13   117   198
# 2016-02-20   117   201
# 2016-02-27   112   198
# 2016-03-05   109   195

# %%
df.plot()

# %%
df
# Out:
#             col1  col2
# 2016-01-16   108   199
# 2016-01-23   111   196
# 2016-01-30   108   200
# 2016-02-06   112   208
# 2016-02-13   117   198
# 2016-02-20   117   201
# 2016-02-27   112   198
# 2016-03-05   109   195

# %%
df.asfreq('2W',method='ffill')
# Out:
#             col1  col2
# 2016-01-17   108   199
# 2016-01-31   108   200
# 2016-02-14   117   198
# 2016-02-28   112   198

# %%
df=pd.DataFrame([{'Name': 'Chris', 'Item Purchased': 'Sponge', 'Cost': 22.50},
                   {'Name': 'Kevyn', 'Item Purchased': 'Kitty Litter', 'Cost': 2.50},
                   {'Name': 'Filip', 'Item Purchased': 'Spoon', 'Cost': 5.00}],
                  index=['Store 1', 'Store 1', 'Store 2'])

# %%
df
# Out:
#           Name Item Purchased  Cost
# Store 1  Chris         Sponge  22.5
# Store 1  Kevyn   Kitty Litter   2.5
# Store 2  Filip          Spoon   5.0

# %%
df['Date']=['January 1','February 14','March 20']

# %%
df
# Out:
#           Name Item Purchased  Cost         Date
# Store 1  Chris         Sponge  22.5    January 1
# Store 1  Kevyn   Kitty Litter   2.5  February 14
# Store 2  Filip          Spoon   5.0     March 20

# %%
df['Delivered']=True

# %%
df['Feedback']=['positive','Negative',None]

# %%
df
# Out:
#           Name Item Purchased  Cost         Date  Delivered  Feedback
# Store 1  Chris         Sponge  22.5    January 1       True  positive
# Store 1  Kevyn   Kitty Litter   2.5  February 14       True  Negative
# Store 2  Filip          Spoon   5.0     March 20       True      None

# %%
adf=df.reset_index()

# %%
adf
# Out:
#      index   Name Item Purchased  Cost         Date  Delivered  Feedback
# 0  Store 1  Chris         Sponge  22.5    January 1       True  positive
# 1  Store 1  Kevyn   Kitty Litter   2.5  February 14       True  Negative
# 2  Store 2  Filip          Spoon   5.0     March 20       True      None

# %%
adf['Date']=pd.Series({0:'January 30',1:'February 28'})

# %%
adf
# Out:
#      index   Name Item Purchased  Cost         Date  Delivered  Feedback
# 0  Store 1  Chris         Sponge  22.5   January 30       True  positive
# 1  Store 1  Kevyn   Kitty Litter   2.5  February 28       True  Negative
# 2  Store 2  Filip          Spoon   5.0          NaN       True      None

# %%
staff_df=pd.DataFrame([
    {'Name': 'Kelly', 'Role': 'Director of HR'},
                         {'Name': 'Sally', 'Role': 'Course liasion'},
                         {'Name': 'James', 'Role': 'Grader'}
])

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
staff_df=staff_df.set_index('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-267-35e774dd176a> in <module>
# ----> 1 staff_df=staff_df.set_index('Name')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Name'] are in the columns"

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
student_df=pd.DataFrame([{'Name': 'James', 'School': 'Business'},
                           {'Name': 'Mike', 'School': 'Law'},
                           {'Name': 'Sally', 'School': 'Engineering'}])

# %%
student_df=student_df.set_index('Name')

# %%
pd.merge(staff_df,student_df,how='outer',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Kelly  Director of HR          NaN
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
student_df
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df,student_df,how='inner',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
staff_df
# Out:
#                  Role
# Name
# Kelly  Director of HR
# Sally  Course liasion
# James          Grader

# %%
student_df
# Out:
#             School
# Name
# James     Business
# Mike           Law
# Sally  Engineering

# %%
pd.merge(staff_df,student_df,how='left',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# Kelly  Director of HR          NaN
# Sally  Course liasion  Engineering
# James          Grader     Business

# %%
pd.merge(staff_df,student_df,how='right',left_index=True,right_index=True)
# Out:
#                  Role       School
# Name
# James          Grader     Business
# Mike              NaN          Law
# Sally  Course liasion  Engineering

# %%
staff_df=staff_df.reset_index()

# %%
student_df=student_df.reset_index()

# %%
pd.merge(staff_df,student_df,how='outer',left_on='Name',right_on='Name')
# Out:
#     Name            Role       School
# 0  Kelly  Director of HR          NaN
# 1  Sally  Course liasion  Engineering
# 2  James          Grader     Business
# 3   Mike             NaN          Law

# %%
staff_df = pd.DataFrame([{'Name': 'Kelly', 'Role': 'Director of HR', 'Location': 'State Street'},
                         {'Name': 'Sally', 'Role': 'Course liasion', 'Location': 'Washington Avenue'},
                         {'Name': 'James', 'Role': 'Grader', 'Location': 'Washington Avenue'}])
student_df = pd.DataFrame([{'Name': 'James', 'School': 'Business', 'Location': '1024 Billiard Avenue'},
                           {'Name': 'Mike', 'School': 'Law', 'Location': 'Fraternity House #22'},
                           {'Name': 'Sally', 'School': 'Engineering', 'Location': '512 Wilson Crescent'}])

# %%
staff_df
# Out:
#     Name            Role           Location
# 0  Kelly  Director of HR       State Street
# 1  Sally  Course liasion  Washington Avenue
# 2  James          Grader  Washington Avenue

# %%
student_df
# Out:
#     Name       School              Location
# 0  James     Business  1024 Billiard Avenue
# 1   Mike          Law  Fraternity House #22
# 2  Sally  Engineering   512 Wilson Crescent

# %%
pd.merge(staff_df,student_df,how='outer',left_on='Name',right_on='Name')
# Out:
#     Name            Role         Location_x       School            Location_y
# 0  Kelly  Director of HR       State Street          NaN                   NaN
# 1  Sally  Course liasion  Washington Avenue  Engineering   512 Wilson Crescent
# 2  James          Grader  Washington Avenue     Business  1024 Billiard Avenue
# 3   Mike             NaN                NaN          Law  Fraternity House #22

# %%
staff_df = pd.DataFrame([{'First Name': 'Kelly', 'Last Name': 'Desjardins', 'Role': 'Director of HR'},
                         {'First Name': 'Sally', 'Last Name': 'Brooks', 'Role': 'Course liasion'},
                         {'First Name': 'James', 'Last Name': 'Wilde', 'Role': 'Grader'}])
student_df = pd.DataFrame([{'First Name': 'James', 'Last Name': 'Hammond', 'School': 'Business'},
                           {'First Name': 'Mike', 'Last Name': 'Smith', 'School': 'Law'},
                           {'First Name': 'Sally', 'Last Name': 'Brooks', 'School': 'Engineering'}])

# %%
staff_df
# Out:
#   First Name   Last Name            Role
# 0      Kelly  Desjardins  Director of HR
# 1      Sally      Brooks  Course liasion
# 2      James       Wilde          Grader

# %%
student_df
# Out:
#   First Name Last Name       School
# 0      James   Hammond     Business
# 1       Mike     Smith          Law
# 2      Sally    Brooks  Engineering

# %%
pd.merge(staff_df,student_df,how='left',left_on=['First Name','Last Name'],right_on=['First Name','Last Name'])
# Out:
#   First Name   Last Name            Role       School
# 0      Kelly  Desjardins  Director of HR          NaN
# 1      Sally      Brooks  Course liasion  Engineering
# 2      James       Wilde          Grader          NaN

# %%
product_df=pd.DataFrame([{'Product Id':4109,'Price':5.0,'Product':'Sushi Roll'},
                         {'Product Id':1412,'Price':0.5,'Product':'Egg'},
                         {'Product Id':8931,'Price':1.5,'Product':'Bagei'}])

# %%
product_df
# Out:
#    Product Id  Price     Product
# 0        4109    5.0  Sushi Roll
# 1        1412    0.5         Egg
# 2        8931    1.5       Bagei

# %%
invoices_df=pd.DataFrame([{'Customer':'Ali','Product Id':4109,'Quantity':1},
                          {'Customer':'Eric','Product Id':1412,'Quantity':12},
                          {'Customer':'Ande','Product Id':8931,'Quantity':6},
                          {'Customer':'Sam','Product Id':4109,'Quantity':2}])

# %%
invoices_df
# Out:
#   Customer  Product Id  Quantity
# 0      Ali        4109         1
# 1     Eric        1412        12
# 2     Ande        8931         6
# 3      Sam        4109         2

# %%
df=pd.merge(product_df,invoices_df,how='inner',left_on='Product Id',right_on='Product Id')

# %%
df
# Out:
#    Product Id  Price     Product Customer  Quantity
# 0        4109    5.0  Sushi Roll      Ali         1
# 1        4109    5.0  Sushi Roll      Sam         2
# 2        1412    0.5         Egg     Eric        12
# 3        8931    1.5       Bagei     Ande         6

# %%
df['Total']=df['Price']*df['Quantity']

# %%
df
# Out:
#    Product Id  Price     Product Customer  Quantity  Total
# 0        4109    5.0  Sushi Roll      Ali         1    5.0
# 1        4109    5.0  Sushi Roll      Sam         2   10.0
# 2        1412    0.5         Egg     Eric        12    6.0
# 3        8931    1.5       Bagei     Ande         6    9.0

# %%
df=pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.where(df['SUMLEV']==50).dropna().set_index(['STNAME','CTYNAME']).rename(columns={'ESTIMATESBASE2010':'ESTIMATE BASE 2010'}).head()
# Out:
#                         SUMLEV  REGION  DIVISION  STATE  COUNTY  \
# STNAME  CTYNAME
# Alabama Autauga County    50.0     3.0       6.0    1.0     1.0
#         Baldwin County    50.0     3.0       6.0    1.0     3.0
#         Barbour County    50.0     3.0       6.0    1.0     5.0
#         Bibb County       50.0     3.0       6.0    1.0     7.0
#         Blount County     50.0     3.0       6.0    1.0     9.0
#
#                         CENSUS2010POP  ESTIMATE BASE 2010  POPESTIMATE2010  \
# STNAME  CTYNAME
# Alabama Autauga County        54571.0             54571.0          54660.0
#         Baldwin County       182265.0            182265.0         183193.0
#         Barbour County        27457.0             27457.0          27341.0
#         Bibb County           22915.0             22919.0          22861.0
#         Blount County         57322.0             57322.0          57373.0
#
#                         POPESTIMATE2011  POPESTIMATE2012  ...  \
# ...

# %%
data=df[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014']]

# %%
data
# Out:
#       POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  POPESTIMATE2013  \
# 0             4785161          4801108          4816089          4830533
# 1               54660            55253            55175            55038
# 2              183193           186659           190396           195126
# 3               27341            27226            27159            26973
# 4               22861            22733            22642            22512
# ...               ...              ...              ...              ...
# 3188            43593            44041            45104            45162
# 3189            21297            21482            21697            22347
# 3190            21102            20912            20989            21022
# 3191             8545             8469             8443             8443
# 3192             7181             7114             7065             7160
#
#       POPESTIMATE2014
# 0             4846411
# 1               55290
# ...

# %%
np.min(data,axis=1)
# Out:
# 0       4785161
# 1         54660
# 2        183193
# 3         26815
# 4         22512
#          ...
# 3188      43593
# 3189      21297
# 3190      20903
# 3191       8316
# 3192       7065
# Length: 3193, dtype: int64

# %%
len(data)
# Out:
# 3193

# %%
def min_max(row):
    data=row[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014']]
    row['min']=np.min(data)
    row['max']=np.max(data)
    return pd.Series({'min':np.min(data),'max':np.max(data)})
df.apply(min_max,axis=1)
# Out:
#           min      max
# 0     4785161  4846411
# 1       54660    55290
# 2      183193   199713
# 3       26815    27341
# 4       22512    22861
# ...       ...      ...
# 3188    43593    45162
# 3189    21297    22905
# 3190    20903    21102
# 3191     8316     8545
# 3192     7065     7185
#
# [3193 rows x 2 columns]

# %%
rows=['POPESTIMATE2010',
        'POPESTIMATE2011',
        'POPESTIMATE2012',
        'POPESTIMATE2013',
        'POPESTIMATE2014',
        'POPESTIMATE2015']

# %%
df[['POPESTIMATE2010',
        'POPESTIMATE2011',
        'POPESTIMATE2012',
        'POPESTIMATE2013',
        'POPESTIMATE2014',
        'POPESTIMATE2015']].apply(lambda x:{'min':np.min(x),'max':np.max(x)},axis=1)
# Out:
# 0       {'min': 4785161, 'max': 4858979}
# 1           {'min': 54660, 'max': 55347}
# 2         {'min': 183193, 'max': 203709}
# 3           {'min': 26489, 'max': 27341}
# 4           {'min': 22512, 'max': 22861}
#                       ...
# 3188        {'min': 43593, 'max': 45162}
# 3189        {'min': 21297, 'max': 23125}
# 3190        {'min': 20822, 'max': 21102}
# 3191          {'min': 8316, 'max': 8545}
# 3192          {'min': 7065, 'max': 7234}
# Length: 3193, dtype: object

# %%
df.apply(lambda x:np.min(x[rows]),axis=1)
# Out:
# 0       4785161
# 1         54660
# 2        183193
# 3         26489
# 4         22512
#          ...
# 3188      43593
# 3189      21297
# 3190      20822
# 3191       8316
# 3192       7065
# Length: 3193, dtype: int64

# %%
df=df[df['SUMLEV']==50]

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
for state in df['STNAME'].unique():
    avg=np.average(df.where(df['STNAME']==state).dropna()['CENSUS2010POP'])
    print('Counties in state ' + state + ' have an average population of ' + str(avg))
# Out:
# Counties in state Alabama have an average population of 71339.34328358209
# Counties in state Alaska have an average population of 24490.724137931036
# Counties in state Arizona have an average population of 426134.4666666667
# Counties in state Arkansas have an average population of 38878.90666666667
# Counties in state California have an average population of 642309.5862068966
# Counties in state Colorado have an average population of 78581.1875
# Counties in state Connecticut have an average population of 446762.125
# Counties in state Delaware have an average population of 299311.3333333333
# Counties in state District of Columbia have an average population of 601723.0
# Counties in state Florida have an average population of 280616.5671641791
# Counties in state Georgia have an average population of 60928.63522012578
# Counties in state Hawaii have an average population of 272060.2
# Counties in state Idaho have an average population of 35626.86363636364
# ...

# %%
for group,frame in df.groupby('STNAME'):
    avg=np.average(frame['CENSUS2010POP'])
    print('state=',group,',population=',avg)
# Out:
# state= Alabama ,population= 71339.34328358209
# state= Alaska ,population= 24490.724137931036
# state= Arizona ,population= 426134.4666666667
# state= Arkansas ,population= 38878.90666666667
# state= California ,population= 642309.5862068966
# state= Colorado ,population= 78581.1875
# state= Connecticut ,population= 446762.125
# state= Delaware ,population= 299311.3333333333
# state= District of Columbia ,population= 601723.0
# state= Florida ,population= 280616.5671641791
# state= Georgia ,population= 60928.63522012578
# state= Hawaii ,population= 272060.2
# state= Idaho ,population= 35626.86363636364
# state= Illinois ,population= 125790.50980392157
# state= Indiana ,population= 70476.10869565218
# state= Iowa ,population= 30771.262626262625
# state= Kansas ,population= 27172.55238095238
# state= Kentucky ,population= 36161.39166666667
# state= Louisiana ,population= 70833.9375
# state= Maine ,population= 83022.5625
# state= Maryland ,population= 240564.66666666666
# ...

# %%
df['CENSUS2010POP'].apply(lambda x:np.average(x))
# Out:
# 1        54571.0
# 2       182265.0
# 3        27457.0
# 4        22915.0
# 5        57322.0
#           ...
# 3188     43806.0
# 3189     21294.0
# 3190     21118.0
# 3191      8533.0
# 3192      7208.0
# Name: CENSUS2010POP, Length: 3142, dtype: float64

# %%
df['CENSUS2010POP']
# Out:
# 1        54571
# 2       182265
# 3        27457
# 4        22915
# 5        57322
#          ...
# 3188     43806
# 3189     21294
# 3190     21118
# 3191      8533
# 3192      7208
# Name: CENSUS2010POP, Length: 3142, dtype: int64

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
# 5          57322              57322            57373  ...          1.807375
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg([np.max,np.average,np.sum])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                          amax        average       sum
# STNAME
# Alabama                658466   71339.343284   4779736
# Alaska                 291826   24490.724138    710231
# Arizona               3817117  426134.466667   6392017
# Arkansas               382748   38878.906667   2915918
# California            9818605  642309.586207  37253956
# Colorado               622263   78581.187500   5029196
# Connecticut            916829  446762.125000   3574097
# Delaware               538479  299311.333333    897934
# District of Columbia   601723  601723.000000    601723
# Florida               2496435  280616.567164  18801310
# ...

# %%
df1=df.groupby('STNAME')

# %%
df1

# %%
df1['CENSUS2010POP'].apply(lambda x:np.average(x))
# Out:
# STNAME
# Alabama                  71339.343284
# Alaska                   24490.724138
# Arizona                 426134.466667
# Arkansas                 38878.906667
# California              642309.586207
# Colorado                 78581.187500
# Connecticut             446762.125000
# Delaware                299311.333333
# District of Columbia    601723.000000
# Florida                 280616.567164
# Georgia                  60928.635220
# Hawaii                  272060.200000
# Idaho                    35626.863636
# Illinois                125790.509804
# Indiana                  70476.108696
# Iowa                     30771.262626
# Kansas                   27172.552381
# Kentucky                 36161.391667
# Louisiana                70833.937500
# Maine                    83022.562500
# Maryland                240564.666667
# Massachusetts           467687.785714
# Michigan                119080.000000
# Minnesota                60964.655172
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2010','POPESTIMATE2011'].agg([np.sum,np.average])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                      POPESTIMATE2010                POPESTIMATE2011  \
#                                  sum        average             sum
# STNAME
# Alabama                      4785161   71420.313433         4801108
# Alaska                        714021   24621.413793          722720
# Arizona                      6408208  427213.866667         6468732
# Arkansas                     2922394   38965.253333         2938538
# ...

# %%
df.groupby('STNAME')['POPESTIMATE2010','POPESTIMATE2011'].agg({'POPESTIMATE2010':np.average,'POPESTIMATE2011':np.sum})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                       POPESTIMATE2010  POPESTIMATE2011
# STNAME
# Alabama                  71420.313433          4801108
# Alaska                   24621.413793           722720
# Arizona                 427213.866667          6468732
# Arkansas                 38965.253333          2938538
# California              643691.017241         37700034
# Colorado                 78878.968750          5119480
# ...

# %%
df.groupby('STNAME').agg({'POPESTIMATE2010':[np.sum,np.average],'POPESTIMATE2011':[np.sum]})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#                      POPESTIMATE2010                POPESTIMATE2011
#                                  sum        average             sum
# STNAME
# Alabama                      4785161   71420.313433         4801108
# Alaska                        714021   24621.413793          722720
# Arizona                      6408208  427213.866667         6468732
# Arkansas                     2922394   38965.253333         2938538
# California                  37334079  643691.017241        37700034
# Colorado                     5048254   78878.968750         5119480
# Connecticut                  3579717  447464.625000         3589759
# ...

# %%
df=pd.DataFrame(['A+', 'A', 'A-', 'B+', 'B', 'B-', 'C+', 'C', 'C-', 'D+', 'D'],
               index=['excellent', 'excellent', 'excellent', 'good', 'good', 'good', 'ok', 'ok', 'ok', 'poor', 'poor'])

# %%
df=df.rename(columns={0:'Grades'})

# %%
df
# Out:
#           Grades
# excellent     A+
# excellent      A
# excellent     A-
# good          B+
# good           B
# good          B-
# ok            C+
# ok             C
# ok            C-
# poor          D+
# poor           D

# %%
df['Grades']
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: object

# %%
df['Grades']=df['Grades'].astype('category')

# %%
df['Grades']
# Out:
# excellent    A+
# excellent     A
# excellent    A-
# good         B+
# good          B
# good         B-
# ok           C+
# ok            C
# ok           C-
# poor         D+
# poor          D
# Name: Grades, dtype: category
# Categories (11, object): [A, A+, A-, B, ..., C+, C-, D, D+]

# %%
df['Grades']=pd.Categorical(df['Grades'],['D+','D','C-','C','C+','B-','B','B+','A-','A','A+'],
                           ordered=True)

# %%
df['Grades']>'C'
# Out:
# excellent     True
# excellent     True
# excellent     True
# good          True
# good          True
# good          True
# ok            True
# ok           False
# ok           False
# poor         False
# poor         False
# Name: Grades, dtype: bool

# %%
df=pd.read_csv('census.csv')

# %%
df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
# 2         182265             182265           183193  ...         14.832960
# 3          27457              27457            27341  ...         -4.728132
# 4          22915              22919            22861  ...         -5.527043
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
df=df[df['SUMLEV']==50]

# %%
df=df.set_index('STNAME').groupby(level=0)['CENSUS2010POP'].agg([np.average])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
df.head()
# Out:
#                   average
# STNAME
# Alabama      71339.343284
# Alaska       24490.724138
# Arizona     426134.466667
# Arkansas     38878.906667
# California  642309.586207

# %%
pd.cut(df['average'],3)
# Out:
# STNAME
# Alabama                  (11706.087, 222327.236]
# Alaska                   (11706.087, 222327.236]
# Arizona                 (222327.236, 432318.411]
# Arkansas                 (11706.087, 222327.236]
# California              (432318.411, 642309.586]
# Colorado                 (11706.087, 222327.236]
# Connecticut             (432318.411, 642309.586]
# Delaware                (222327.236, 432318.411]
# District of Columbia    (432318.411, 642309.586]
# Florida                 (222327.236, 432318.411]
# Georgia                  (11706.087, 222327.236]
# Hawaii                  (222327.236, 432318.411]
# Idaho                    (11706.087, 222327.236]
# Illinois                 (11706.087, 222327.236]
# Indiana                  (11706.087, 222327.236]
# Iowa                     (11706.087, 222327.236]
# Kansas                   (11706.087, 222327.236]
# Kentucky                 (11706.087, 222327.236]
# Louisiana                (11706.087, 222327.236]
# ...

# %%
df1=pd.DataFrame([{'Name':'Maher','age':24},
                  {'Name':'Sunny','age':50},
                  {'Name':'Nasima','age':35},
                  {'Name':'ALIUR','age':54}])

# %%
df1
# Out:
#      Name  age
# 0   Maher   24
# 1   Sunny   50
# 2  Nasima   35
# 3   ALIUR   54

# %%
df1['age_group']=pd.cut(df1['age'],bins=[20,30,40,50,60],
                       labels=['Small','Medium','Large','Extra large'])

# %%
df1
# Out:
#      Name  age    age_group
# 0   Maher   24        Small
# 1   Sunny   50        Large
# 2  Nasima   35       Medium
# 3   ALIUR   54  Extra large

# %%
df=pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
df.pivot_table(values='(kW)',index='YEAR',columns='Make',aggfunc=[np.mean,np.average])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#        mean                                                             \
# Make    BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# 2012    NaN       NaN    NaN   NaN       49.0   80.0   NaN         NaN
# 2013    NaN       NaN  107.0   NaN       49.0   80.0  35.0  280.000000
# 2014    NaN     104.0  107.0   NaN       49.0   80.0  35.0  268.333333
# 2015  125.0     104.0  107.0  81.0       49.0   80.0  35.0  320.666667
# 2016  125.0     104.0  107.0  81.0       49.0   80.0  35.0  409.700000
#
#      average
# Make     BMW CHEVROLET   FORD   KIA MITSUBISHI NISSAN SMART       TESLA
# YEAR
# ...

# %%
pd.Timestamp('6/8/2020 5:48PM')
# Out:
# Timestamp('2020-06-08 17:48:00')

# %%
pd.Period('2020/6')
# Out:
# Period('2020-06', 'M')

# %%
pd.Period('6/7/2020')
# Out:
# Period('2020-06-07', 'D')

# %%
t1=pd.Series(list('abc'),index=[pd.Timestamp('6/8/2020'),pd.Timestamp('7/8/2020'),
                               pd.Timestamp('8/8/2020')])

# %%
t1
# Out:
# 2020-06-08    a
# 2020-07-08    b
# 2020-08-08    c
# dtype: object

# %%
d1 = ['2 June 2013', 'Aug 29, 2014', '2015-06-26', '7/12/16']
ts3=pd.DataFrame(np.random.randint(0,10,(4,2)),index=d1,columns=list('ab'))

# %%
ts3
# Out:
#               a  b
# 2 June 2013   8  1
# Aug 29, 2014  1  6
# 2015-06-26    6  9
# 7/12/16       4  2

# %%
ts3.index=pd.to_datetime(ts3.index)

# %%
ts3
# Out:
#             a  b
# 2013-06-02  8  1
# 2014-08-29  1  6
# 2015-06-26  6  9
# 2016-07-12  4  2

# %%
pd.to_datetime('6.8.2020',dayfirst=True)
# Out:
# Timestamp('2020-08-06 00:00:00')

# %%
pd.Timestamp('6/8/2020')-pd.Timestamp('6/3/2020')
# Out:
# Timedelta('5 days 00:00:00')

# %%
pd.Timestamp('6/8/2020 12PM')+pd.Timedelta('3d 3h')
# Out:
# Timestamp('2020-06-11 15:00:00')

# %%
dates=pd.date_range('1/6/2016',periods=8,freq='2W-SUN')

# %%
df=pd.DataFrame(np.random.randint(-5,100,(8,2)),index=dates,columns=list('ab'))

# %%
df
# Out:
#              a   b
# 2016-01-10  58  21
# 2016-01-24  52  50
# 2016-02-07   1  89
# 2016-02-21  39  25
# 2016-03-06  50  63
# 2016-03-20  47   7
# 2016-04-03  52  53
# 2016-04-17  64  -4

# %%
df.diff()
# Out:
#                a     b
# 2016-01-10   NaN   NaN
# 2016-01-24  -6.0  29.0
# 2016-02-07 -51.0  39.0
# 2016-02-21  38.0 -64.0
# 2016-03-06  11.0  38.0
# 2016-03-20  -3.0 -56.0
# 2016-04-03   5.0  46.0
# 2016-04-17  12.0 -57.0

# %%
df.resample('M').mean()
# Out:
#                a     b
# 2016-01-31  55.0  35.5
# 2016-02-29  20.0  57.0
# 2016-03-31  48.5  35.0
# 2016-04-30  58.0  24.5

# %%
df['2016-02-21':]
# Out:
#              a   b
# 2016-02-21  39  25
# 2016-03-06  50  63
# 2016-03-20  47   7
# 2016-04-03  52  53
# 2016-04-17  64  -4

# %%
df.plot()

# %%
dates=pd.date_range('6/8/2020',periods=2,freq='1W-Fri')

# %%
enegy=aFrame([{'Name':'Maher','Age':25},
                 {'Name':'Sunny','Age':21}],index=dates)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-443-3152dec307e4> in <module>
# ----> 1 enegy=aFrame([{'Name':'Maher','Age':25},
#       2                  {'Name':'Sunny','Age':21}],index=dates)
#
# NameError: name 'aFrame' is not defined

# %%
df
# Out:
#              Name  Age
# 2020-06-12  Maher   25
# 2020-06-19  Sunny   21

# %%
energy=pd.read_excel('Energy Indicators.xls',skiprows=17,skipfooter=38)

# %%
col_names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
#del(energy['Unnamed: 1'])
del(energy['Unnamed: 0'])

# %%
# Out:
#      Unnamed: 0                 Unnamed: 2 Petajoules Gigajoules           %
# 0           NaN                Afghanistan        321         10   78.669280
# 1           NaN                    Albania        102         35  100.000000
# 2           NaN                    Algeria       1959         51    0.551010
# 3           NaN             American Samoa        ...        ...    0.641026
# 4           NaN                    Andorra          9        121   88.695650
# ..          ...                        ...        ...        ...         ...
# 222         NaN                   Viet Nam       2554         28   45.321520
# 223         NaN  Wallis and Futuna Islands          0         26    0.000000
# 224         NaN                      Yemen        344         13    0.000000
# 225         NaN                     Zambia        400         26   99.714670
# 226         NaN                   Zimbabwe        480         32   52.536120
#
# [227 rows x 5 columns]

# %%
energy.columns=col_names

# %%
energy.loc[energy['Energy Supply']=='...']=np.NaN

# %%
energy[['Energy Supply','Energy Supply per Capita']]=energy[['Energy Supply','Energy Supply per Capita']]

# %%
energy
# Out:
#                        Country Energy Supply Energy Supply per Capita  \
# 0                  Afghanistan           321                       10
# 1                      Albania           102                       35
# 2                      Algeria          1959                       51
# 3                          NaN           NaN                      NaN
# 4                      Andorra             9                      121
# ..                         ...           ...                      ...
# 222                   Viet Nam          2554                       28
# 223  Wallis and Futuna Islands             0                       26
# 224                      Yemen           344                       13
# 225                     Zambia           400                       26
# 226                   Zimbabwe           480                       32
#
#      % Renewable
# 0       78.66928
# 1      100.00000
# 2        0.55101
# 3            NaN
# 4       88.69565
# ...

# %%
energy['Energy Supply']=energy['Energy Supply']*10**6

# %%
energy
# Out:
#                        Country Energy Supply Energy Supply per Capita  \
# 0                  Afghanistan     321000000                       10
# 1                      Albania     102000000                       35
# 2                      Algeria    1959000000                       51
# 3                          NaN           NaN                      NaN
# 4                      Andorra       9000000                      121
# ..                         ...           ...                      ...
# 222                   Viet Nam    2554000000                       28
# 223  Wallis and Futuna Islands             0                       26
# 224                      Yemen     344000000                       13
# 225                     Zambia     400000000                       26
# 226                   Zimbabwe     480000000                       32
#
#      % Renewable
# 0       78.66928
# 1      100.00000
# 2        0.55101
# 3            NaN
# 4       88.69565
# ...

# %%
string='my(\ name.* is maher'
string.replace(r"(\.","")
# Out:
# 'my(\\ name.* is maher'

# %%
string
# Out:
# 'my(\\ name.* is maher'

# %%
energy[energy['Country']=='Switzerland17']
# Out:
#            Country Energy Supply Energy Supply per Capita  % Renewable
# 197  Switzerland17    1113000000                      136     57.74548

# %%
energy['Country']=energy['Country'].str.replace(r'([0-9]+)$','')

# %%
energy[energy['Country']=='Switzerland']
# Out:
#          Country Energy Supply Energy Supply per Capita  % Renewable
# 197  Switzerland    1113000000                      136     57.74548

# %%
energy['Country']=energy['Country'].str.replace(r'\(.*\)','')

# %%
energy.reset_index()
# Out:
#      index                    Country Energy Supply Energy Supply per Capita  \
# 0        0                Afghanistan     321000000                       10
# 1        1                    Albania     102000000                       35
# 2        2                    Algeria    1959000000                       51
# 3        3                        NaN           NaN                      NaN
# 4        4                    Andorra       9000000                      121
# ..     ...                        ...           ...                      ...
# 222    222                   Viet Nam    2554000000                       28
# 223    223  Wallis and Futuna Islands             0                       26
# 224    224                      Yemen     344000000                       13
# 225    225                     Zambia     400000000                       26
# 226    226                   Zimbabwe     480000000                       32
#
#      % Renewable
# 0       78.66928
# ...

# %%
energy=energy.set_index('Country')

# %%
energy=energy.reset_index()

# %%
replace_dict={
    "Republic of Korea": "South Korea",
"United States of America": "United States",
"United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
"China, Hong Kong Special Administrative Region": "Hong Kong"
}

# %%
energy['Country'].replace(to_replace=replace_dict,inplace=True)

# %%
energy.head()
# Out:
#        Country Energy Supply Energy Supply per Capita  % Renewable
# 0  Afghanistan     321000000                       10     78.66928
# 1      Albania     102000000                       35    100.00000
# 2      Algeria    1959000000                       51      0.55101
# 3          NaN           NaN                      NaN          NaN
# 4      Andorra       9000000                      121     88.69565

# %%
energy=energy.set_index('Country')

# %%
energy.index
# Out:
# Index([              'Afghanistan',                   'Albania',
#                          'Algeria',                         nan,
#                          'Andorra',                    'Angola',
#                         'Anguilla',       'Antigua and Barbuda',
#                        'Argentina',                   'Armenia',
#        ...
#                                nan,                   'Uruguay',
#                       'Uzbekistan',                   'Vanuatu',
#                       'Venezuela ',                  'Viet Nam',
#        'Wallis and Futuna Islands',                     'Yemen',
#                           'Zambia',                  'Zimbabwe'],
#       dtype='object', name='Country', length=227)

# %%
energy=pd.read_excel('Energy Indicators.xls',skiprows=17,skipfooter=38)

# %%
energy.head()
del(energy['Unnamed: 0'])

# %%
del(energy['Unnamed: 1'])

# %%
col_names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
energy.columns=col_names

# %%
energy.loc[energy['Energy Supply']=='...']=np.NaN

# %%
energy['Energy Supply']=energy['Energy Supply']*10**6

# %%
energy.head()
# Out:
#        Country Energy Supply Energy Supply per Capita  % Renewable
# 0  Afghanistan     321000000                       10     78.66928
# 1      Albania     102000000                       35    100.00000
# 2      Algeria    1959000000                       51      0.55101
# 3          NaN           NaN                      NaN          NaN
# 4      Andorra       9000000                      121     88.69565

# %%
energy['Country']=energy['Country'].str.replace(r'\(.*\)','')
energy['Country']=energy['Country'].str.replace(r'([0-9]+)$','')

# %%
replace_dict={
    "Republic of Korea": "South Korea",
"United States of America": "United States",
"United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
"China, Hong Kong Special Administrative Region": "Hong Kong"
}

# %%
energy['Country'].replace(to_replace=replace_dict,inplace=True)

# %%
energy=energy.set_index('Country')

# %%
energy
# Out:
#                           Energy Supply Energy Supply per Capita  % Renewable
# Country
# Afghanistan                   321000000                       10     78.66928
# Albania                       102000000                       35    100.00000
# Algeria                      1959000000                       51      0.55101
# NaN                                 NaN                      NaN          NaN
# Andorra                         9000000                      121     88.69565
# ...                                 ...                      ...          ...
# Viet Nam                     2554000000                       28     45.32152
# Wallis and Futuna Islands             0                       26      0.00000
# Yemen                         344000000                       13      0.00000
# Zambia                        400000000                       26     99.71467
# Zimbabwe                      480000000                       32     52.53612
#
# [227 rows x 3 columns]

# %%
energy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 227 entries, Afghanistan to Zimbabwe
# Data columns (total 3 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Energy Supply             222 non-null    object
#  1   Energy Supply per Capita  222 non-null    object
#  2   % Renewable               222 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 7.1+ KB

# %%
GDP=pd.read_csv('world_bank.csv',skiprows=4)
country_dict={
    "Korea, Rep.": "South Korea", 
"Iran, Islamic Rep.": "Iran",
"Hong Kong SAR, China": "Hong Kong"
}
GDP['Country Name'].replace(to_replace=country_dict,inplace=True)

# %%
GDP.head(
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  GDP at market prices (constant 2010 US$)
# 1      Andorra          AND  GDP at market prices (constant 2010 US$)
# 2  Afghanistan          AFG  GDP at market prices (constant 2010 US$)
# 3       Angola          AGO  GDP at market prices (constant 2010 US$)
# 4      Albania          ALB  GDP at market prices (constant 2010 US$)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965  ...          2006  \
# 0  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...           NaN
# 1  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  4.018196e+09
# 2  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  1.030523e+10
# 3  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  5.581103e+10
# 4  NY.GDP.MKTP.KD   NaN   NaN   NaN   NaN   NaN   NaN  ...  9.771760e+09
#
#            2007          2008          2009          2010          2011  \
# ...

# %%
years_to_keep=np.arange(2006,2016).astype('str')

# %%
years_to_keep
# Out:
# array(['2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015'], dtype='<U11')

# %%
GDP=GDP[np.append(['Country Name'],years_to_keep)]

# %%
GDP.reset_index()
# Out:
#      index      Country Name          2006          2007          2008  \
# 0        0             Aruba           NaN           NaN           NaN
# 1        1           Andorra  4.018196e+09  4.021331e+09  3.675728e+09
# 2        2       Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10
# 3        3            Angola  5.581103e+10  6.842044e+10  7.787420e+10
# 4        4           Albania  9.771760e+09  1.034829e+10  1.112752e+10
# ..     ...               ...           ...           ...           ...
# 259    259       Yemen, Rep.  2.672565e+10  2.761787e+10  2.872656e+10
# 260    260      South Africa  3.402852e+11  3.585261e+11  3.699668e+11
# 261    261  Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10
# 262    262            Zambia  1.440569e+10  1.560892e+10  1.682234e+10
# 263    263          Zimbabwe  1.006276e+10  9.695130e+09  7.982103e+09
#
#              2009          2010          2011          2012          2013  \
# ...

# %%
GDP=GDP.rename(columns={'Country Name':'Country'})

# %%
GDP.set_index('Country')
# Out:
#                           2006          2007          2008          2009  \
# Country
# Aruba                      NaN           NaN           NaN           NaN
# Andorra           4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# Afghanistan       1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# Angola            5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# Albania           9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
# ...                        ...           ...           ...           ...
# Yemen, Rep.       2.672565e+10  2.761787e+10  2.872656e+10  2.991436e+10
# South Africa      3.402852e+11  3.585261e+11  3.699668e+11  3.642764e+11
# Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10  1.916651e+10
# Zambia            1.440569e+10  1.560892e+10  1.682234e+10  1.837342e+10
# Zimbabwe          1.006276e+10  9.695130e+09  7.982103e+09  8.459783e+09
#
#                           2010          2011          2012          2013  \
# ...

# %%
energy.head()
# Out:
#             Energy Supply Energy Supply per Capita  % Renewable
# Country
# Afghanistan     321000000                       10     78.66928
# Albania         102000000                       35    100.00000
# Algeria        1959000000                       51      0.55101
# NaN                   NaN                      NaN          NaN
# Andorra           9000000                      121     88.69565

# %%
scimEn=pd.read_excel('scimagojr-3.xlsx',header=0)

# %%
scimEn.head()
# Out:
#    Rank             Country  Documents  Citable documents  Citations  \
# 0     1               China     127050             126767     597237
# 1     2       United States      96661              94747     792274
# 2     3               Japan      30504              30287     223024
# 3     4      United Kingdom      20944              20357     206091
# 4     5  Russian Federation      18534              18301      34266
#
#    Self-citations  Citations per document  H index
# 0          411683                    4.70      138
# 1          265436                    8.20      230
# 2           61554                    7.31      134
# 3           37874                    9.84      139
# 4           12422                    1.85       57

# %%
scimEn.reset_index()
# Out:
#      index  Rank             Country  Documents  Citable documents  Citations  \
# 0        0     1               China     127050             126767     597237
# 1        1     2       United States      96661              94747     792274
# 2        2     3               Japan      30504              30287     223024
# 3        3     4      United Kingdom      20944              20357     206091
# 4        4     5  Russian Federation      18534              18301      34266
# ..     ...   ...                 ...        ...                ...        ...
# 186    186   187              Guyana          1                  1          0
# 187    187   188    Christmas Island          1                  1          0
# 188    188   189             Reunion          1                  1          2
# 189    189   190         Saint Lucia          1                  1          0
# 190    190   191          Mauritania          1                  1          1
#
# ...

# %%
scimEn=scimEn.set_index('Country')

# %%
scimEn
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Guyana               187          1                  1          0
# Christmas Island     188          1                  1          0
# Reunion              189          1                  1          2
# Saint Lucia          190          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index
# Country
# China                       411683                    4.70      138
# ...

# %%
first_merge=pd.merge(energy,GDP,how='outer',left_index=True,right_index=True)

# %%
result=pd.merge(scimEn,first_merge,how='outer',left_index=True,right_index=True)

# %%
result.head()
# Out:
#    Rank  Documents  Citable documents  Citations  Self-citations  \
# 0   NaN        NaN                NaN        NaN             NaN
# 1   NaN        NaN                NaN        NaN             NaN
# 2   NaN        NaN                NaN        NaN             NaN
# 3   NaN        NaN                NaN        NaN             NaN
# 4   NaN        NaN                NaN        NaN             NaN
#
#    Citations per document  H index Energy Supply Energy Supply per Capita  \
# 0                     NaN      NaN           NaN                      NaN
# 1                     NaN      NaN           NaN                      NaN
# 2                     NaN      NaN           NaN                      NaN
# 3                     NaN      NaN           NaN                      NaN
# 4                     NaN      NaN           NaN                      NaN
#
#    % Renewable  ...          2006          2007          2008          2009  \
# ...

# %%
first_merge.head()
# Out:
#   Energy Supply Energy Supply per Capita  % Renewable      Country  \
# 0           NaN                      NaN          NaN        Aruba
# 1           NaN                      NaN          NaN      Andorra
# 2           NaN                      NaN          NaN  Afghanistan
# 3           NaN                      NaN          NaN       Angola
# 4           NaN                      NaN          NaN      Albania
#
#            2006          2007          2008          2009          2010  \
# 0           NaN           NaN           NaN           NaN  2.467704e+09
# 1  4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09  3.346317e+09
# 2  1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10  1.593680e+10
# 3  5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10  8.247091e+10
# 4  9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10  1.192695e+10
#
#            2011          2012          2013          2014          2015
# ...

# %%
energy.head()
# Out:
#             Energy Supply Energy Supply per Capita  % Renewable
# Country
# Afghanistan     321000000                       10     78.66928
# Albania         102000000                       35    100.00000
# Algeria        1959000000                       51      0.55101
# NaN                   NaN                      NaN          NaN
# Andorra           9000000                      121     88.69565

# %%
GDP=GDP.set_index('Country')

# %%
first_merge=pd.merge(energy,GDP,how='outer',left_index=True,right_index=True)

# %%
first_merge.head()
# Out:
#                Energy Supply Energy Supply per Capita  % Renewable  \
# Country
# Afghanistan        321000000                       10     78.66928
# Albania            102000000                       35    100.00000
# Algeria           1959000000                       51      0.55101
# American Samoa           NaN                      NaN          NaN
# Andorra              9000000                      121     88.69565
#
#                         2006          2007          2008          2009  \
# Country
# Afghanistan     1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# Albania         9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
# Algeria         1.446474e+11  1.495654e+11  1.531550e+11  1.556055e+11
# American Samoa           NaN           NaN           NaN           NaN
# Andorra         4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
#
#                         2010          2011          2012          2013  \
# Country
# ...

# %%
result=pd.merge(scimEn,first_merge,how='outer',left_index=True,right_index=True)

# %%
result=result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')

# %%
result=result.loc[result['Rank']<=15]

# %%
del(result['index'])

# %%
result.head()
# Out:
#            Rank  Documents  Citable documents  Citations  Self-citations  \
# Country
# Australia  14.0     8831.0             8725.0    90765.0         15606.0
# Brazil     15.0     8668.0             8596.0    60702.0         14396.0
# Canada      6.0    17899.0            17620.0   215003.0         40930.0
# China       1.0   127050.0           126767.0   597237.0        411683.0
# France      9.0    13153.0            12973.0   130632.0         28601.0
#
#            Citations per document  H index Energy Supply  \
# Country
# Australia                   10.28    107.0    5386000000
# Brazil                       7.00     86.0   12149000000
# Canada                      12.01    149.0   10431000000
# China                        4.70    138.0  127191000000
# France                       9.93    114.0   10597000000
#
#           Energy Supply per Capita  % Renewable          2006          2007  \
# Country
# ...

# %%
result.shape
# Out:
# (15, 20)

# %%
first_merge.loc['American Samoa']
# Out:
# Energy Supply               NaN
# Energy Supply per Capita    NaN
# % Renewable                 NaN
# 2006                        NaN
# 2007                        NaN
# 2008                        NaN
# 2009                        NaN
# 2010                        NaN
# 2011                        NaN
# 2012                        NaN
# 2013                        NaN
# 2014                        NaN
# 2015                        NaN
# Name: American Samoa, dtype: object

# %%
first_merge=first_merge.dropna(thresh=5)

# %%
energy=pd.read_excel('Energy Indicators.xls',skiprows=17,skipfooter=38)

# %%
del(energy['Unnamed: 0'])

# %%
energy
# Out:
#                     Unnamed: 2 Petajoules Gigajoules           %
# 0                  Afghanistan        321         10   78.669280
# 1                      Albania        102         35  100.000000
# 2                      Algeria       1959         51    0.551010
# 3               American Samoa        ...        ...    0.641026
# 4                      Andorra          9        121   88.695650
# ..                         ...        ...        ...         ...
# 222                   Viet Nam       2554         28   45.321520
# 223  Wallis and Futuna Islands          0         26    0.000000
# 224                      Yemen        344         13    0.000000
# 225                     Zambia        400         26   99.714670
# 226                   Zimbabwe        480         32   52.536120
#
# [227 rows x 4 columns]

# %%
col_names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
energy.columns=col_names

# %%
energy.loc[energy['Energy Supply']=='...']=np.NaN

# %%
energy['Energy Supply']=energy['Energy Supply']*10**6

# %%
energy['Country']=energy['Country'].str.replace(r'\(.*\)','')
energy['Country']=energy['Country'].str.replace(r'([0-9]+)$','')

# %%
replace_dict={
    "Republic of Korea": "South Korea",
"United States of America": "United States",
"United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
"China, Hong Kong Special Administrative Region": "Hong Kong"
}

# %%
energy['Country'].replace(to_replace=replace_dict,inplace=True)

# %%
energy.head()
# Out:
#        Country Energy Supply Energy Supply per Capita  % Renewable
# 0  Afghanistan     321000000                       10     78.66928
# 1      Albania     102000000                       35    100.00000
# 2      Algeria    1959000000                       51      0.55101
# 3          NaN           NaN                      NaN          NaN
# 4      Andorra       9000000                      121     88.69565

# %%
energy.reset_index()
# Out:
#      index                    Country Energy Supply Energy Supply per Capita  \
# 0        0                Afghanistan     321000000                       10
# 1        1                    Albania     102000000                       35
# 2        2                    Algeria    1959000000                       51
# 3        3                        NaN           NaN                      NaN
# 4        4                    Andorra       9000000                      121
# ..     ...                        ...           ...                      ...
# 222    222                   Viet Nam    2554000000                       28
# 223    223  Wallis and Futuna Islands             0                       26
# 224    224                      Yemen     344000000                       13
# 225    225                     Zambia     400000000                       26
# 226    226                   Zimbabwe     480000000                       32
#
#      % Renewable
# 0       78.66928
# ...

# %%
energy=energy.set_index('Country')

# %%
energy.head()
# Out:
#             Energy Supply Energy Supply per Capita  % Renewable
# Country
# Afghanistan     321000000                       10     78.66928
# Albania         102000000                       35    100.00000
# Algeria        1959000000                       51      0.55101
# NaN                   NaN                      NaN          NaN
# Andorra           9000000                      121     88.69565

# %%
energy=pd.read_excel('Energy Indicators.xls',skiprows=17,skipfooter=38)
del(energy['Unnamed: 0'])
del(energy['Unnamed: 1'])
col_names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
energy.columns=col_names
replace_dict={
"Republic of Korea": "South Korea",
"United States of America": "United States",
"United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
"China, Hong Kong Special Administrative Region": "Hong Kong"
        }
energy['Country'].replace(to_replace=replace_dict,inplace=True)
energy.reset_index()
energy=energy.set_index('Country')
energy
# Out:
#                           Energy Supply Energy Supply per Capita  % Renewable
# Country
# Afghanistan                         321                       10    78.669280
# Albania                             102                       35   100.000000
# Algeria                            1959                       51     0.551010
# American Samoa                      ...                      ...     0.641026
# Andorra                               9                      121    88.695650
# ...                                 ...                      ...          ...
# Viet Nam                           2554                       28    45.321520
# Wallis and Futuna Islands             0                       26     0.000000
# Yemen                               344                       13     0.000000
# Zambia                              400                       26    99.714670
# Zimbabwe                            480                       32    52.536120
#
# [227 rows x 3 columns]

# %%
GDP=pd.read_csv('world_bank.csv',skiprows=4)

# %%
replace_dict={
    "Korea, Rep.": "South Korea", 
"Iran, Islamic Rep.": "Iran",
"Hong Kong SAR, China": "Hong Kong"
}
GDP['Country Name'].replace(to_replace=replace_dict,inplace=True)

# %%
years_to_keep=np.arange(2006,2016).astype('str')

# %%
GDP=GDP[np.append(['Country Name'],years_to_keep)]

# %%
GDP.reset_index()
# Out:
#      index      Country Name          2006          2007          2008  \
# 0        0             Aruba           NaN           NaN           NaN
# 1        1           Andorra  4.018196e+09  4.021331e+09  3.675728e+09
# 2        2       Afghanistan  1.030523e+10  1.172119e+10  1.214448e+10
# 3        3            Angola  5.581103e+10  6.842044e+10  7.787420e+10
# 4        4           Albania  9.771760e+09  1.034829e+10  1.112752e+10
# ..     ...               ...           ...           ...           ...
# 259    259       Yemen, Rep.  2.672565e+10  2.761787e+10  2.872656e+10
# 260    260      South Africa  3.402852e+11  3.585261e+11  3.699668e+11
# 261    261  Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10
# 262    262            Zambia  1.440569e+10  1.560892e+10  1.682234e+10
# 263    263          Zimbabwe  1.006276e+10  9.695130e+09  7.982103e+09
#
#              2009          2010          2011          2012          2013  \
# ...

# %%
GDP.rename(columns={'Country Name':'Country'},inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
GDP=GDP.set_index('Country')

# %%
GDP
# Out:
#                           2006          2007          2008          2009  \
# Country
# Aruba                      NaN           NaN           NaN           NaN
# Andorra           4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# Afghanistan       1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# Angola            5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# Albania           9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
# ...                        ...           ...           ...           ...
# Yemen, Rep.       2.672565e+10  2.761787e+10  2.872656e+10  2.991436e+10
# South Africa      3.402852e+11  3.585261e+11  3.699668e+11  3.642764e+11
# Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10  1.916651e+10
# Zambia            1.440569e+10  1.560892e+10  1.682234e+10  1.837342e+10
# Zimbabwe          1.006276e+10  9.695130e+09  7.982103e+09  8.459783e+09
#
#                           2010          2011          2012          2013  \
# ...

# %%
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype('str')
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')

# %%
GDP
# Out:
#                           2006          2007          2008          2009  \
# Country
# Aruba                      NaN           NaN           NaN           NaN
# Andorra           4.018196e+09  4.021331e+09  3.675728e+09  3.535389e+09
# Afghanistan       1.030523e+10  1.172119e+10  1.214448e+10  1.469733e+10
# Angola            5.581103e+10  6.842044e+10  7.787420e+10  7.975320e+10
# Albania           9.771760e+09  1.034829e+10  1.112752e+10  1.150029e+10
# ...                        ...           ...           ...           ...
# Yemen, Rep.       2.672565e+10  2.761787e+10  2.872656e+10  2.991436e+10
# South Africa      3.402852e+11  3.585261e+11  3.699668e+11  3.642764e+11
# Congo, Dem. Rep.  1.650894e+10  1.754232e+10  1.863448e+10  1.916651e+10
# Zambia            1.440569e+10  1.560892e+10  1.682234e+10  1.837342e+10
# Zimbabwe          1.006276e+10  9.695130e+09  7.982103e+09  8.459783e+09
#
#                           2010          2011          2012          2013  \
# ...

# %%
ScimEn=pd.read_excel('scimagojr-3.xlsx',header=0)

# %%
ScimEn.reset_index()
# Out:
#      index  Rank             Country  Documents  Citable documents  Citations  \
# 0        0     1               China     127050             126767     597237
# 1        1     2       United States      96661              94747     792274
# 2        2     3               Japan      30504              30287     223024
# 3        3     4      United Kingdom      20944              20357     206091
# 4        4     5  Russian Federation      18534              18301      34266
# ..     ...   ...                 ...        ...                ...        ...
# 186    186   187              Guyana          1                  1          0
# 187    187   188    Christmas Island          1                  1          0
# 188    188   189             Reunion          1                  1          2
# 189    189   190         Saint Lucia          1                  1          0
# 190    190   191          Mauritania          1                  1          1
#
# ...

# %%
ScimEn=ScimEn.set_index('Country')

# %%
ScimEn
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# ...                  ...        ...                ...        ...
# Guyana               187          1                  1          0
# Christmas Island     188          1                  1          0
# Reunion              189          1                  1          2
# Saint Lucia          190          1                  1          0
# Mauritania           191          1                  1          1
#
#                     Self-citations  Citations per document  H index
# Country
# China                       411683                    4.70      138
# ...

# %%
first_merge=pd.merge(energy,GDP,how='outer',left_index=True,right_index=True)

# %%
result=pd.merge(ScimEn,first_merge,how='outer',left_index=True,right_index=True)

# %%
result=result.reset_index().dropna(thresh=(result.shape[1]-10)).set_index('Country')

# %%
result=result.loc[result['Rank']<=15]

# %%
result
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# Australia           14.0     8831.0             8725.0    90765.0
# Brazil              15.0     8668.0             8596.0    60702.0
# Canada               6.0    17899.0            17620.0   215003.0
# China                1.0   127050.0           126767.0   597237.0
# France               9.0    13153.0            12973.0   130632.0
# Germany              7.0    17027.0            16831.0   140566.0
# India                8.0    15005.0            14841.0   128763.0
# Iran                13.0     8896.0             8819.0    57470.0
# Italy               11.0    10964.0            10794.0   111850.0
# Japan                3.0    30504.0            30287.0   223024.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
# South Korea         10.0    11983.0            11923.0   114675.0
# Spain               12.0     9428.0             9330.0   123336.0
# ...

# %%
result.shape
# Out:
# (15, 20)

# %%
import pandas as pd
import numpy as np
energy=pd.read_excel('Energy Indicators.xls',skiprows=17,skipfooter=38)
del(energy['Unnamed: 0'])
del(energy['Unnamed: 1'])
col_names=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
energy.columns=col_names
energy.loc[energy['Energy Supply']=='...']=np.NaN
energy['Energy Supply']=energy['Energy Supply']*10**6
replace_dict={
    "Republic of Korea": "South Korea",
"United States of America": "United States",
"United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
"China, Hong Kong Special Administrative Region": "Hong Kong"
             }
energy['Country']=energy['Country'].str.replace(r' \(.*\)','')
energy['Country']=energy['Country'].str.replace(r'([0-9]+)$','')
energy['Country'].replace(to_replace=replace_dict,inplace=True)
energy.reset_index()
energy=energy.set_index('Country')
energy_shape=energy.shape
GDP=pd.read_csv('world_bank.csv',skiprows=4)
replace_dict={
    "Korea, Rep.": "South Korea", 
"Iran, Islamic Rep.": "Iran",
"Hong Kong SAR, China": "Hong Kong"
    
             }
GDP['Country Name'].replace(to_replace=replace_dict,inplace=True)
GDP=GDP.rename(columns={'Country Name':'Country'})
years_to_keep=np.arange(2006,2016).astype('str')
GDP=GDP[np.append(['Country'],years_to_keep)]
GDP.reset_index()
GDP=GDP.set_index('Country')
GDP_shape=GDP.shape
ScimEn=pd.read_excel('scimagojr-3.xlsx',header=0)
ScimEn.reset_index()
ScimEn=ScimEn.set_index('Country')
ScimEn_shape=ScimEn.shape
first_merge=pd.merge(energy,GDP,how='outer',left_index=True,right_index=True)
result=pd.merge(ScimEn,first_merge,how='outer',left_index=True,right_index=True)
result=result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
result=result.loc[result['Rank']<=15]
years_to_keep=np.arange(2006,2016).astype('str')
result['avgGDP']=result[years_to_keep].mean(axis=1).sort_values(ascending=False)

# %%
result['avgGDP'].count()
# Out:
# 15

# %%
del(result['avgGDP'])

# %%
years_to_keep=np.arange(2006,2016).astype('str')
result['avgGDP']=result[years_to_keep].mean(axis=1)

# %%
result['avgGDP'].sort_values(ascending=False)
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# Name: avgGDP, dtype: float64

# %%
def answer_three():
    import numpy as np
    Top15 = answer_one()
    years_to_keep=np.arange(2006,2016).astype('str')
    Top15['avgGDP']=Top15['years_to_keep'].mean(axis=1)
    
    return Top15['avgGDP'].sort_values(ascending=False)
answer_three()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-791-f3bcaebdea20> in <module>
#       6
#       7     return Top15['avgGDP'].sort_values(ascending=False)
# ----> 8 answer_three()
#
# <ipython-input-791-f3bcaebdea20> in answer_three()
#       1 def answer_three():
#       2     import numpy as np
# ----> 3     Top15 = answer_one()
#       4     years_to_keep=np.arange(2006,2016).astype('str')
#       5     Top15['avgGDP']=Top15['years_to_keep'].mean(axis=1)
#
# NameError: name 'answer_one' is not defined

# %%
result['diff']=(result[years_to_keep].min(axis=1)-result[years_to_keep].max(axis=1))

# %%
result['diff'].sort_values(ascending=True)[:6]
# Out:
# Country
# China           -4.805667e+12
# United States   -1.953731e+12
# India           -1.101312e+12
# Brazil          -5.671510e+11
# Japan           -4.182547e+11
# Germany         -4.022160e+11
# Name: diff, dtype: float64

# %%
result[years_to_keep].head()
# Out:
#                    2006          2007          2008          2009  \
# Country
# Australia  1.021939e+12  1.060340e+12  1.099644e+12  1.119654e+12
# Brazil     1.845080e+12  1.957118e+12  2.056809e+12  2.054215e+12
# Canada     1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# China      3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# France     2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
#
#                    2010          2011          2012          2013  \
# Country
# Australia  1.142251e+12  1.169431e+12  1.211913e+12  1.241484e+12
# Brazil     2.208872e+12  2.295245e+12  2.339209e+12  2.409740e+12
# Canada     1.613406e+12  1.664087e+12  1.693133e+12  1.730688e+12
# China      6.039659e+12  6.612490e+12  7.124978e+12  7.672448e+12
# France     2.646995e+12  2.702032e+12  2.706968e+12  2.722567e+12
#
#                    2014          2015
# Country
# Australia  1.272520e+12  1.301251e+12
# Brazil     2.412231e+12  2.319423e+12
# ...

# %%
result['avgGDP'].sort_values(ascending=False)
# Out:
# Country
# United States         1.536434e+13
# China                 6.348609e+12
# Japan                 5.542208e+12
# Germany               3.493025e+12
# France                2.681725e+12
# United Kingdom        2.487907e+12
# Brazil                2.189794e+12
# Italy                 2.120175e+12
# India                 1.769297e+12
# Canada                1.660647e+12
# Russian Federation    1.565459e+12
# Spain                 1.418078e+12
# Australia             1.164043e+12
# South Korea           1.106715e+12
# Iran                  4.441558e+11
# Name: avgGDP, dtype: float64

# %%
result.sort_values(['avgGDP'],ascending=False)
del(result['avgGDP'])

# %%
def func():
    years_to_keep=np.arange(2006,2016).astype('str')
    result['avgGDP']=result[years_to_keep].mean(axis=1)
    result=result.sort_values(['avgGDP'],ascending=False)
    result['deltaGDP']=result['2015']-result['2006']
    result=result.reset_index()
    return result
func()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-805-195ca3942fc1> in <module>
#       6     result=result.reset_index()
#       7     return result
# ----> 8 func()
#
# <ipython-input-805-195ca3942fc1> in func()
#       1 def func():
#       2     years_to_keep=np.arange(2006,2016).astype('str')
# ----> 3     result['avgGDP']=result[years_to_keep].mean(axis=1)
#       4     result=result.sort_values(['avgGDP'],ascending=False)
#       5     result['deltaGDP']=result['2015']-result['2006']
#
# UnboundLocalError: local variable 'result' referenced before assignment

# %%
result[years_to_keep]
# Out:
#                             2006          2007          2008          2009  \
# Country
# Australia           1.021939e+12  1.060340e+12  1.099644e+12  1.119654e+12
# Brazil              1.845080e+12  1.957118e+12  2.056809e+12  2.054215e+12
# Canada              1.564469e+12  1.596740e+12  1.612713e+12  1.565145e+12
# China               3.992331e+12  4.559041e+12  4.997775e+12  5.459247e+12
# France              2.607840e+12  2.669424e+12  2.674637e+12  2.595967e+12
# Germany             3.332891e+12  3.441561e+12  3.478809e+12  3.283340e+12
# India               1.265894e+12  1.374865e+12  1.428361e+12  1.549483e+12
# Iran                3.895523e+11  4.250646e+11  4.289909e+11  4.389208e+11
# Italy               2.202170e+12  2.234627e+12  2.211154e+12  2.089938e+12
# Japan               5.496542e+12  5.617036e+12  5.558527e+12  5.251308e+12
# Russian Federation  1.385793e+12  1.504071e+12  1.583004e+12  1.459199e+12
# ...

# %%
def answer_four():
    years_to_keep=np.arange(2006,2016).astype('str')
    result['avgGDP']=result[years_to_keep].mean(axis=1)
    result1=result.sort_values(['avgGDP'],ascending=False)
    result1['deltaGDP']=result1['2015']-result1['2006']
    result1=result1.reset_index()
    return result1.loc[5,'deltaGDP']
answer_four()
# Out:
# 246702696075.3999

# %%
result['Energy Supply per Capita'].mean()
# Out:
# 157.6

# %%
renewable=result['% Renewable']/100
renewable.max()
renewable=result[result['% Renewable']==result['% Renewable'].max()]

# %%
renewable
# Out:
#          Rank  Documents  Citable documents  Citations  Self-citations  \
# Country
# Brazil   15.0     8668.0             8596.0    60702.0         14396.0
#
#          Citations per document  H index Energy Supply  \
# Country
# Brazil                      7.0     86.0   12149000000
#
#         Energy Supply per Capita  % Renewable  ...          2008  \
# Country                                        ...
# Brazil                        59     69.64803  ...  2.056809e+12
#
#                  2009          2010          2011          2012          2013  \
# Country
# Brazil   2.054215e+12  2.208872e+12  2.295245e+12  2.339209e+12  2.409740e+12
#
#                  2014          2015          diff        avgGDP
# Country
# Brazil   2.412231e+12  2.319423e+12 -5.671510e+11  2.189794e+12
#
# [1 rows x 22 columns]

# %%
result['% Renewable'].argmax()
# Out:
# 1

# %%
result.index
# Out:
# Index(['Australia', 'Brazil', 'Canada', 'China', 'France', 'Germany', 'India',
#        'Iran', 'Italy', 'Japan', 'Russian Federation', 'South Korea', 'Spain',
#        'United Kingdom', 'United States'],
#       dtype='object', name='Country')

# %%
result=result.reset_index()

# %%
result[result['% Renewable']==result['% Renewable'].max()][['Country','% Renewable']]
# Out:
#   Country  % Renewable
# 1  Brazil     69.64803

# %%
result=result.set_index('Country')

# %%
def answer_one():
    res=result['% Renewable'].argmax()
    result1=result.reset_index()
    country=result1.loc[res]['Country']
    return (country,result1.loc[res,'% Renewable'])
answer_one()
# Out:
# ('Brazil', 69.64803)

# %%
result=result.reset_index()

# %%
result.loc[1]['Country']
# Out:
# 'Brazil'

# %%
def answer_one():
    max_loc=result['% Renewable'].argmax()
    country=result.loc[max_loc,'Country']
    return (country,result.loc[max_loc,'% Renewable'])
answer_one()
# Out:
# ('Brazil', 69.64803)

# %%
result.loc[3,'Country']
# Out:
# 'China'

# %%
def answer_six():
    result['citationratio']=result['Self-citations']/result['Citations']
    loc=result['citationratio'].argmax()
    country=result.loc[loc,'Country']
    return (country,result.loc[loc,'citationratio']

answer_six()
# Out:
#   File "<ipython-input-894-614a69b1689f>", line 7
#     answer_six()
#              ^
# SyntaxError: invalid syntax

# %%
result.columns
# Out:
# Index(['Country', 'Rank', 'Documents', 'Citable documents', 'Citations',
#        'Self-citations', 'Citations per document', 'H index', 'Energy Supply',
#        'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', 'diff',
#        'avgGDP'],
#       dtype='object')

# %%
result['citationratio']=result['Self-citations']/result['Citations']
loc=result['citationratio'].argmax()
country=result.loc[loc,'Country']
country
# Out:
# 'China'

# %%
result
# Out:
#                Country  Rank  Documents  Citable documents  Citations  \
# 0            Australia  14.0     8831.0             8725.0    90765.0
# 1               Brazil  15.0     8668.0             8596.0    60702.0
# 2               Canada   6.0    17899.0            17620.0   215003.0
# 3                China   1.0   127050.0           126767.0   597237.0
# 4               France   9.0    13153.0            12973.0   130632.0
# 5              Germany   7.0    17027.0            16831.0   140566.0
# 6                India   8.0    15005.0            14841.0   128763.0
# 7                 Iran  13.0     8896.0             8819.0    57470.0
# 8                Italy  11.0    10964.0            10794.0   111850.0
# 9                Japan   3.0    30504.0            30287.0   223024.0
# 10  Russian Federation   5.0    18534.0            18301.0    34266.0
# 11         South Korea  10.0    11983.0            11923.0   114675.0
# ...

# %%
def answer_seven():
# Out:
#   File "<ipython-input-895-e87a30ca8b8c>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing

# %%
del(result['citationratio'])

# %%
def answer_seven():
    result['citationratio']=result['Self-citations']/result['Citations']
    loc=result['citationratio'].argmax()
    country=result.loc[loc,'Country']
    return (country,result.loc[loc,'citationratio'])
answer_seven()
# Out:
# ('China', 0.6893126179389422)

# %%
def answer_one():
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
    col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy.columns = col_names
    energy.loc[energy['Energy Supply'] == '...'] = np.NaN
    energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*10**6
    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
    replace_dict={"Republic of Korea": "South Korea",
                  "United States of America": "United States",
                  "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                  "China, Hong Kong Special Administrative Region": "Hong Kong"}
    energy['Country'].replace(to_replace=replace_dict, inplace=True)
    energy.reset_index()
    energy = energy.set_index('Country')
    
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype(str)
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')
    
    ScimEn = pd.read_excel('scimagojr-3.xlsx', header=0)
    ScimEn.reset_index()
    ScimEn = ScimEn.set_index('Country')
    first_merge = pd.merge(energy, GDP, how='outer', left_index=True, right_index=True)
    result = pd.merge(ScimEn, first_merge, how='outer', left_index=True, right_index=True)
    result = result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
    result = result.loc[result['Rank']<=15]
    
    return result
answer_one()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-905-0459ef6222f9> in <module>
#      39
#      40     return result
# ---> 41 answer_one()
#      42
#
# <ipython-input-905-0459ef6222f9> in answer_one()
#       4     energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
#       5     col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
# ----> 6     energy.columns = col_names
#       7     energy.loc[energy['Energy Supply'] == '...'] = np.NaN
#       8     energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# ...

# %%
result
# Out:
#                Country  Rank  Documents  Citable documents  Citations  \
# 0            Australia  14.0     8831.0             8725.0    90765.0
# 1               Brazil  15.0     8668.0             8596.0    60702.0
# 2               Canada   6.0    17899.0            17620.0   215003.0
# 3                China   1.0   127050.0           126767.0   597237.0
# 4               France   9.0    13153.0            12973.0   130632.0
# 5              Germany   7.0    17027.0            16831.0   140566.0
# 6                India   8.0    15005.0            14841.0   128763.0
# 7                 Iran  13.0     8896.0             8819.0    57470.0
# 8                Italy  11.0    10964.0            10794.0   111850.0
# 9                Japan   3.0    30504.0            30287.0   223024.0
# 10  Russian Federation   5.0    18534.0            18301.0    34266.0
# 11         South Korea  10.0    11983.0            11923.0   114675.0
# ...

# %%
result.columns
# Out:
# Index(['Country', 'Rank', 'Documents', 'Citable documents', 'Citations',
#        'Self-citations', 'Citations per document', 'H index', 'Energy Supply',
#        'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', 'diff',
#        'avgGDP', 'citationratio'],
#       dtype='object')

# %%
result=result.set_index('Country')

# %%
result.head()
# Out:
#            Rank  Documents  Citable documents  Citations  Self-citations  \
# Country
# Australia  14.0     8831.0             8725.0    90765.0         15606.0
# Brazil     15.0     8668.0             8596.0    60702.0         14396.0
# Canada      6.0    17899.0            17620.0   215003.0         40930.0
# China       1.0   127050.0           126767.0   597237.0        411683.0
# France      9.0    13153.0            12973.0   130632.0         28601.0
#
#            Citations per document  H index Energy Supply  \
# Country
# Australia                   10.28    107.0    5386000000
# Brazil                       7.00     86.0   12149000000
# Canada                      12.01    149.0   10431000000
# China                        4.70    138.0  127191000000
# France                       9.93    114.0   10597000000
#
#           Energy Supply per Capita  % Renewable  ...          2009  \
# Country                                          ...
# ...

# %%
years_to_keep=np.arange(2006,2015).astype('str')
result[years_to_keep].sum(axis=1)
# Out:
# Country
# Australia             1.033918e+13
# Brazil                1.957852e+13
# Canada                1.481387e+13
# China                 5.468809e+13
# France                2.405606e+13
# Germany               3.124470e+13
# India                 1.532577e+13
# Iran                  3.997402e+12
# Italy                 1.915244e+13
# Japan                 4.975251e+13
# Russian Federation    1.403845e+13
# South Korea           9.800565e+12
# Spain                 1.276096e+13
# United Kingdom        2.221273e+13
# United States         1.370949e+14
# dtype: float64

# %%
result['Energy Supply']/result['Energy Supply per Capita']
# Out:
# Country
# Australia              2.3316e+07
# Brazil                2.05915e+08
# Canada                3.52399e+07
# China                 1.36765e+09
# France                6.38373e+07
# Germany               8.03697e+07
# India                 1.27673e+09
# Iran                  7.70756e+07
# Italy                 5.99083e+07
# Japan                 1.27409e+08
# Russian Federation      1.435e+08
# South Korea           4.98054e+07
# Spain                 4.64434e+07
# United Kingdom         6.3871e+07
# United States         3.17615e+08
# dtype: object

# %%
result.loc[2,'Country']
# Out:
# 'Canada'

# %%
del(result['popest'])

# %%
result['popest']=result['Energy Supply']/result['Energy Supply per Capita']
result=result.sort_values(['popest'],ascending=False)
result=result.reset_index()
result.loc[2,'Country']
# Out:
# 'United States'

# %%
result
# Out:
#                            index      Rank  Documents  Citable documents  \
# index                   1.000000  0.485714  -0.584915          -0.585101
# Rank                    0.485714  1.000000  -0.703849          -0.702179
# Documents              -0.584915 -0.703849   1.000000           0.999943
# Citable documents      -0.585101 -0.702179   0.999943           1.000000
# Citations              -0.457628 -0.689219   0.924086           0.920451
# Self-citations         -0.555113 -0.640129   0.991635           0.992488
# Citations per document  0.715849  0.335432  -0.360302          -0.362623
# H index                -0.159590 -0.589597   0.617514           0.611284
# % Renewable             0.116172  0.295288  -0.166832          -0.165754
# 2006                   -0.424727 -0.574161   0.668326           0.661228
# 2007                   -0.443317 -0.587375   0.692532           0.685671
# 2008                   -0.458803 -0.596649   0.714274           0.707633
# ...

# %%
del(result['popest'])

# %%
result['popest']=result['Energy Supply']/result['Energy Supply per Capita']
result['citabledocsperperson']=result['Citable documents']/result['popest']
result=result.corr()
ressult.loc['citabledocsperperson','Energy Supply per Capita']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Energy Supply'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-933-b5ef87d2e957> in <module>
# ...

# %%
result.corr()
# Out:
#                            index      Rank  Documents  Citable documents  \
# index                   1.000000  0.915103  -0.952245          -0.952283
# Rank                    0.915103  1.000000  -0.973014          -0.972150
# Documents              -0.952245 -0.973014   1.000000           0.999986
# Citable documents      -0.952283 -0.972150   0.999986           1.000000
# Citations              -0.916187 -0.983535   0.979277           0.978216
# Self-citations         -0.946460 -0.961097   0.998297           0.998567
# Citations per document  0.926286  0.766553  -0.827478          -0.828743
# H index                -0.753905 -0.911340   0.854176           0.851617
# % Renewable             0.617391  0.722813  -0.674892          -0.673487
# 2006                   -0.856261 -0.937088   0.893394           0.890972
# 2007                   -0.866175 -0.943431   0.903254           0.900940
# 2008                   -0.874682 -0.948570   0.911700           0.909485
# ...

# %%
result.head()
# Out:
#                       index      Rank  Documents  Citable documents  \
# index              1.000000  0.485714  -0.584915          -0.585101
# Rank               0.485714  1.000000  -0.703849          -0.702179
# Documents         -0.584915 -0.703849   1.000000           0.999943
# Citable documents -0.585101 -0.702179   0.999943           1.000000
# Citations         -0.457628 -0.689219   0.924086           0.920451
#
#                    Citations  Self-citations  Citations per document  \
# index              -0.457628       -0.555113                0.715849
# Rank               -0.689219       -0.640129                0.335432
# Documents           0.924086        0.991635               -0.360302
# Citable documents   0.920451        0.992488               -0.362623
# Citations           1.000000        0.897606               -0.111725
#
#                     H index  % Renewable      2006  ...      2009      2010  \
# ...

# %%
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
    del(energy['Unnamed: 0'])
    del(energy['Unnamed: 1'])
    col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy.columns = col_names
    energy.loc[energy['Energy Supply'] == '...'] = np.NaN
    energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*10**6
    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
    replace_dict={"Republic of Korea": "South Korea",
                  "United States of America": "United States",
                  "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                  "China, Hong Kong Special Administrative Region": "Hong Kong"}
    energy['Country'].replace(to_replace=replace_dict, inplace=True)
    energy.reset_index()
    energy = energy.set_index('Country')
    
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype('str')
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')
    
    ScimEn = pd.read_excel('scimagojr-3.xlsx', header=0)
    ScimEn.reset_index()
    ScimEn = ScimEn.set_index('Country')
    first_merge = pd.merge(energy, GDP, how='outer', left_index=True, right_index=True)
    result = pd.merge(ScimEn, first_merge, how='outer', left_index=True, right_index=True)
    result = result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
    result = result.loc[result['Rank']<=15]

# %%
result['popest']=result['Energy Supply']/result['Energy Supply per Capita']
result['citable documents per person']=result['Citable documents']/result['popest']
result=result.corr()
result.loc['citable documents per person','Energy Supply per Capita']
# Out:
# 0.7222011699576485

# %%
result
# Out:
#                                   Rank  Documents  Citable documents  \
# Rank                          1.000000  -0.956666          -0.955298
# Documents                    -0.956666   1.000000           0.999977
# Citable documents            -0.955298   0.999977           1.000000
# Citations                    -0.978793   0.966781           0.965059
# Self-citations               -0.937482   0.996998           0.997471
# Citations per document        0.708881  -0.837950          -0.839776
# H index                      -0.887059   0.777688           0.773716
# Energy Supply                -0.923691   0.993021           0.993631
# Energy Supply per Capita     -0.286571   0.041925           0.036752
# % Renewable                   0.757857  -0.729585          -0.727776
# 2006                         -0.899451   0.843270           0.839600
# 2007                         -0.908224   0.857268           0.853755
# 2008                         -0.915402   0.869139           0.865767
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
result.plot(x='citable documents per person',y='Energy Supply per Capita',kind='scatter')

# %%
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
    del(energy['Unnamed: 0'])
    del(energy['Unnamed: 1'])
    col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy.columns = col_names
    energy.loc[energy['Energy Supply'] == '...'] = np.NaN
    energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*10**6
    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
    replace_dict={"Republic of Korea": "South Korea",
                  "United States of America": "United States",
                  "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                  "China, Hong Kong Special Administrative Region": "Hong Kong"}
    energy['Country'].replace(to_replace=replace_dict, inplace=True)
    energy.reset_index()
    energy = energy.set_index('Country')
    
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype('str')
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')
    
    ScimEn = pd.read_excel('scimagojr-3.xlsx', header=0)
    ScimEn.reset_index()
    ScimEn = ScimEn.set_index('Country')
    first_merge = pd.merge(energy, GDP, how='outer', left_index=True, right_index=True)
    result = pd.merge(ScimEn, first_merge, how='outer', left_index=True, right_index=True)
    result = result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
    result = result.loc[result['Rank']<=15]

# %%
result.head()
# Out:
#            Rank  Documents  Citable documents  Citations  Self-citations  \
# Country
# Australia  14.0     8831.0             8725.0    90765.0         15606.0
# Brazil     15.0     8668.0             8596.0    60702.0         14396.0
# Canada      6.0    17899.0            17620.0   215003.0         40930.0
# China       1.0   127050.0           126767.0   597237.0        411683.0
# France      9.0    13153.0            12973.0   130632.0         28601.0
#
#            Citations per document  H index  Energy Supply  \
# Country
# Australia                   10.28    107.0   5.386000e+09
# Brazil                       7.00     86.0   1.214900e+10
# Canada                      12.01    149.0   1.043100e+10
# China                        4.70    138.0   1.271910e+11
# France                       9.93    114.0   1.059700e+10
#
#            Energy Supply per Capita  % Renewable          2006          2007  \
# Country
# ...

# %%
def answer_eight():
    Top15 = answer_one()
    Top15['popest']=Top15['Energy Supply']/Top15['Energy Supply per capita']
    Top15=Top15.sort_values(['popest'],ascending=False)
    Top15=Top15.reset_index()
    return Top15.loc[2,'Country']
answer_eight()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-973-ddf17843375f> in <module>
#       5     Top15=Top15.reset_index()
#       6     return Top15.loc[2,'Country']
# ----> 7 answer_eight()
#
# <ipython-input-973-ddf17843375f> in answer_eight()
#       1 def answer_eight():
#       2     Top15 = answer_one()
# ----> 3     Top15['popest']=Top15['Energy Supply']/Top15['Energy Supply per capita']
#       4     Top15=Top15.sort_values(['popest'],ascending=False)
#       5     Top15=Top15.reset_index()
#
# TypeError: 'NoneType' object is not subscriptable

# %%
result['popest']=result['Energy Supply']/result['Energy Supply per Capita']
result=result.sort_values(['popest'],ascending=False)
result=result.reset_index()
result.loc[2,'Country']
# Out:
# 'United States'

# %%
result
# Out:
#                            index      Rank  Documents  Citable documents  \
# 0              Citable documents -0.955298   0.999977           1.000000
# 1                      Documents -0.956666   1.000000           0.999977
# 2                      Citations -0.978793   0.966781           0.965059
# 3                           2015 -0.946354   0.935292           0.932917
# 4                           2014 -0.948728   0.929393           0.926888
# 5                           Rank  1.000000  -0.956666          -0.955298
# 6                           2013 -0.945185   0.922594           0.919976
# 7                           2012 -0.940854   0.914336           0.911584
# 8                           2011 -0.936333   0.906435           0.903566
# 9                           2010 -0.930590   0.896074           0.893055
# 10                          2009 -0.924975   0.885706           0.882544
# 11                   % Renewable  0.757857  -0.729585          -0.727776
# ...

# %%
result['popest']=result['Energy Supply']/result['Energy Supply per Capita']
result['Citable docs per Capita']=result['Citable documents']/result['popest']

# %%
result.plot(x='Citable docs per Capita',y='Energy Supply per Capita',kind='scatter',xlim=[0,0.0006])

# %%
#result=result.set_index('Country')
result['%Renewable median']=result['% Renewable'].median()
result['HighRenew']=result['% Renewable']>=result['%Renewable median']
result['HighRenew'].sort_values(ascending=True)
# Out:
# Country
# India                 False
# United States         False
# Japan                 False
# Iran                  False
# United Kingdom        False
# South Korea           False
# Australia             False
# China                  True
# Brazil                 True
# Russian Federation     True
# Germany                True
# France                 True
# Italy                  True
# Spain                  True
# Canada                 True
# Name: HighRenew, dtype: bool

# %%
result.index
# Out:
# Index(['China', 'India', 'United States', 'Brazil', 'Russian Federation',
#        'Japan', 'Germany', 'Iran', 'United Kingdom', 'France', 'Italy',
#        'South Korea', 'Spain', 'Canada', 'Australia'],
#       dtype='object', name='Country')

# %%
result.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                1.0   127050.0           126767.0   597237.0
# India                8.0    15005.0            14841.0   128763.0
# United States        2.0    96661.0            94747.0   792274.0
# Brazil              15.0     8668.0             8596.0    60702.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                     411683.0                    4.70    138.0
# India                      37209.0                    8.58    115.0
# United States             265436.0                    8.20    230.0
# Brazil                     14396.0                    7.00     86.0
# Russian Federation         12422.0                    1.85     57.0
#
#                     Energy Supply  Energy Supply per Capita  % Renewable  ...  \
# ...

# %%
result=result.reset_index()
result=result.set_index('Country')
result['%Renewable median']=result['% Renewable'].median()
result['HighRenew']=result['% Renewable']>=result['%Renewable median']
result['HighRenew'].sort_values(ascending=True)
# Out:
# Country
# India                 False
# United States         False
# Japan                 False
# Iran                  False
# United Kingdom        False
# South Korea           False
# Australia             False
# China                  True
# Brazil                 True
# Russian Federation     True
# Germany                True
# France                 True
# Italy                  True
# Spain                  True
# Canada                 True
# Name: HighRenew, dtype: bool

# %%
result.head()
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                1.0   127050.0           126767.0   597237.0
# India                8.0    15005.0            14841.0   128763.0
# United States        2.0    96661.0            94747.0   792274.0
# Brazil              15.0     8668.0             8596.0    60702.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
#
#                     Self-citations  Citations per document  H index  \
# Country
# China                     411683.0                    4.70    138.0
# India                      37209.0                    8.58    115.0
# United States             265436.0                    8.20    230.0
# Brazil                     14396.0                    7.00     86.0
# Russian Federation         12422.0                    1.85     57.0
#
#                     Energy Supply  Energy Supply per Capita  % Renewable  ...  \
# ...

# %%
 ContinentDict  = {'China':'Asia',
                      'United States':'North America', 
                      'Japan':'Asia',
                      'United Kingdom':'Europe',
                      'Russian Federation':'Europe',
                      'Canada':'North America',
                      'Germany':'Europe', 
                      'India':'Asia',
                      'France':'Europe', 
                      'South Korea':'Asia', 
                      'Italy':'Europe', 
                      'Spain':'Europe', 
                      'Iran':'Asia',
                      'Australia':'Australia', 
                      'Brazil':'South America'}

# %%
result=result.reset_index()
result['Country'].map(ContinentDict)
# Out:
# 0              Asia
# 1              Asia
# 2     North America
# 3     South America
# 4            Europe
# 5              Asia
# 6            Europe
# 7              Asia
# 8            Europe
# 9            Europe
# 10           Europe
# 11             Asia
# 12           Europe
# 13    North America
# 14        Australia
# Name: Country, dtype: object

# %%
result['Country']
# Out:
# 0                  China
# 1                  India
# 2          United States
# 3                 Brazil
# 4     Russian Federation
# 5                  Japan
# 6                Germany
# 7                   Iran
# 8         United Kingdom
# 9                 France
# 10                 Italy
# 11           South Korea
# 12                 Spain
# 13                Canada
# 14             Australia
# Name: Country, dtype: object

# %%
result['popest']
# Out:
# 0     1.367645e+09
# 1     1.276731e+09
# 2     3.176154e+08
# 3     2.059153e+08
# 4     1.435000e+08
# 5     1.274094e+08
# 6     8.036970e+07
# 7     7.707563e+07
# 8     6.387097e+07
# 9     6.383735e+07
# 10    5.990826e+07
# 11    4.980543e+07
# 12    4.644340e+07
# 13    3.523986e+07
# 14    2.331602e+07
# Name: popest, dtype: float64

# %%
ContinentDict  = {'China':'Asia',
                      'United States':'North America', 
                      'Japan':'Asia',
                      'United Kingdom':'Europe',
                      'Russian Federation':'Europe',
                      'Canada':'North America',
                      'Germany':'Europe', 
                      'India':'Asia',
                      'France':'Europe', 
                      'South Korea':'Asia', 
                      'Italy':'Europe', 
                      'Spain':'Europe', 
                      'Iran':'Asia',
                      'Australia':'Australia', 
                      'Brazil':'South America'}

# %%
result['continent']=result['Country'].map(ContinentDict)
result1=result.copy()
result1=result1[['continent','popest']]
result1=result1.groupby('continent')['popest'].agg([np.size,np.sum,np.mean,np.std])

# %%
result1
# Out:
#                size           sum          mean           std
# continent
# Asia            5.0  2.898666e+09  5.797333e+08  6.790979e+08
# Australia       1.0  2.331602e+07  2.331602e+07           NaN
# Europe          6.0  4.579297e+08  7.632161e+07  3.464767e+07
# North America   2.0  3.528552e+08  1.764276e+08  1.996696e+08
# South America   1.0  2.059153e+08  2.059153e+08           NaN

# %%
result['continent']
# Out:
# 0              Asia
# 1              Asia
# 2     North America
# 3     South America
# 4            Europe
# 5              Asia
# 6            Europe
# 7              Asia
# 8            Europe
# 9            Europe
# 10           Europe
# 11             Asia
# 12           Europe
# 13    North America
# 14        Australia
# Name: continent, dtype: object

# %%
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
    del(energy['Unnamed: 0'])
    del(energy['Unnamed: 1'])
    col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy.columns = col_names
    energy.loc[energy['Energy Supply'] == '...'] = np.NaN
    energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*10**6
    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
    replace_dict={"Republic of Korea": "South Korea",
                  "United States of America": "United States",
                  "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                  "China, Hong Kong Special Administrative Region": "Hong Kong"}
    energy['Country'].replace(to_replace=replace_dict, inplace=True)
    energy.reset_index()
    energy = energy.set_index('Country')
    
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype('str')
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')
    
    ScimEn = pd.read_excel('scimagojr-3.xlsx', header=0)
    ScimEn.reset_index()
    ScimEn = ScimEn.set_index('Country')
    first_merge = pd.merge(energy, GDP, how='outer', left_index=True, right_index=True)
    result = pd.merge(ScimEn, first_merge, how='outer', left_index=True, right_index=True)
    result = result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
    result = result.loc[result['Rank']<=15]

# %%
result=result.reset_index()
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

# %%
result['popest']=result['Energy Supply']/result['Energy Supply per Capita']
result['continent']=result['Country'].map(ContinentDict)
result1=result.copy()
result1=result1[['continent','popest']]
result1=result1.groupby('continent')['popest'].agg([np.size,np.sum,np.mean,np.std])
result1
# Out:
#                size           sum          mean           std
# continent
# Asia            5.0  2.898666e+09  5.797333e+08  6.790979e+08
# Australia       1.0  2.331602e+07  2.331602e+07           NaN
# Europe          6.0  4.579297e+08  7.632161e+07  3.464767e+07
# North America   2.0  3.528552e+08  1.764276e+08  1.996696e+08
# South America   1.0  2.059153e+08  2.059153e+08           NaN

# %%
result
# Out:
#                Country  Rank  Documents  Citable documents  Citations  \
# 0            Australia  14.0     8831.0             8725.0    90765.0
# 1               Brazil  15.0     8668.0             8596.0    60702.0
# 2               Canada   6.0    17899.0            17620.0   215003.0
# 3                China   1.0   127050.0           126767.0   597237.0
# 4               France   9.0    13153.0            12973.0   130632.0
# 5              Germany   7.0    17027.0            16831.0   140566.0
# 6                India   8.0    15005.0            14841.0   128763.0
# 7                 Iran  13.0     8896.0             8819.0    57470.0
# 8                Italy  11.0    10964.0            10794.0   111850.0
# 9                Japan   3.0    30504.0            30287.0   223024.0
# 10  Russian Federation   5.0    18534.0            18301.0    34266.0
# 11         South Korea  10.0    11983.0            11923.0   114675.0
# ...

# %%
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
    del(energy['Unnamed: 0'])
    del(energy['Unnamed: 1'])
    col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy.columns = col_names
    energy.loc[energy['Energy Supply'] == '...'] = np.NaN
    energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*10**6
    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
    replace_dict={"Republic of Korea": "South Korea",
                  "United States of America": "United States",
                  "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                  "China, Hong Kong Special Administrative Region": "Hong Kong"}
    energy['Country'].replace(to_replace=replace_dict, inplace=True)
    energy.reset_index()
    energy = energy.set_index('Country')
    
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype('str')
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')
    
    ScimEn = pd.read_excel('scimagojr-3.xlsx', header=0)
    ScimEn.reset_index()
    ScimEn = ScimEn.set_index('Country')
    first_merge = pd.merge(energy, GDP, how='outer', left_index=True, right_index=True)
    result = pd.merge(ScimEn, first_merge, how='outer', left_index=True, right_index=True)
    result = result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
    result = result.loc[result['Rank']<=15]

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

# %%
result=result.reset_index()
result['continent']=result['Country'].map(ContinentDict)
result['% Renewable']=pd.cut(result['% Renewable'],bins=5)
result.groupby(['continent','% Renewable']).size()
# Out:
# continent      % Renewable
# Asia           (2.212, 15.753]     4
#                (15.753, 29.227]    1
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# Australia      (2.212, 15.753]     1
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# Europe         (2.212, 15.753]     1
#                (15.753, 29.227]    3
#                (29.227, 42.701]    2
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# North America  (2.212, 15.753]     1
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    1
# South America  (2.212, 15.753]     0
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
# ...

# %%
result2
# Out:
#         continent       % Renewable  Country
# 0            Asia   (2.212, 15.753]        4
# 1            Asia  (15.753, 29.227]        1
# 2            Asia  (29.227, 42.701]        0
# 3            Asia  (42.701, 56.174]        0
# 4            Asia  (56.174, 69.648]        0
# 5       Australia   (2.212, 15.753]        1
# 6       Australia  (15.753, 29.227]        0
# 7       Australia  (29.227, 42.701]        0
# 8       Australia  (42.701, 56.174]        0
# 9       Australia  (56.174, 69.648]        0
# 10         Europe   (2.212, 15.753]        1
# 11         Europe  (15.753, 29.227]        3
# 12         Europe  (29.227, 42.701]        2
# 13         Europe  (42.701, 56.174]        0
# 14         Europe  (56.174, 69.648]        0
# 15  North America   (2.212, 15.753]        1
# 16  North America  (15.753, 29.227]        0
# 17  North America  (29.227, 42.701]        0
# 18  North America  (42.701, 56.174]        0
# 19  North America  (56.174, 69.648]        1
# ...

# %%
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
    del(energy['Unnamed: 0'])
    del(energy['Unnamed: 1'])
    col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy.columns = col_names
    energy.loc[energy['Energy Supply'] == '...'] = np.NaN
    energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*10**6
    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
    replace_dict={"Republic of Korea": "South Korea",
                  "United States of America": "United States",
                  "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                  "China, Hong Kong Special Administrative Region": "Hong Kong"}
    energy['Country'].replace(to_replace=replace_dict, inplace=True)
    energy.reset_index()
    energy = energy.set_index('Country')
    
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype('str')
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')
    
    ScimEn = pd.read_excel('scimagojr-3.xlsx', header=0)
    ScimEn.reset_index()
    ScimEn = ScimEn.set_index('Country')
    first_merge = pd.merge(energy, GDP, how='outer', left_index=True, right_index=True)
    result = pd.merge(ScimEn, first_merge, how='outer', left_index=True, right_index=True)
    result = result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
    result = result.loc[result['Rank']<=15]

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

# %%
result=result.reset_index()
result['continent']=[ContinentDict[country] for country in result['Country']]

# %%
result['continent']
# Out:
# 0         Australia
# 1     South America
# 2     North America
# 3              Asia
# 4            Europe
# 5            Europe
# 6              Asia
# 7              Asia
# 8            Europe
# 9              Asia
# 10           Europe
# 11             Asia
# 12           Europe
# 13           Europe
# 14    North America
# Name: continent, dtype: object

# %%
del(result['continent'])

# %%
result['continent']=result['Country'].map(ContinentDict)

# %%
result['continent']
result['%renewable']=pd.cut(result['% Renewable'],bins=5)
result.groupby(['continent','% Renewable']).size()
# Out:
# continent      % Renewable
# Asia           2.279353       1
#                5.707721       1
#                10.232820      1
#                14.969080      1
#                19.754910      1
# Australia      11.810810      1
# Europe         10.600470      1
#                17.020280      1
#                17.288680      1
#                17.901530      1
#                33.667230      1
#                37.968590      1
# North America  11.570980      1
#                61.945430      1
# South America  69.648030      1
# dtype: int64

# %%
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
    del(energy['Unnamed: 0'])
    del(energy['Unnamed: 1'])
    col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy.columns = col_names
    energy.loc[energy['Energy Supply'] == '...'] = np.NaN
    energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*10**6
    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
    replace_dict={"Republic of Korea": "South Korea",
                  "United States of America": "United States",
                  "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                  "China, Hong Kong Special Administrative Region": "Hong Kong"}
    energy['Country'].replace(to_replace=replace_dict, inplace=True)
    energy.reset_index()
    energy = energy.set_index('Country')
    
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype('str')
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')
    
    ScimEn = pd.read_excel('scimagojr-3.xlsx', header=0)
    ScimEn.reset_index()
    ScimEn = ScimEn.set_index('Country')
    first_merge = pd.merge(energy, GDP, how='outer', left_index=True, right_index=True)
    result = pd.merge(ScimEn, first_merge, how='outer', left_index=True, right_index=True)
    result = result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
    result = result.loc[result['Rank']<=15]
    ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}

# %%
result=result.reset_index()
result['continent']=result['Country'].map(ContinentDict)
result['%renewable']=pd.cut(result['% Renewable'],bins=5)
result.groupby(['continent','%renewable']).size()
# Out:
# continent      %renewable
# Asia           (2.212, 15.753]     4
#                (15.753, 29.227]    1
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# Australia      (2.212, 15.753]     1
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# Europe         (2.212, 15.753]     1
#                (15.753, 29.227]    3
#                (29.227, 42.701]    2
#                (42.701, 56.174]    0
#                (56.174, 69.648]    0
# North America  (2.212, 15.753]     1
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
#                (56.174, 69.648]    1
# South America  (2.212, 15.753]     0
#                (15.753, 29.227]    0
#                (29.227, 42.701]    0
#                (42.701, 56.174]    0
# ...

# %%
    import pandas as pd
    import numpy as np
    energy = pd.read_excel('Energy Indicators.xls', skip_footer=38, skiprows=17)
    del(energy['Unnamed: 0'])
    del(energy['Unnamed: 1'])
    col_names = ['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    energy.columns = col_names
    energy.loc[energy['Energy Supply'] == '...'] = np.NaN
    energy[['Energy Supply', 'Energy Supply per Capita']] = energy[['Energy Supply', 'Energy Supply per Capita']].apply(pd.to_numeric)
    energy['Energy Supply'] = energy['Energy Supply']*10**6
    energy['Country'] = energy['Country'].str.replace(r" \(.*\)","")
    energy['Country'] = energy['Country'].str.replace(r"([0-9]+)$","")
    replace_dict={"Republic of Korea": "South Korea",
                  "United States of America": "United States",
                  "United Kingdom of Great Britain and Northern Ireland": "United Kingdom",
                  "China, Hong Kong Special Administrative Region": "Hong Kong"}
    energy['Country'].replace(to_replace=replace_dict, inplace=True)
    energy.reset_index()
    energy = energy.set_index('Country')
    
    GDP = pd.read_csv('world_bank.csv', skiprows=4)
    replace_dict = {"Korea, Rep.": "South Korea", 
                    "Iran, Islamic Rep.": "Iran",
                    "Hong Kong SAR, China": "Hong Kong"
                   }
    GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
    years_to_keep = np.arange(2006, 2016).astype('str')
    GDP = GDP[np.append(['Country Name'],years_to_keep)]
    GDP.reset_index()
    GDP = GDP.rename(columns={'Country Name': 'Country'})
    GDP = GDP.set_index('Country')
    
    ScimEn = pd.read_excel('scimagojr-3.xlsx', header=0)
    ScimEn.reset_index()
    ScimEn = ScimEn.set_index('Country')
    first_merge = pd.merge(energy, GDP, how='outer', left_index=True, right_index=True)
    result = pd.merge(ScimEn, first_merge, how='outer', left_index=True, right_index=True)
    result = result.reset_index().dropna(thresh=result.shape[1]-10).set_index('Country')
    result = result.loc[result['Rank']<=15]

# %%
result
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# Australia           14.0     8831.0             8725.0    90765.0
# Brazil              15.0     8668.0             8596.0    60702.0
# Canada               6.0    17899.0            17620.0   215003.0
# China                1.0   127050.0           126767.0   597237.0
# France               9.0    13153.0            12973.0   130632.0
# Germany              7.0    17027.0            16831.0   140566.0
# India                8.0    15005.0            14841.0   128763.0
# Iran                13.0     8896.0             8819.0    57470.0
# Italy               11.0    10964.0            10794.0   111850.0
# Japan                3.0    30504.0            30287.0   223024.0
# Russian Federation   5.0    18534.0            18301.0    34266.0
# South Korea         10.0    11983.0            11923.0   114675.0
# Spain               12.0     9428.0             9330.0   123336.0
# ...

# %%
10**6
# Out:
# 1000000
